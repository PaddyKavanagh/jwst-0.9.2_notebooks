# %% [markdown]
# # Run level 2A, 2B and 3 pipelines on MRS data using jwst.pipeline classes

# %% [markdown]
# ### by Patrick Kavanagh (DIAS, Ireland) April 10th 2018

# %% [markdown]
# This notebook demonstrates the execution of the level 2A, 2B, and 3 pipelines for MRS data in Python using the jwst.pipeline classes.
#
# For a description of the pipeline classes see:
#
# https://jwst-pipeline.readthedocs.io/en/latest/jwst/pipeline/index.html
#
# The files used in this notebook is a MIRISim simulation of a point source with power-law (alpha=0) plus emission lines spectrum. The simulated observation is a four-point dither on the source with the channels 1 and 2, and the SHORT disperser.
#
# The steps applied are:
#
# - ramps to slopes pipeline (Detector1Pipeline)
#
# - CALSPEC2 steps and spectral extraction from each dither (Spec2Pipeline)
#
# - combination of dithers and spectral extraction (Spec3Pipeline)
#
# - manual conversion of extracted spectra to Jy

# %% [markdown]
# #### Imports

# %%
import os, glob, shutil

import numpy as np
from astropy.io import fits
from matplotlib.colors import LogNorm
import matplotlib.pyplot as plt
from subprocess import call

from jwst import datamodels

# %matplotlib inline
# %matplotlib notebook # if you want interactive plots

# %% [markdown]
# #### Set input, output location and source type
# Since we know the simulation is of a point source, we can set the source type metadata to 'POINT' at this stage as that information is used later in spectral extraction. Otherwise, the pipeline will set the default source type for MRS which is 'EXTENDED'

# %%
# set input filenames and directory. In this example, the files are located in a folder called 'MRS_demo_data'
input_dir = 'MRS_demo_data'
input_files = glob.glob(os.path.join(input_dir,'*.fits'))

# set the source type as 'POINT'
for f in input_files:
    with datamodels.MIRIRampModel(f) as dm:
        dm.meta.target.source_type = 'POINT'
        dm.save(os.path.join(input_dir, dm.meta.filename))

# set the output directory name
output_dir = input_dir + '_pipelined'

# if the output directory exists, delete it
if os.path.exists(output_dir): shutil.rmtree(output_dir)

# create the output directory
os.mkdir(output_dir)

# %% [markdown]
# #### print some information about the input files. We will just look at the first file

# %%
# print some info on input file
with fits.open(input_files[0]) as hdulist:
    
    if hdulist[0].header['ORIGIN'] == 'STScI':
        # specific information on instrument/exposure
        identifier = hdulist[0].header['OBS_ID']
        detector = hdulist[0].header['DETECTOR']
        nInts = hdulist[0].header['NINTS']
        nGroups = hdulist[0].header['NGROUPS']
        readPatt = hdulist[0].header['READPATT']
        expTime = hdulist[0].header['EFFEXPTM']
        subArr = hdulist[0].header['SUBARRAY']
        channel = hdulist[0].header['CHANNEL']
        band = hdulist[0].header['BAND']
        print("ID\t\t\t\t Detector\t nInts\t nGrps\t rdPatt\t subAr\t chan.\t band")
        print("--------------------------------------------------------------------------------------------------")
        print("%s\t %s\t %d\t %s\t %s\t %s\t %s\t %s" % (identifier,detector,nInts,nGroups,readPatt,subArr,channel,band))
        print("\n\n")
        
    else:
        # specific information on instrument/exposure
        detector = hdulist[0].header['DETECTOR']
        nInts = hdulist[0].header['NINTS']
        nGroups = hdulist[0].header['NGROUPS']
        readPatt = hdulist[0].header['READPATT']
        expTime = hdulist[0].header['EFFEXPTM']
        subArr = hdulist[0].header['SUBARRAY']
        channel = hdulist[0].header['CHANNEL']
        band = hdulist[0].header['BAND']
        print("ID\t Detector\t nInts\t nGrps\t rdPatt\t chan.\t band")
        print("--------------------------------------------------------------------------------------------------")
        print("MIRISim\t %s\t %d\t %s\t %s\t %s\t %s" % (detector,nInts,nGroups,readPatt,channel,band))
        print("\n\n")

    # fits extension table
    hdulist.info()
# Out:
# ID	 Detector	 nInts	 nGrps	 rdPatt	 chan.	 band
# --------------------------------------------------------------------------------------------------
# MIRISim	 MIRIFUSHORT	 2	 50	 FAST	 12	 SHORT
#
#
#
# Filename: MRS_demo_data/det_image_seq2_MIRIFUSHORT_12SHORTexp1.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      99   ()
#   1  SCI           1 ImageHDU        62   (1032, 1024, 50, 2)   float32
#   2  PIXELDQ       1 ImageHDU        11   (1032, 1024)   int32 (rescales to uint32)
#   3  GROUPDQ       1 ImageHDU        11   (1032, 1024, 50, 2)   uint8
#   4  ERR           1 ImageHDU        11   (1032, 1024, 50, 2)   float32
#   5  REFOUT        1 ImageHDU        12   (258, 1024, 50, 2)   float32
#   6  PIXELDQ_DEF    1 BinTableHDU     17   31R x 4C   [J, J, 40A, 128A]
#   7  ASDF          1 AsdfHDU          8   (105680587,)

# %% [markdown]
# #### show the last frame of the first integration for each file

# %%
fig, axs = plt.subplots(2, 2, figsize=(12, 12))
axs = axs.ravel()

i = 0
for f in input_files:
    # open the input image as a jwst data model
    with datamodels.MIRIRampModel(f) as in_dm:

        dith_num = i+1
        axs[i].imshow(in_dm.data[0,-1,:,:], cmap='jet', interpolation='nearest', origin='lower', norm=LogNorm(vmin=1e4,vmax=1.5e4))
        axs[i].annotate('Dither %d' % dith_num, xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')
        axs[i].set_facecolor('black')
        i += 1

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Level 2A pipeline (ramps-to-slopes)

# %% [markdown]
# #### import the level 2A pipeline class and print description

# %%
from jwst.pipeline import Detector1Pipeline
print(Detector1Pipeline.__doc__)
# Out:
#     Detector1Pipeline: Apply all calibration steps to raw JWST
#     ramps to produce a 2-D slope product. Included steps are:
#     group_scale, dq_init, saturation, ipc, superbias, refpix, rscd,
#     lastframe, linearity, dark_current, persistence, jump detection,
#     ramp_fit, and gain_scale.

# %% [markdown]
# #### run pipeline
# We pass the level 1B files (demo data). We need to explicitly skip the IPC step. The output level 2A files will be saved in the output_dir as '*_rate.fits'

# %%
for f in input_files:
    Detector1Pipeline.call(f, output_use_model=True, save_results=True, output_dir=output_dir,
                           steps={'ipc': {'skip': True}})
# Out:
# 2018-04-17 11:37:35,617 - stpipe.Detector1Pipeline - INFO - Detector1Pipeline instance created.
# 2018-04-17 11:37:35,620 - stpipe.Detector1Pipeline.lastframe - INFO - LastFrameStep instance created.
# 2018-04-17 11:37:35,622 - stpipe.Detector1Pipeline.dark_current - INFO - DarkCurrentStep instance created.
# 2018-04-17 11:37:35,624 - stpipe.Detector1Pipeline.refpix - INFO - RefPixStep instance created.
# 2018-04-17 11:37:35,626 - stpipe.Detector1Pipeline.linearity - INFO - LinearityStep instance created.
# 2018-04-17 11:37:35,628 - stpipe.Detector1Pipeline.jump - INFO - JumpStep instance created.
# 2018-04-17 11:37:35,630 - stpipe.Detector1Pipeline.firstframe - INFO - FirstFrameStep instance created.
# 2018-04-17 11:37:35,632 - stpipe.Detector1Pipeline.ramp_fit - INFO - RampFitStep instance created.
# 2018-04-17 11:37:35,633 - stpipe.Detector1Pipeline.gain_scale - INFO - GainScaleStep instance created.
# 2018-04-17 11:37:35,635 - stpipe.Detector1Pipeline.saturation - INFO - SaturationStep instance created.
# 2018-04-17 11:37:35,637 - stpipe.Detector1Pipeline.superbias - INFO - SuperBiasStep instance created.
# 2018-04-17 11:37:35,638 - stpipe.Detector1Pipeline.dq_init - INFO - DQInitStep instance created.
# 2018-04-17 11:37:35,640 - stpipe.Detector1Pipeline.group_scale - INFO - GroupScaleStep instance created.
# 2018-04-17 11:37:35,641 - stpipe.Detector1Pipeline.persistence - INFO - PersistenceStep instance created.
# 2018-04-17 11:37:35,643 - stpipe.Detector1Pipeline.rscd - INFO - RSCD_Step instance created.
# 2018-04-17 11:37:35,645 - stpipe.Detector1Pipeline.ipc - INFO - IPCStep instance created.
# 2018-04-17 11:37:37,409 - stpipe.Detector1Pipeline - INFO - Prefetch for DARK reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_dark_0056.fits'.
# 2018-04-17 11:37:37,410 - stpipe.Detector1Pipeline - INFO - Prefetch for GAIN reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_gain_0007.fits'.
# 2018-04-17 11:37:37,412 - stpipe.Detector1Pipeline - INFO - Prefetch for LINEARITY reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_linearity_0023.fits'.
# 2018-04-17 11:37:37,413 - stpipe.Detector1Pipeline - INFO - Prefetch for MASK reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_mask_0020.fits'.
# 2018-04-17 11:37:37,414 - stpipe.Detector1Pipeline - INFO - Prefetch for PERSAT reference file is 'N/A'.
# 2018-04-17 11:37:37,414 - stpipe.Detector1Pipeline - INFO - Prefetch for READNOISE reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_readnoise_0034.fits'.
# 2018-04-17 11:37:37,416 - stpipe.Detector1Pipeline - INFO - Prefetch for REFPIX reference file is 'N/A'.
# 2018-04-17 11:37:37,416 - stpipe.Detector1Pipeline - INFO - Prefetch for RSCD reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_rscd_0002.fits'.
# 2018-04-17 11:37:37,417 - stpipe.Detector1Pipeline - INFO - Prefetch for SATURATION reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_saturation_0020.fits'.
# 2018-04-17 11:37:37,418 - stpipe.Detector1Pipeline - INFO - Prefetch for SUPERBIAS reference file is 'N/A'.
# 2018-04-17 11:37:37,419 - stpipe.Detector1Pipeline - INFO - Prefetch for TRAPDENSITY reference file is 'N/A'.
# 2018-04-17 11:37:37,419 - stpipe.Detector1Pipeline - INFO - Prefetch for TRAPPARS reference file is 'N/A'.
# 2018-04-17 11:37:37,420 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline running with args ('MRS_demo_data/det_image_seq2_MIRIFUSHORT_12SHORTexp1.fits',).
# 2018-04-17 11:37:37,421 - stpipe.Detector1Pipeline - INFO - Starting calwebb_detector1 ...
# 2018-04-17 11:37:37,778 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale running with args (<jwst.datamodels.ramp.RampModel object at 0x181abe2a58>,).
# 2018-04-17 11:37:37,812 - stpipe.Detector1Pipeline.group_scale - WARNING - NFRAMES=1 is a power of 2
# 2018-04-17 11:37:37,813 - stpipe.Detector1Pipeline.group_scale - WARNING - Step will be skipped
# 2018-04-17 11:37:37,815 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale done
# 2018-04-17 11:37:37,897 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init running with args (<jwst.datamodels.ramp.RampModel object at 0x1818c1efd0>,).
# 2018-04-17 11:37:37,939 - stpipe.Detector1Pipeline.dq_init - INFO - Using MASK reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_mask_0020.fits
# 2018-04-17 11:37:42,271 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init done
# 2018-04-17 11:37:42,390 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation running with args (<jwst.datamodels.ramp.RampModel object at 0x1818c54cf8>,).
# 2018-04-17 11:37:42,430 - stpipe.Detector1Pipeline.saturation - INFO - Using SATURATION reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_saturation_0020.fits
# 2018-04-17 11:37:43,739 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation done
# 2018-04-17 11:37:43,824 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc running with args (<jwst.datamodels.ramp.RampModel object at 0x1818d7a908>,).
# 2018-04-17 11:37:43,825 - stpipe.Detector1Pipeline.ipc - INFO - Step skipped.
# 2018-04-17 11:37:43,828 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc done
# 2018-04-17 11:37:43,909 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity running with args (<jwst.datamodels.ramp.RampModel object at 0x1818d7a908>,).
# 2018-04-17 11:37:43,951 - stpipe.Detector1Pipeline.linearity - INFO - Using Linearity reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_linearity_0023.fits
# 2018-04-17 11:37:46,062 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity done
# 2018-04-17 11:37:46,133 - stpipe.Detector1Pipeline.rscd - INFO - Step rscd running with args (<jwst.datamodels.ramp.RampModel object at 0x1818d76fd0>,).
# 2018-04-17 11:37:46,174 - stpipe.Detector1Pipeline.rscd - INFO - Using RSCD reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_rscd_0002.fits
# 2018-04-17 11:39:01,270 - stpipe.Detector1Pipeline.rscd - INFO - Step rscd done
# 2018-04-17 11:39:01,346 - stpipe.Detector1Pipeline.firstframe - INFO - Step firstframe running with args (<jwst.datamodels.ramp.RampModel object at 0x1818a60eb8>,).
# 2018-04-17 11:39:02,296 - stpipe.Detector1Pipeline.firstframe - INFO - Step firstframe done
# 2018-04-17 11:39:02,389 - stpipe.Detector1Pipeline.lastframe - INFO - Step lastframe running with args (<jwst.datamodels.ramp.RampModel object at 0x1134e1128>,).
# 2018-04-17 11:39:03,257 - stpipe.Detector1Pipeline.lastframe - INFO - Step lastframe done
# 2018-04-17 11:39:03,344 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current running with args (<jwst.datamodels.ramp.RampModel object at 0x1818c54b38>,).
# 2018-04-17 11:39:03,388 - stpipe.Detector1Pipeline.dark_current - INFO - Using DARK reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_dark_0056.fits
# 2018-04-17 11:39:03,618 - stpipe.Detector1Pipeline.dark_current - INFO - Science data nints=2, ngroups=50, nframes=1, groupgap=0
# 2018-04-17 11:39:03,619 - stpipe.Detector1Pipeline.dark_current - INFO - Dark data nints=2, ngroups=200, nframes=1, groupgap=0
# 2018-04-17 11:39:13,326 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current done
# 2018-04-17 11:39:13,440 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix running with args (<jwst.datamodels.ramp.RampModel object at 0x1136754e0>,).
# 2018-04-17 11:39:13,555 - stpipe.Detector1Pipeline.refpix - INFO - use_side_ref_pixels = True
# 2018-04-17 11:39:13,557 - stpipe.Detector1Pipeline.refpix - INFO - odd_even_columns = True
# 2018-04-17 11:39:13,557 - stpipe.Detector1Pipeline.refpix - INFO - side_smoothing_length = 11
# 2018-04-17 11:39:13,558 - stpipe.Detector1Pipeline.refpix - INFO - side_gain = 1.000000
# 2018-04-17 11:39:13,559 - stpipe.Detector1Pipeline.refpix - INFO - odd_even_rows = True
# 2018-04-17 11:39:14,238 - stpipe.Detector1Pipeline.refpix - INFO - Subtracting initial read from each integration
# 2018-04-17 11:39:16,140 - stpipe.Detector1Pipeline.refpix - INFO - Adding initial read back in
# 2018-04-17 11:39:18,984 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix done
# 2018-04-17 11:39:19,115 - stpipe.Detector1Pipeline.jump - INFO - Step jump running with args (<jwst.datamodels.ramp.RampModel object at 0x1818a608d0>,).
# 2018-04-17 11:39:19,161 - stpipe.Detector1Pipeline.jump - INFO - CR rejection threshold = 4 sigma
# 2018-04-17 11:39:19,173 - stpipe.Detector1Pipeline.jump - INFO - Using GAIN reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_gain_0007.fits
# 2018-04-17 11:39:19,246 - stpipe.Detector1Pipeline.jump - INFO - Using READNOISE reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_readnoise_0034.fits
# 2018-04-17 11:39:21,110 - stpipe.Detector1Pipeline.jump - INFO - Executing two-point difference method
# 2018-04-17 11:39:21,775 - stpipe.Detector1Pipeline.jump - INFO -  working on integration 1
# 2018-04-17 11:39:25,109 - stpipe.Detector1Pipeline.jump - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/jump/twopoint_difference.py:83: RuntimeWarning: invalid value encountered in sqrt
#   poisson_noise = np.sqrt(np.abs(med_diffs))
#
# 2018-04-17 11:39:40,037 - stpipe.Detector1Pipeline.jump - INFO -  working on integration 2
# 2018-04-17 11:39:58,597 - stpipe.Detector1Pipeline.jump - INFO - Step jump done
# 2018-04-17 11:39:58,687 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit running with args (<jwst.datamodels.ramp.RampModel object at 0x1818c47518>,).
# 2018-04-17 11:39:58,734 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using READNOISE reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_readnoise_0034.fits
# 2018-04-17 11:39:58,887 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using GAIN reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_gain_0007.fits
# 2018-04-17 11:39:58,927 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using algorithm = ols
# 2018-04-17 11:39:58,928 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using weighting = optimal
# 2018-04-17 11:39:58,932 - stpipe.Detector1Pipeline.ramp_fit - INFO - MIRI dataset has all final reads flagged as DO_NOT_USE.
# 2018-04-17 11:39:58,956 - stpipe.Detector1Pipeline.ramp_fit - INFO - Effective integration time per group: 2.77504
# 2018-04-17 11:41:40,898 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/utils.py:475: RuntimeWarning: invalid value encountered in true_divide
#   var_poisson = sum_p / (sum_wgt_p * nsegs_pix)
#
# 2018-04-17 11:41:49,515 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/utils.py:481: RuntimeWarning: divide by zero encountered in true_divide
#   var_r = rn_1d**2 * 12./(segments**3. - segments)
#
# 2018-04-17 11:41:50,658 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/utils.py:485: RuntimeWarning: divide by zero encountered in true_divide
#   sum_r = (segments*var_r[:]/((nsegs_pix)**3.)).sum(axis=0)
#
# 2018-04-17 11:41:50,659 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/utils.py:485: RuntimeWarning: invalid value encountered in true_divide
#   sum_r = (segments*var_r[:]/((nsegs_pix)**3.)).sum(axis=0)
#
# 2018-04-17 11:41:50,815 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/utils.py:489: RuntimeWarning: divide by zero encountered in true_divide
#   var_readnoise = sum_r/nsegs_pix
#
# 2018-04-17 11:41:50,816 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/utils.py:489: RuntimeWarning: invalid value encountered in true_divide
#   var_readnoise = sum_r/nsegs_pix
#
# 2018-04-17 11:43:31,277 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/utils.py:475: RuntimeWarning: divide by zero encountered in true_divide
#   var_poisson = sum_p / (sum_wgt_p * nsegs_pix)
#
# 2018-04-17 11:43:41,280 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/ramp_fit.py:324: RuntimeWarning: invalid value encountered in sqrt
#   err_2d_all = np.sqrt( var_p_2d_all + var_r_2d_all )
#
# 2018-04-17 11:44:46,549 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/utils.py:620: RuntimeWarning: invalid value encountered in sqrt
#   cubemod.err = np.sqrt(var_p_int + var_r_int)
#
# 2018-04-17 11:44:46,588 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of groups per integration: 50
# 2018-04-17 11:44:46,589 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of integrations: 2
# 2018-04-17 11:44:47,006 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit done
# 2018-04-17 11:44:47,178 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<jwst.datamodels.ifuimage.IFUImageModel object at 0x1818d1acf8>,).
# 2018-04-17 11:44:47,267 - stpipe.Detector1Pipeline.gain_scale - INFO - GAINFACT not found in gain reference file
# 2018-04-17 11:44:47,268 - stpipe.Detector1Pipeline.gain_scale - INFO - Step will be skipped
# 2018-04-17 11:44:47,271 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# 2018-04-17 11:44:47,356 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<jwst.datamodels.cube.CubeModel object at 0x1818b78e48>,).
# 2018-04-17 11:44:47,442 - stpipe.Detector1Pipeline.gain_scale - INFO - GAINFACT not found in gain reference file
# 2018-04-17 11:44:47,443 - stpipe.Detector1Pipeline.gain_scale - INFO - Step will be skipped
# 2018-04-17 11:44:47,446 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# 2018-04-17 11:44:47,583 - stpipe.Detector1Pipeline - INFO - Saved model in MRS_demo_data_pipelined/det_image_seq2_MIRIFUSHORT_12SHORTexp1_rateints.fits
# 2018-04-17 11:44:47,584 - stpipe.Detector1Pipeline - INFO - ... ending calwebb_detector1
# 2018-04-17 11:44:47,709 - stpipe.Detector1Pipeline - INFO - Saved model in MRS_demo_data_pipelined/det_image_seq2_MIRIFUSHORT_12SHORTexp1_rate.fits
# 2018-04-17 11:44:47,710 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline done
# 2018-04-17 11:44:47,724 - stpipe.Detector1Pipeline - INFO - Detector1Pipeline instance created.
# 2018-04-17 11:44:47,725 - stpipe.Detector1Pipeline.lastframe - INFO - LastFrameStep instance created.
# 2018-04-17 11:44:47,727 - stpipe.Detector1Pipeline.dark_current - INFO - DarkCurrentStep instance created.
# 2018-04-17 11:44:47,729 - stpipe.Detector1Pipeline.refpix - INFO - RefPixStep instance created.
# 2018-04-17 11:44:47,730 - stpipe.Detector1Pipeline.linearity - INFO - LinearityStep instance created.
# 2018-04-17 11:44:47,732 - stpipe.Detector1Pipeline.jump - INFO - JumpStep instance created.
# 2018-04-17 11:44:47,734 - stpipe.Detector1Pipeline.firstframe - INFO - FirstFrameStep instance created.
# 2018-04-17 11:44:47,736 - stpipe.Detector1Pipeline.ramp_fit - INFO - RampFitStep instance created.
# 2018-04-17 11:44:47,737 - stpipe.Detector1Pipeline.gain_scale - INFO - GainScaleStep instance created.
# 2018-04-17 11:44:47,739 - stpipe.Detector1Pipeline.saturation - INFO - SaturationStep instance created.
# 2018-04-17 11:44:47,741 - stpipe.Detector1Pipeline.superbias - INFO - SuperBiasStep instance created.
# 2018-04-17 11:44:47,743 - stpipe.Detector1Pipeline.dq_init - INFO - DQInitStep instance created.
# 2018-04-17 11:44:47,744 - stpipe.Detector1Pipeline.group_scale - INFO - GroupScaleStep instance created.
# 2018-04-17 11:44:47,746 - stpipe.Detector1Pipeline.persistence - INFO - PersistenceStep instance created.
# 2018-04-17 11:44:47,748 - stpipe.Detector1Pipeline.rscd - INFO - RSCD_Step instance created.
# 2018-04-17 11:44:47,749 - stpipe.Detector1Pipeline.ipc - INFO - IPCStep instance created.
# 2018-04-17 11:44:48,349 - stpipe.Detector1Pipeline - INFO - Prefetch for DARK reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_dark_0056.fits'.
# 2018-04-17 11:44:48,350 - stpipe.Detector1Pipeline - INFO - Prefetch for GAIN reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_gain_0007.fits'.
# 2018-04-17 11:44:48,351 - stpipe.Detector1Pipeline - INFO - Prefetch for LINEARITY reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_linearity_0023.fits'.
# 2018-04-17 11:44:48,352 - stpipe.Detector1Pipeline - INFO - Prefetch for MASK reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_mask_0020.fits'.
# 2018-04-17 11:44:48,353 - stpipe.Detector1Pipeline - INFO - Prefetch for PERSAT reference file is 'N/A'.
# 2018-04-17 11:44:48,354 - stpipe.Detector1Pipeline - INFO - Prefetch for READNOISE reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_readnoise_0034.fits'.
# 2018-04-17 11:44:48,355 - stpipe.Detector1Pipeline - INFO - Prefetch for REFPIX reference file is 'N/A'.
# 2018-04-17 11:44:48,356 - stpipe.Detector1Pipeline - INFO - Prefetch for RSCD reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_rscd_0002.fits'.
# 2018-04-17 11:44:48,356 - stpipe.Detector1Pipeline - INFO - Prefetch for SATURATION reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_saturation_0020.fits'.
# 2018-04-17 11:44:48,357 - stpipe.Detector1Pipeline - INFO - Prefetch for SUPERBIAS reference file is 'N/A'.
# 2018-04-17 11:44:48,358 - stpipe.Detector1Pipeline - INFO - Prefetch for TRAPDENSITY reference file is 'N/A'.
# 2018-04-17 11:44:48,359 - stpipe.Detector1Pipeline - INFO - Prefetch for TRAPPARS reference file is 'N/A'.
# 2018-04-17 11:44:48,360 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline running with args ('MRS_demo_data/det_image_seq1_MIRIFUSHORT_12SHORTexp1.fits',).
# 2018-04-17 11:44:48,361 - stpipe.Detector1Pipeline - INFO - Starting calwebb_detector1 ...
# 2018-04-17 11:44:48,740 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale running with args (<jwst.datamodels.ramp.RampModel object at 0x1818d7d7b8>,).
# 2018-04-17 11:44:48,776 - stpipe.Detector1Pipeline.group_scale - WARNING - NFRAMES=1 is a power of 2
# 2018-04-17 11:44:48,776 - stpipe.Detector1Pipeline.group_scale - WARNING - Step will be skipped
# 2018-04-17 11:44:48,778 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale done
# 2018-04-17 11:44:48,863 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init running with args (<jwst.datamodels.ramp.RampModel object at 0x113675208>,).
# 2018-04-17 11:44:48,907 - stpipe.Detector1Pipeline.dq_init - INFO - Using MASK reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_mask_0020.fits
# 2018-04-17 11:44:53,302 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init done
# 2018-04-17 11:44:53,412 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation running with args (<jwst.datamodels.ramp.RampModel object at 0x1818c27668>,).
# 2018-04-17 11:44:53,451 - stpipe.Detector1Pipeline.saturation - INFO - Using SATURATION reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_saturation_0020.fits
# 2018-04-17 11:44:54,715 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation done
# 2018-04-17 11:44:54,796 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc running with args (<jwst.datamodels.ramp.RampModel object at 0x1818d7b898>,).
# 2018-04-17 11:44:54,797 - stpipe.Detector1Pipeline.ipc - INFO - Step skipped.
# 2018-04-17 11:44:54,799 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc done
# 2018-04-17 11:44:54,854 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity running with args (<jwst.datamodels.ramp.RampModel object at 0x1818d7b898>,).
# 2018-04-17 11:44:54,896 - stpipe.Detector1Pipeline.linearity - INFO - Using Linearity reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_linearity_0023.fits
# 2018-04-17 11:44:57,074 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity done
# 2018-04-17 11:44:57,159 - stpipe.Detector1Pipeline.rscd - INFO - Step rscd running with args (<jwst.datamodels.ramp.RampModel object at 0x1818d7d0b8>,).
# 2018-04-17 11:44:57,204 - stpipe.Detector1Pipeline.rscd - INFO - Using RSCD reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_rscd_0002.fits
# 2018-04-17 11:45:43,610 - stpipe.Detector1Pipeline.rscd - INFO - Step rscd done
# 2018-04-17 11:45:43,678 - stpipe.Detector1Pipeline.firstframe - INFO - Step firstframe running with args (<jwst.datamodels.ramp.RampModel object at 0x11343c2e8>,).
# 2018-04-17 11:45:44,576 - stpipe.Detector1Pipeline.firstframe - INFO - Step firstframe done
# 2018-04-17 11:45:44,659 - stpipe.Detector1Pipeline.lastframe - INFO - Step lastframe running with args (<jwst.datamodels.ramp.RampModel object at 0x11352e390>,).
# 2018-04-17 11:45:45,519 - stpipe.Detector1Pipeline.lastframe - INFO - Step lastframe done
# 2018-04-17 11:45:45,596 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current running with args (<jwst.datamodels.ramp.RampModel object at 0x11341cf98>,).
# 2018-04-17 11:45:45,638 - stpipe.Detector1Pipeline.dark_current - INFO - Using DARK reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_dark_0056.fits
# 2018-04-17 11:45:45,857 - stpipe.Detector1Pipeline.dark_current - INFO - Science data nints=2, ngroups=50, nframes=1, groupgap=0
# 2018-04-17 11:45:45,858 - stpipe.Detector1Pipeline.dark_current - INFO - Dark data nints=2, ngroups=200, nframes=1, groupgap=0
# 2018-04-17 11:45:54,488 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current done
# 2018-04-17 11:45:54,609 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix running with args (<jwst.datamodels.ramp.RampModel object at 0x181abbdc50>,).
# 2018-04-17 11:45:54,728 - stpipe.Detector1Pipeline.refpix - INFO - use_side_ref_pixels = True
# 2018-04-17 11:45:54,729 - stpipe.Detector1Pipeline.refpix - INFO - odd_even_columns = True
# 2018-04-17 11:45:54,730 - stpipe.Detector1Pipeline.refpix - INFO - side_smoothing_length = 11
# 2018-04-17 11:45:54,731 - stpipe.Detector1Pipeline.refpix - INFO - side_gain = 1.000000
# 2018-04-17 11:45:54,732 - stpipe.Detector1Pipeline.refpix - INFO - odd_even_rows = True
# 2018-04-17 11:45:55,464 - stpipe.Detector1Pipeline.refpix - INFO - Subtracting initial read from each integration
# 2018-04-17 11:45:57,217 - stpipe.Detector1Pipeline.refpix - INFO - Adding initial read back in
# 2018-04-17 11:45:58,622 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix done
# 2018-04-17 11:45:58,748 - stpipe.Detector1Pipeline.jump - INFO - Step jump running with args (<jwst.datamodels.ramp.RampModel object at 0x1818c27550>,).
# 2018-04-17 11:45:58,791 - stpipe.Detector1Pipeline.jump - INFO - CR rejection threshold = 4 sigma
# 2018-04-17 11:45:58,799 - stpipe.Detector1Pipeline.jump - INFO - Using GAIN reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_gain_0007.fits
# 2018-04-17 11:45:58,855 - stpipe.Detector1Pipeline.jump - INFO - Using READNOISE reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_readnoise_0034.fits
# 2018-04-17 11:46:00,043 - stpipe.Detector1Pipeline.jump - INFO - Executing two-point difference method
# 2018-04-17 11:46:00,678 - stpipe.Detector1Pipeline.jump - INFO -  working on integration 1
# 2018-04-17 11:46:04,586 - stpipe.Detector1Pipeline.jump - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/jump/twopoint_difference.py:83: RuntimeWarning: invalid value encountered in sqrt
#   poisson_noise = np.sqrt(np.abs(med_diffs))
#
# 2018-04-17 11:46:19,046 - stpipe.Detector1Pipeline.jump - INFO -  working on integration 2
# 2018-04-17 11:46:37,187 - stpipe.Detector1Pipeline.jump - INFO - Step jump done
# 2018-04-17 11:46:37,273 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit running with args (<jwst.datamodels.ramp.RampModel object at 0x1134efd68>,).
# 2018-04-17 11:46:37,322 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using READNOISE reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_readnoise_0034.fits
# 2018-04-17 11:46:37,465 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using GAIN reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_gain_0007.fits
# 2018-04-17 11:46:37,503 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using algorithm = ols
# 2018-04-17 11:46:37,504 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using weighting = optimal
# 2018-04-17 11:46:37,510 - stpipe.Detector1Pipeline.ramp_fit - INFO - MIRI dataset has all final reads flagged as DO_NOT_USE.
# 2018-04-17 11:46:37,535 - stpipe.Detector1Pipeline.ramp_fit - INFO - Effective integration time per group: 2.77504
# 2018-04-17 11:48:20,623 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/utils.py:475: RuntimeWarning: invalid value encountered in true_divide
#   var_poisson = sum_p / (sum_wgt_p * nsegs_pix)
#
# 2018-04-17 11:48:29,329 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/utils.py:481: RuntimeWarning: divide by zero encountered in true_divide
#   var_r = rn_1d**2 * 12./(segments**3. - segments)
#
# 2018-04-17 11:48:30,184 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/utils.py:485: RuntimeWarning: divide by zero encountered in true_divide
#   sum_r = (segments*var_r[:]/((nsegs_pix)**3.)).sum(axis=0)
#
# 2018-04-17 11:48:30,186 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/utils.py:485: RuntimeWarning: invalid value encountered in true_divide
#   sum_r = (segments*var_r[:]/((nsegs_pix)**3.)).sum(axis=0)
#
# 2018-04-17 11:48:30,331 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/utils.py:489: RuntimeWarning: divide by zero encountered in true_divide
#   var_readnoise = sum_r/nsegs_pix
#
# 2018-04-17 11:48:30,332 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/utils.py:489: RuntimeWarning: invalid value encountered in true_divide
#   var_readnoise = sum_r/nsegs_pix
#
# 2018-04-17 11:50:12,349 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/utils.py:475: RuntimeWarning: divide by zero encountered in true_divide
#   var_poisson = sum_p / (sum_wgt_p * nsegs_pix)
#
# 2018-04-17 11:50:21,880 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/ramp_fit.py:324: RuntimeWarning: invalid value encountered in sqrt
#   err_2d_all = np.sqrt( var_p_2d_all + var_r_2d_all )
#
# 2018-04-17 11:51:29,585 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/utils.py:620: RuntimeWarning: invalid value encountered in sqrt
#   cubemod.err = np.sqrt(var_p_int + var_r_int)
#
# 2018-04-17 11:51:29,619 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of groups per integration: 50
# 2018-04-17 11:51:29,619 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of integrations: 2
# 2018-04-17 11:51:30,016 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit done
# 2018-04-17 11:51:30,220 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<jwst.datamodels.ifuimage.IFUImageModel object at 0x1134771d0>,).
# 2018-04-17 11:51:30,301 - stpipe.Detector1Pipeline.gain_scale - INFO - GAINFACT not found in gain reference file
# 2018-04-17 11:51:30,302 - stpipe.Detector1Pipeline.gain_scale - INFO - Step will be skipped
# 2018-04-17 11:51:30,305 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# 2018-04-17 11:51:30,387 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<jwst.datamodels.cube.CubeModel object at 0x1818d62898>,).
# 2018-04-17 11:51:30,471 - stpipe.Detector1Pipeline.gain_scale - INFO - GAINFACT not found in gain reference file
# 2018-04-17 11:51:30,472 - stpipe.Detector1Pipeline.gain_scale - INFO - Step will be skipped
# 2018-04-17 11:51:30,476 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# 2018-04-17 11:51:30,635 - stpipe.Detector1Pipeline - INFO - Saved model in MRS_demo_data_pipelined/det_image_seq1_MIRIFUSHORT_12SHORTexp1_rateints.fits
# 2018-04-17 11:51:30,636 - stpipe.Detector1Pipeline - INFO - ... ending calwebb_detector1
# 2018-04-17 11:51:30,766 - stpipe.Detector1Pipeline - INFO - Saved model in MRS_demo_data_pipelined/det_image_seq1_MIRIFUSHORT_12SHORTexp1_rate.fits
# 2018-04-17 11:51:30,767 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline done
# 2018-04-17 11:51:30,781 - stpipe.Detector1Pipeline - INFO - Detector1Pipeline instance created.
# 2018-04-17 11:51:30,783 - stpipe.Detector1Pipeline.lastframe - INFO - LastFrameStep instance created.
# 2018-04-17 11:51:30,785 - stpipe.Detector1Pipeline.dark_current - INFO - DarkCurrentStep instance created.
# 2018-04-17 11:51:30,787 - stpipe.Detector1Pipeline.refpix - INFO - RefPixStep instance created.
# 2018-04-17 11:51:30,788 - stpipe.Detector1Pipeline.linearity - INFO - LinearityStep instance created.
# 2018-04-17 11:51:30,790 - stpipe.Detector1Pipeline.jump - INFO - JumpStep instance created.
# 2018-04-17 11:51:30,792 - stpipe.Detector1Pipeline.firstframe - INFO - FirstFrameStep instance created.
# 2018-04-17 11:51:30,794 - stpipe.Detector1Pipeline.ramp_fit - INFO - RampFitStep instance created.
# 2018-04-17 11:51:30,796 - stpipe.Detector1Pipeline.gain_scale - INFO - GainScaleStep instance created.
# 2018-04-17 11:51:30,797 - stpipe.Detector1Pipeline.saturation - INFO - SaturationStep instance created.
# 2018-04-17 11:51:30,799 - stpipe.Detector1Pipeline.superbias - INFO - SuperBiasStep instance created.
# 2018-04-17 11:51:30,801 - stpipe.Detector1Pipeline.dq_init - INFO - DQInitStep instance created.
# 2018-04-17 11:51:30,803 - stpipe.Detector1Pipeline.group_scale - INFO - GroupScaleStep instance created.
# 2018-04-17 11:51:30,805 - stpipe.Detector1Pipeline.persistence - INFO - PersistenceStep instance created.
# 2018-04-17 11:51:30,806 - stpipe.Detector1Pipeline.rscd - INFO - RSCD_Step instance created.
# 2018-04-17 11:51:30,808 - stpipe.Detector1Pipeline.ipc - INFO - IPCStep instance created.
# 2018-04-17 11:51:31,417 - stpipe.Detector1Pipeline - INFO - Prefetch for DARK reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_dark_0056.fits'.
# 2018-04-17 11:51:31,418 - stpipe.Detector1Pipeline - INFO - Prefetch for GAIN reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_gain_0007.fits'.
# 2018-04-17 11:51:31,419 - stpipe.Detector1Pipeline - INFO - Prefetch for LINEARITY reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_linearity_0023.fits'.
# 2018-04-17 11:51:31,420 - stpipe.Detector1Pipeline - INFO - Prefetch for MASK reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_mask_0020.fits'.
# 2018-04-17 11:51:31,421 - stpipe.Detector1Pipeline - INFO - Prefetch for PERSAT reference file is 'N/A'.
# 2018-04-17 11:51:31,421 - stpipe.Detector1Pipeline - INFO - Prefetch for READNOISE reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_readnoise_0034.fits'.
# 2018-04-17 11:51:31,422 - stpipe.Detector1Pipeline - INFO - Prefetch for REFPIX reference file is 'N/A'.
# 2018-04-17 11:51:31,423 - stpipe.Detector1Pipeline - INFO - Prefetch for RSCD reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_rscd_0002.fits'.
# 2018-04-17 11:51:31,424 - stpipe.Detector1Pipeline - INFO - Prefetch for SATURATION reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_saturation_0020.fits'.
# 2018-04-17 11:51:31,425 - stpipe.Detector1Pipeline - INFO - Prefetch for SUPERBIAS reference file is 'N/A'.
# 2018-04-17 11:51:31,426 - stpipe.Detector1Pipeline - INFO - Prefetch for TRAPDENSITY reference file is 'N/A'.
# 2018-04-17 11:51:31,426 - stpipe.Detector1Pipeline - INFO - Prefetch for TRAPPARS reference file is 'N/A'.
# 2018-04-17 11:51:31,427 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline running with args ('MRS_demo_data/det_image_seq4_MIRIFUSHORT_12SHORTexp1.fits',).
# 2018-04-17 11:51:31,428 - stpipe.Detector1Pipeline - INFO - Starting calwebb_detector1 ...
# 2018-04-17 11:51:31,841 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale running with args (<jwst.datamodels.ramp.RampModel object at 0x1135290f0>,).
# 2018-04-17 11:51:31,881 - stpipe.Detector1Pipeline.group_scale - WARNING - NFRAMES=1 is a power of 2
# 2018-04-17 11:51:31,882 - stpipe.Detector1Pipeline.group_scale - WARNING - Step will be skipped
# 2018-04-17 11:51:31,884 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale done
# 2018-04-17 11:51:31,960 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init running with args (<jwst.datamodels.ramp.RampModel object at 0x1818c3e2e8>,).
# 2018-04-17 11:51:32,001 - stpipe.Detector1Pipeline.dq_init - INFO - Using MASK reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_mask_0020.fits
# 2018-04-17 11:51:36,185 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init done
# 2018-04-17 11:51:36,302 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation running with args (<jwst.datamodels.ramp.RampModel object at 0x1137b56a0>,).
# 2018-04-17 11:51:36,341 - stpipe.Detector1Pipeline.saturation - INFO - Using SATURATION reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_saturation_0020.fits
# 2018-04-17 11:51:38,027 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation done
# 2018-04-17 11:51:38,173 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc running with args (<jwst.datamodels.ramp.RampModel object at 0x1818a573c8>,).
# 2018-04-17 11:51:38,175 - stpipe.Detector1Pipeline.ipc - INFO - Step skipped.
# 2018-04-17 11:51:38,178 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc done
# 2018-04-17 11:51:38,274 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity running with args (<jwst.datamodels.ramp.RampModel object at 0x1818a573c8>,).
# 2018-04-17 11:51:38,315 - stpipe.Detector1Pipeline.linearity - INFO - Using Linearity reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_linearity_0023.fits
# 2018-04-17 11:51:40,734 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity done
# 2018-04-17 11:51:40,799 - stpipe.Detector1Pipeline.rscd - INFO - Step rscd running with args (<jwst.datamodels.ramp.RampModel object at 0x1136c69e8>,).
# 2018-04-17 11:51:40,843 - stpipe.Detector1Pipeline.rscd - INFO - Using RSCD reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_rscd_0002.fits
# 2018-04-17 11:52:28,671 - stpipe.Detector1Pipeline.rscd - INFO - Step rscd done
# 2018-04-17 11:52:28,742 - stpipe.Detector1Pipeline.firstframe - INFO - Step firstframe running with args (<jwst.datamodels.ramp.RampModel object at 0x11345c198>,).
# 2018-04-17 11:52:29,546 - stpipe.Detector1Pipeline.firstframe - INFO - Step firstframe done
# 2018-04-17 11:52:29,629 - stpipe.Detector1Pipeline.lastframe - INFO - Step lastframe running with args (<jwst.datamodels.ramp.RampModel object at 0x1818d4eba8>,).
# 2018-04-17 11:52:30,437 - stpipe.Detector1Pipeline.lastframe - INFO - Step lastframe done
# 2018-04-17 11:52:30,520 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current running with args (<jwst.datamodels.ramp.RampModel object at 0x1818d27668>,).
# 2018-04-17 11:52:30,558 - stpipe.Detector1Pipeline.dark_current - INFO - Using DARK reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_dark_0056.fits
# 2018-04-17 11:52:30,780 - stpipe.Detector1Pipeline.dark_current - INFO - Science data nints=2, ngroups=50, nframes=1, groupgap=0
# 2018-04-17 11:52:30,781 - stpipe.Detector1Pipeline.dark_current - INFO - Dark data nints=2, ngroups=200, nframes=1, groupgap=0
# 2018-04-17 11:52:40,191 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current done
# 2018-04-17 11:52:40,316 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix running with args (<jwst.datamodels.ramp.RampModel object at 0x1818c3e8d0>,).
# 2018-04-17 11:52:40,426 - stpipe.Detector1Pipeline.refpix - INFO - use_side_ref_pixels = True
# 2018-04-17 11:52:40,427 - stpipe.Detector1Pipeline.refpix - INFO - odd_even_columns = True
# 2018-04-17 11:52:40,428 - stpipe.Detector1Pipeline.refpix - INFO - side_smoothing_length = 11
# 2018-04-17 11:52:40,429 - stpipe.Detector1Pipeline.refpix - INFO - side_gain = 1.000000
# 2018-04-17 11:52:40,429 - stpipe.Detector1Pipeline.refpix - INFO - odd_even_rows = True
# 2018-04-17 11:52:41,144 - stpipe.Detector1Pipeline.refpix - INFO - Subtracting initial read from each integration
# 2018-04-17 11:52:42,775 - stpipe.Detector1Pipeline.refpix - INFO - Adding initial read back in
# 2018-04-17 11:52:43,950 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix done
# 2018-04-17 11:52:44,033 - stpipe.Detector1Pipeline.jump - INFO - Step jump running with args (<jwst.datamodels.ramp.RampModel object at 0x181aa91320>,).
# 2018-04-17 11:52:44,068 - stpipe.Detector1Pipeline.jump - INFO - CR rejection threshold = 4 sigma
# 2018-04-17 11:52:44,074 - stpipe.Detector1Pipeline.jump - INFO - Using GAIN reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_gain_0007.fits
# 2018-04-17 11:52:44,132 - stpipe.Detector1Pipeline.jump - INFO - Using READNOISE reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_readnoise_0034.fits
# 2018-04-17 11:52:45,538 - stpipe.Detector1Pipeline.jump - INFO - Executing two-point difference method
# 2018-04-17 11:52:46,189 - stpipe.Detector1Pipeline.jump - INFO -  working on integration 1
# 2018-04-17 11:52:50,237 - stpipe.Detector1Pipeline.jump - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/jump/twopoint_difference.py:83: RuntimeWarning: invalid value encountered in sqrt
#   poisson_noise = np.sqrt(np.abs(med_diffs))
#
# 2018-04-17 11:53:04,518 - stpipe.Detector1Pipeline.jump - INFO -  working on integration 2
# 2018-04-17 11:53:23,209 - stpipe.Detector1Pipeline.jump - INFO - Step jump done
# 2018-04-17 11:53:23,294 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit running with args (<jwst.datamodels.ramp.RampModel object at 0x1818d4e0f0>,).
# 2018-04-17 11:53:23,340 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using READNOISE reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_readnoise_0034.fits
# 2018-04-17 11:53:23,495 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using GAIN reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_gain_0007.fits
# 2018-04-17 11:53:23,533 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using algorithm = ols
# 2018-04-17 11:53:23,534 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using weighting = optimal
# 2018-04-17 11:53:23,539 - stpipe.Detector1Pipeline.ramp_fit - INFO - MIRI dataset has all final reads flagged as DO_NOT_USE.
# 2018-04-17 11:53:23,561 - stpipe.Detector1Pipeline.ramp_fit - INFO - Effective integration time per group: 2.77504
# 2018-04-17 11:55:15,588 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/utils.py:475: RuntimeWarning: divide by zero encountered in true_divide
#   var_poisson = sum_p / (sum_wgt_p * nsegs_pix)
#
# 2018-04-17 11:55:15,589 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/utils.py:475: RuntimeWarning: invalid value encountered in true_divide
#   var_poisson = sum_p / (sum_wgt_p * nsegs_pix)
# 2018-04-17 11:55:25,034 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/utils.py:481: RuntimeWarning: divide by zero encountered in true_divide
#   var_r = rn_1d**2 * 12./(segments**3. - segments)
#
# 2018-04-17 11:55:25,707 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/utils.py:485: RuntimeWarning: divide by zero encountered in true_divide
#   sum_r = (segments*var_r[:]/((nsegs_pix)**3.)).sum(axis=0)
#
# 2018-04-17 11:55:25,709 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/utils.py:485: RuntimeWarning: invalid value encountered in true_divide
#   sum_r = (segments*var_r[:]/((nsegs_pix)**3.)).sum(axis=0)
#
# 2018-04-17 11:55:25,844 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/utils.py:489: RuntimeWarning: divide by zero encountered in true_divide
#   var_readnoise = sum_r/nsegs_pix
#
# 2018-04-17 11:55:25,845 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/utils.py:489: RuntimeWarning: invalid value encountered in true_divide
#   var_readnoise = sum_r/nsegs_pix
#
# 2018-04-17 11:57:28,727 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/ramp_fit.py:324: RuntimeWarning: invalid value encountered in sqrt
#   err_2d_all = np.sqrt( var_p_2d_all + var_r_2d_all )
#
# 2018-04-17 11:58:35,604 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/utils.py:620: RuntimeWarning: invalid value encountered in sqrt
#   cubemod.err = np.sqrt(var_p_int + var_r_int)
#
# 2018-04-17 11:58:35,733 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of groups per integration: 50
# 2018-04-17 11:58:35,734 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of integrations: 2
# 2018-04-17 11:58:36,167 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit done
# 2018-04-17 11:58:36,521 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<jwst.datamodels.ifuimage.IFUImageModel object at 0x113460208>,).
# 2018-04-17 11:58:36,613 - stpipe.Detector1Pipeline.gain_scale - INFO - GAINFACT not found in gain reference file
# 2018-04-17 11:58:36,614 - stpipe.Detector1Pipeline.gain_scale - INFO - Step will be skipped
# 2018-04-17 11:58:36,619 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# 2018-04-17 11:58:36,687 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<jwst.datamodels.cube.CubeModel object at 0x1818b62160>,).
# 2018-04-17 11:58:36,760 - stpipe.Detector1Pipeline.gain_scale - INFO - GAINFACT not found in gain reference file
# 2018-04-17 11:58:36,761 - stpipe.Detector1Pipeline.gain_scale - INFO - Step will be skipped
# 2018-04-17 11:58:36,764 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# 2018-04-17 11:58:36,902 - stpipe.Detector1Pipeline - INFO - Saved model in MRS_demo_data_pipelined/det_image_seq4_MIRIFUSHORT_12SHORTexp1_rateints.fits
# 2018-04-17 11:58:36,903 - stpipe.Detector1Pipeline - INFO - ... ending calwebb_detector1
# 2018-04-17 11:58:37,017 - stpipe.Detector1Pipeline - INFO - Saved model in MRS_demo_data_pipelined/det_image_seq4_MIRIFUSHORT_12SHORTexp1_rate.fits
# 2018-04-17 11:58:37,018 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline done
# 2018-04-17 11:58:37,032 - stpipe.Detector1Pipeline - INFO - Detector1Pipeline instance created.
# 2018-04-17 11:58:37,034 - stpipe.Detector1Pipeline.lastframe - INFO - LastFrameStep instance created.
# 2018-04-17 11:58:37,035 - stpipe.Detector1Pipeline.dark_current - INFO - DarkCurrentStep instance created.
# 2018-04-17 11:58:37,038 - stpipe.Detector1Pipeline.refpix - INFO - RefPixStep instance created.
# 2018-04-17 11:58:37,040 - stpipe.Detector1Pipeline.linearity - INFO - LinearityStep instance created.
# 2018-04-17 11:58:37,042 - stpipe.Detector1Pipeline.jump - INFO - JumpStep instance created.
# 2018-04-17 11:58:37,044 - stpipe.Detector1Pipeline.firstframe - INFO - FirstFrameStep instance created.
# 2018-04-17 11:58:37,047 - stpipe.Detector1Pipeline.ramp_fit - INFO - RampFitStep instance created.
# 2018-04-17 11:58:37,048 - stpipe.Detector1Pipeline.gain_scale - INFO - GainScaleStep instance created.
# 2018-04-17 11:58:37,051 - stpipe.Detector1Pipeline.saturation - INFO - SaturationStep instance created.
# 2018-04-17 11:58:37,053 - stpipe.Detector1Pipeline.superbias - INFO - SuperBiasStep instance created.
# 2018-04-17 11:58:37,054 - stpipe.Detector1Pipeline.dq_init - INFO - DQInitStep instance created.
# 2018-04-17 11:58:37,056 - stpipe.Detector1Pipeline.group_scale - INFO - GroupScaleStep instance created.
# 2018-04-17 11:58:37,058 - stpipe.Detector1Pipeline.persistence - INFO - PersistenceStep instance created.
# 2018-04-17 11:58:37,061 - stpipe.Detector1Pipeline.rscd - INFO - RSCD_Step instance created.
# 2018-04-17 11:58:37,063 - stpipe.Detector1Pipeline.ipc - INFO - IPCStep instance created.
# 2018-04-17 11:58:37,416 - stpipe.Detector1Pipeline - INFO - Prefetch for DARK reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_dark_0056.fits'.
# 2018-04-17 11:58:37,417 - stpipe.Detector1Pipeline - INFO - Prefetch for GAIN reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_gain_0007.fits'.
# 2018-04-17 11:58:37,418 - stpipe.Detector1Pipeline - INFO - Prefetch for LINEARITY reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_linearity_0023.fits'.
# 2018-04-17 11:58:37,419 - stpipe.Detector1Pipeline - INFO - Prefetch for MASK reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_mask_0020.fits'.
# 2018-04-17 11:58:37,420 - stpipe.Detector1Pipeline - INFO - Prefetch for PERSAT reference file is 'N/A'.
# 2018-04-17 11:58:37,420 - stpipe.Detector1Pipeline - INFO - Prefetch for READNOISE reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_readnoise_0034.fits'.
# 2018-04-17 11:58:37,421 - stpipe.Detector1Pipeline - INFO - Prefetch for REFPIX reference file is 'N/A'.
# 2018-04-17 11:58:37,422 - stpipe.Detector1Pipeline - INFO - Prefetch for RSCD reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_rscd_0002.fits'.
# 2018-04-17 11:58:37,423 - stpipe.Detector1Pipeline - INFO - Prefetch for SATURATION reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_saturation_0020.fits'.
# 2018-04-17 11:58:37,424 - stpipe.Detector1Pipeline - INFO - Prefetch for SUPERBIAS reference file is 'N/A'.
# 2018-04-17 11:58:37,425 - stpipe.Detector1Pipeline - INFO - Prefetch for TRAPDENSITY reference file is 'N/A'.
# 2018-04-17 11:58:37,426 - stpipe.Detector1Pipeline - INFO - Prefetch for TRAPPARS reference file is 'N/A'.
# 2018-04-17 11:58:37,426 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline running with args ('MRS_demo_data/det_image_seq3_MIRIFUSHORT_12SHORTexp1.fits',).
# 2018-04-17 11:58:37,427 - stpipe.Detector1Pipeline - INFO - Starting calwebb_detector1 ...
# 2018-04-17 11:58:37,797 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale running with args (<jwst.datamodels.ramp.RampModel object at 0x1134e14a8>,).
# 2018-04-17 11:58:37,830 - stpipe.Detector1Pipeline.group_scale - WARNING - NFRAMES=1 is a power of 2
# 2018-04-17 11:58:37,831 - stpipe.Detector1Pipeline.group_scale - WARNING - Step will be skipped
# 2018-04-17 11:58:37,833 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale done
# 2018-04-17 11:58:37,906 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init running with args (<jwst.datamodels.ramp.RampModel object at 0x1137b1ef0>,).
# 2018-04-17 11:58:37,945 - stpipe.Detector1Pipeline.dq_init - INFO - Using MASK reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_mask_0020.fits
# 2018-04-17 11:58:40,908 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init done
# 2018-04-17 11:58:41,017 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation running with args (<jwst.datamodels.ramp.RampModel object at 0x1818c19b38>,).
# 2018-04-17 11:58:41,056 - stpipe.Detector1Pipeline.saturation - INFO - Using SATURATION reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_saturation_0020.fits
# 2018-04-17 11:58:42,395 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation done
# 2018-04-17 11:58:42,474 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc running with args (<jwst.datamodels.ramp.RampModel object at 0x1818d2f978>,).
# 2018-04-17 11:58:42,475 - stpipe.Detector1Pipeline.ipc - INFO - Step skipped.
# 2018-04-17 11:58:42,478 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc done
# 2018-04-17 11:58:42,553 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity running with args (<jwst.datamodels.ramp.RampModel object at 0x1818d2f978>,).
# 2018-04-17 11:58:42,595 - stpipe.Detector1Pipeline.linearity - INFO - Using Linearity reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_linearity_0023.fits
# 2018-04-17 11:58:44,709 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity done
# 2018-04-17 11:58:44,778 - stpipe.Detector1Pipeline.rscd - INFO - Step rscd running with args (<jwst.datamodels.ramp.RampModel object at 0x1818d4d9e8>,).
# 2018-04-17 11:58:44,817 - stpipe.Detector1Pipeline.rscd - INFO - Using RSCD reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_rscd_0002.fits
# 2018-04-17 11:59:32,779 - stpipe.Detector1Pipeline.rscd - INFO - Step rscd done
# 2018-04-17 11:59:32,857 - stpipe.Detector1Pipeline.firstframe - INFO - Step firstframe running with args (<jwst.datamodels.ramp.RampModel object at 0x1818c22320>,).
# 2018-04-17 11:59:33,752 - stpipe.Detector1Pipeline.firstframe - INFO - Step firstframe done
# 2018-04-17 11:59:33,833 - stpipe.Detector1Pipeline.lastframe - INFO - Step lastframe running with args (<jwst.datamodels.ramp.RampModel object at 0x113533940>,).
# 2018-04-17 11:59:34,774 - stpipe.Detector1Pipeline.lastframe - INFO - Step lastframe done
# 2018-04-17 11:59:34,882 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current running with args (<jwst.datamodels.ramp.RampModel object at 0x11382d4e0>,).
# 2018-04-17 11:59:34,928 - stpipe.Detector1Pipeline.dark_current - INFO - Using DARK reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_dark_0056.fits
# 2018-04-17 11:59:35,156 - stpipe.Detector1Pipeline.dark_current - INFO - Science data nints=2, ngroups=50, nframes=1, groupgap=0
# 2018-04-17 11:59:35,157 - stpipe.Detector1Pipeline.dark_current - INFO - Dark data nints=2, ngroups=200, nframes=1, groupgap=0
# 2018-04-17 11:59:37,610 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current done
# 2018-04-17 11:59:37,761 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix running with args (<jwst.datamodels.ramp.RampModel object at 0x113834630>,).
# 2018-04-17 11:59:37,878 - stpipe.Detector1Pipeline.refpix - INFO - use_side_ref_pixels = True
# 2018-04-17 11:59:37,880 - stpipe.Detector1Pipeline.refpix - INFO - odd_even_columns = True
# 2018-04-17 11:59:37,881 - stpipe.Detector1Pipeline.refpix - INFO - side_smoothing_length = 11
# 2018-04-17 11:59:37,882 - stpipe.Detector1Pipeline.refpix - INFO - side_gain = 1.000000
# 2018-04-17 11:59:37,882 - stpipe.Detector1Pipeline.refpix - INFO - odd_even_rows = True
# 2018-04-17 11:59:38,839 - stpipe.Detector1Pipeline.refpix - INFO - Subtracting initial read from each integration
# 2018-04-17 11:59:41,179 - stpipe.Detector1Pipeline.refpix - INFO - Adding initial read back in
# 2018-04-17 11:59:42,440 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix done
# 2018-04-17 11:59:42,527 - stpipe.Detector1Pipeline.jump - INFO - Step jump running with args (<jwst.datamodels.ramp.RampModel object at 0x181abbda58>,).
# 2018-04-17 11:59:42,563 - stpipe.Detector1Pipeline.jump - INFO - CR rejection threshold = 4 sigma
# 2018-04-17 11:59:42,570 - stpipe.Detector1Pipeline.jump - INFO - Using GAIN reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_gain_0007.fits
# 2018-04-17 11:59:42,615 - stpipe.Detector1Pipeline.jump - INFO - Using READNOISE reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_readnoise_0034.fits
# 2018-04-17 11:59:44,457 - stpipe.Detector1Pipeline.jump - INFO - Executing two-point difference method
# 2018-04-17 11:59:45,140 - stpipe.Detector1Pipeline.jump - INFO -  working on integration 1
# 2018-04-17 11:59:48,741 - stpipe.Detector1Pipeline.jump - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/jump/twopoint_difference.py:83: RuntimeWarning: invalid value encountered in sqrt
#   poisson_noise = np.sqrt(np.abs(med_diffs))
#
# 2018-04-17 12:00:04,565 - stpipe.Detector1Pipeline.jump - INFO -  working on integration 2
# 2018-04-17 12:00:22,370 - stpipe.Detector1Pipeline.jump - INFO - Step jump done
# 2018-04-17 12:00:22,450 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit running with args (<jwst.datamodels.ramp.RampModel object at 0x113472a90>,).
# 2018-04-17 12:00:22,499 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using READNOISE reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_readnoise_0034.fits
# 2018-04-17 12:00:22,666 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using GAIN reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_gain_0007.fits
# 2018-04-17 12:00:22,700 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using algorithm = ols
# 2018-04-17 12:00:22,701 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using weighting = optimal
# 2018-04-17 12:00:22,706 - stpipe.Detector1Pipeline.ramp_fit - INFO - MIRI dataset has all final reads flagged as DO_NOT_USE.
# 2018-04-17 12:00:22,722 - stpipe.Detector1Pipeline.ramp_fit - INFO - Effective integration time per group: 2.77504
# 2018-04-17 12:02:07,363 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/utils.py:475: RuntimeWarning: invalid value encountered in true_divide
#   var_poisson = sum_p / (sum_wgt_p * nsegs_pix)
#
# 2018-04-17 12:02:15,958 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/utils.py:481: RuntimeWarning: divide by zero encountered in true_divide
#   var_r = rn_1d**2 * 12./(segments**3. - segments)
#
# 2018-04-17 12:02:16,614 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/utils.py:485: RuntimeWarning: divide by zero encountered in true_divide
#   sum_r = (segments*var_r[:]/((nsegs_pix)**3.)).sum(axis=0)
#
# 2018-04-17 12:02:16,615 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/utils.py:485: RuntimeWarning: invalid value encountered in true_divide
#   sum_r = (segments*var_r[:]/((nsegs_pix)**3.)).sum(axis=0)
#
# 2018-04-17 12:02:16,784 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/utils.py:489: RuntimeWarning: divide by zero encountered in true_divide
#   var_readnoise = sum_r/nsegs_pix
#
# 2018-04-17 12:02:16,786 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/utils.py:489: RuntimeWarning: invalid value encountered in true_divide
#   var_readnoise = sum_r/nsegs_pix
#
# 2018-04-17 12:04:12,723 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/ramp_fit.py:324: RuntimeWarning: invalid value encountered in sqrt
#   err_2d_all = np.sqrt( var_p_2d_all + var_r_2d_all )
# 2018-04-17 12:05:23,678 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/utils.py:620: RuntimeWarning: invalid value encountered in sqrt
#   cubemod.err = np.sqrt(var_p_int + var_r_int)
#
# 2018-04-17 12:05:23,716 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of groups per integration: 50
# 2018-04-17 12:05:23,717 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of integrations: 2
# 2018-04-17 12:05:24,175 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit done
# 2018-04-17 12:05:24,373 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<jwst.datamodels.ifuimage.IFUImageModel object at 0x11362fa20>,).
# 2018-04-17 12:05:24,450 - stpipe.Detector1Pipeline.gain_scale - INFO - GAINFACT not found in gain reference file
# 2018-04-17 12:05:24,450 - stpipe.Detector1Pipeline.gain_scale - INFO - Step will be skipped
# 2018-04-17 12:05:24,453 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# 2018-04-17 12:05:24,557 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<jwst.datamodels.cube.CubeModel object at 0x1818d715f8>,).
# 2018-04-17 12:05:24,638 - stpipe.Detector1Pipeline.gain_scale - INFO - GAINFACT not found in gain reference file
# 2018-04-17 12:05:24,639 - stpipe.Detector1Pipeline.gain_scale - INFO - Step will be skipped
# 2018-04-17 12:05:24,643 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# 2018-04-17 12:05:24,797 - stpipe.Detector1Pipeline - INFO - Saved model in MRS_demo_data_pipelined/det_image_seq3_MIRIFUSHORT_12SHORTexp1_rateints.fits
# 2018-04-17 12:05:24,798 - stpipe.Detector1Pipeline - INFO - ... ending calwebb_detector1
# 2018-04-17 12:05:24,945 - stpipe.Detector1Pipeline - INFO - Saved model in MRS_demo_data_pipelined/det_image_seq3_MIRIFUSHORT_12SHORTexp1_rate.fits
# 2018-04-17 12:05:24,946 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline done

# %% [markdown]
# #### Quick check of the pipeline steps applied in the output. We'll look at the first dither:

# %%
level2A_files = glob.glob(os.path.join(output_dir,'*_rate.fits'))

with datamodels.open(level2A_files[0]) as dm:
    # check the calibration step information
    print('Check step information status:')
    print('dq_init: %s' % dm.meta.cal_step.dq_init)
    print('saturation: %s' % dm.meta.cal_step.saturation)
    print('ipc: %s' % dm.meta.cal_step.ipc)
    print('linearity: %s' % dm.meta.cal_step.linearity)
    print('rscd: %s' % dm.meta.cal_step.rscd)
    print('firstframe: %s' % dm.meta.cal_step.firstframe)
    print('lastframe: %s' % dm.meta.cal_step.lastframe)
    print('dark_current: %s' % dm.meta.cal_step.dark_sub)
    print('refpix: %s' % dm.meta.cal_step.refpix)
    print('jump: %s' % dm.meta.cal_step.jump)
    print('ramp_fit: %s' % dm.meta.cal_step.ramp_fit)
# Out:
# Check step information status:
# dq_init: COMPLETE
# saturation: COMPLETE
# ipc: None
# linearity: COMPLETE
# rscd: COMPLETE
# firstframe: COMPLETE
# lastframe: COMPLETE
# dark_current: COMPLETE
# refpix: COMPLETE
# jump: COMPLETE
# ramp_fit: COMPLETE

# %% [markdown]
# ### Level 2B pipeline

# %% [markdown]
# #### import the level 2B pipeline class and print description

# %%
from jwst.pipeline import Spec2Pipeline
print(Spec2Pipeline.__doc__)
# Out:
#     Spec2Pipeline: Processes JWST spectroscopic exposures from Level 2a to 2b.
#     Accepts a single exposure or an association as input.
#
#     Included steps are:
#     assign_wcs, background subtraction, NIRSpec MSA imprint subtraction,
#     NIRSpec MSA bad shutter flagging, 2-D subwindow extraction, flat field,
#     source type decision, straylight, fringe, pathloss, barshadow,  photom,
#     resample_spec, cube_build, and extract_1d.

# %% [markdown]
# #### run pipeline
# We pass the level 2A files. The output level 2B files will be saved in the output_dir as '*_cal.fits'.
#
# Note that since MIRISim does not add straylight, we can skip the straylight correction step.

# %%
for f in level2A_files:
    Spec2Pipeline.call(f, output_use_model=True, save_results=True, output_dir=output_dir, 
                       steps={'straylight':{'skip':True}})
# Out:
# 2018-04-17 12:05:25,226 - stpipe.Spec2Pipeline - INFO - Spec2Pipeline instance created.
# 2018-04-17 12:05:25,229 - stpipe.Spec2Pipeline.straylight - INFO - StraylightStep instance created.
# 2018-04-17 12:05:25,230 - stpipe.Spec2Pipeline.imprint_subtract - INFO - ImprintStep instance created.
# 2018-04-17 12:05:25,232 - stpipe.Spec2Pipeline.flat_field - INFO - FlatFieldStep instance created.
# 2018-04-17 12:05:25,234 - stpipe.Spec2Pipeline.extract_1d - INFO - Extract1dStep instance created.
# 2018-04-17 12:05:25,236 - stpipe.Spec2Pipeline.msa_flagging - INFO - MSAFlagOpenStep instance created.
# 2018-04-17 12:05:25,237 - stpipe.Spec2Pipeline.srctype - INFO - SourceTypeStep instance created.
# 2018-04-17 12:05:25,239 - stpipe.Spec2Pipeline.pathloss - INFO - PathLossStep instance created.
# 2018-04-17 12:05:25,242 - stpipe.Spec2Pipeline.resample_spec - INFO - ResampleSpecStep instance created.
# 2018-04-17 12:05:25,245 - stpipe.Spec2Pipeline.assign_wcs - INFO - AssignWcsStep instance created.
# 2018-04-17 12:05:25,248 - stpipe.Spec2Pipeline.cube_build - INFO - CubeBuildStep instance created.
# 2018-04-17 12:05:25,250 - stpipe.Spec2Pipeline.bkg_subtract - INFO - BackgroundStep instance created.
# 2018-04-17 12:05:25,251 - stpipe.Spec2Pipeline.photom - INFO - PhotomStep instance created.
# 2018-04-17 12:05:25,254 - stpipe.Spec2Pipeline.barshadow - INFO - BarShadowStep instance created.
# 2018-04-17 12:05:25,256 - stpipe.Spec2Pipeline.fringe - INFO - FringeStep instance created.
# 2018-04-17 12:05:25,258 - stpipe.Spec2Pipeline.extract_2d - INFO - Extract2dStep instance created.
# 2018-04-17 12:05:25,588 - stpipe.Spec2Pipeline - INFO - Prefetch for AREA reference file is 'N/A'.
# 2018-04-17 12:05:25,590 - stpipe.Spec2Pipeline - INFO - Prefetch for BARSHADOW reference file is 'N/A'.
# 2018-04-17 12:05:25,591 - stpipe.Spec2Pipeline - INFO - Prefetch for CAMERA reference file is 'N/A'.
# 2018-04-17 12:05:25,592 - stpipe.Spec2Pipeline - INFO - Prefetch for COLLIMATOR reference file is 'N/A'.
# 2018-04-17 12:05:25,593 - stpipe.Spec2Pipeline - INFO - Prefetch for CUBEPAR reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_cubepar_0002.fits'.
# 2018-04-17 12:05:25,595 - stpipe.Spec2Pipeline - INFO - Prefetch for DFLAT reference file is 'N/A'.
# 2018-04-17 12:05:25,596 - stpipe.Spec2Pipeline - INFO - Prefetch for DISPERSER reference file is 'N/A'.
# 2018-04-17 12:05:25,597 - stpipe.Spec2Pipeline - INFO - Prefetch for DISTORTION reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_distortion_0021.asdf'.
# 2018-04-17 12:05:25,599 - stpipe.Spec2Pipeline - INFO - Prefetch for DRIZPARS reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_drizpars_0001.fits'.
# 2018-04-17 12:05:25,600 - stpipe.Spec2Pipeline - INFO - Prefetch for EXTRACT1D reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_extract1d_0003.json'.
# 2018-04-17 12:05:25,602 - stpipe.Spec2Pipeline - INFO - Prefetch for FFLAT reference file is 'N/A'.
# 2018-04-17 12:05:25,602 - stpipe.Spec2Pipeline - INFO - Prefetch for FILTEROFFSET reference file is 'N/A'.
# 2018-04-17 12:05:25,603 - stpipe.Spec2Pipeline - INFO - Prefetch for FLAT reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_flat_0248.fits'.
# 2018-04-17 12:05:25,605 - stpipe.Spec2Pipeline - INFO - Prefetch for FORE reference file is 'N/A'.
# 2018-04-17 12:05:25,606 - stpipe.Spec2Pipeline - INFO - Prefetch for FPA reference file is 'N/A'.
# 2018-04-17 12:05:25,607 - stpipe.Spec2Pipeline - INFO - Prefetch for FRINGE reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_fringe_0031.fits'.
# 2018-04-17 12:05:25,609 - stpipe.Spec2Pipeline - INFO - Prefetch for IFUFORE reference file is 'N/A'.
# 2018-04-17 12:05:25,610 - stpipe.Spec2Pipeline - INFO - Prefetch for IFUPOST reference file is 'N/A'.
# 2018-04-17 12:05:25,611 - stpipe.Spec2Pipeline - INFO - Prefetch for IFUSLICER reference file is 'N/A'.
# 2018-04-17 12:05:25,612 - stpipe.Spec2Pipeline - INFO - Prefetch for MSA reference file is 'N/A'.
# 2018-04-17 12:05:25,613 - stpipe.Spec2Pipeline - INFO - Prefetch for MSAOPER reference file is 'N/A'.
# 2018-04-17 12:05:25,614 - stpipe.Spec2Pipeline - INFO - Prefetch for OTE reference file is 'N/A'.
# 2018-04-17 12:05:25,615 - stpipe.Spec2Pipeline - INFO - Prefetch for PATHLOSS reference file is 'N/A'.
# 2018-04-17 12:05:25,616 - stpipe.Spec2Pipeline - INFO - Prefetch for PHOTOM reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_photom_0020.fits'.
# 2018-04-17 12:05:25,618 - stpipe.Spec2Pipeline - INFO - Prefetch for REGIONS reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_regions_0016.asdf'.
# 2018-04-17 12:05:25,619 - stpipe.Spec2Pipeline - INFO - Prefetch for RESOL reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_resol_0003.fits'.
# 2018-04-17 12:05:25,621 - stpipe.Spec2Pipeline - INFO - Prefetch for SFLAT reference file is 'N/A'.
# 2018-04-17 12:05:25,624 - stpipe.Spec2Pipeline - INFO - Prefetch for SPECWCS reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_specwcs_0015.asdf'.
# 2018-04-17 12:05:25,626 - stpipe.Spec2Pipeline - INFO - Prefetch for WAVECORR reference file is 'N/A'.
# 2018-04-17 12:05:25,628 - stpipe.Spec2Pipeline - INFO - Prefetch for WAVELENGTHRANGE reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_wavelengthrange_0003.asdf'.
# 2018-04-17 12:05:25,630 - stpipe.Spec2Pipeline - INFO - Step Spec2Pipeline running with args ('MRS_demo_data_pipelined/det_image_seq4_MIRIFUSHORT_12SHORTexp1_rate.fits',).
# 2018-04-17 12:05:25,631 - stpipe.Spec2Pipeline - INFO - Starting calwebb_spec2 ...
# 2018-04-17 12:05:25,924 - stpipe.Spec2Pipeline - INFO - Processing product MRS_demo_data_pipelined/det_image_seq4_MIRIFUSHORT_12SHORTexp1
# 2018-04-17 12:05:25,925 - stpipe.Spec2Pipeline - INFO - Working on input MRS_demo_data_pipelined/det_image_seq4_MIRIFUSHORT_12SHORTexp1_rate.fits ...
# 2018-04-17 12:05:26,159 - stpipe.Spec2Pipeline.assign_wcs - INFO - Step assign_wcs running with args (<jwst.datamodels.ifuimage.IFUImageModel object at 0x11367af28>,).
# 2018-04-17 12:05:39,318 - stpipe.Spec2Pipeline.assign_wcs - INFO - assign_wcs did not update S_REGION for type MIR_MRS
# 2018-04-17 12:05:39,319 - stpipe.Spec2Pipeline.assign_wcs - INFO - COMPLETED assign_wcs
# 2018-04-17 12:05:39,331 - stpipe.Spec2Pipeline.assign_wcs - INFO - Step assign_wcs done
# 2018-04-17 12:05:39,467 - stpipe.Spec2Pipeline.flat_field - INFO - Step flat_field running with args (<jwst.datamodels.ifuimage.IFUImageModel object at 0x1818d1a358>,).
# 2018-04-17 12:05:39,623 - stpipe.Spec2Pipeline.flat_field - WARNING - Keyword CDP_LOW_QUAL does not correspond to an existing DQ mnemonic, so will be ignored
# 2018-04-17 12:05:40,693 - stpipe.Spec2Pipeline.flat_field - INFO - Step flat_field done
# 2018-04-17 12:05:40,838 - stpipe.Spec2Pipeline.srctype - INFO - Step srctype running with args (<jwst.datamodels.ifuimage.IFUImageModel object at 0x181b3e9940>,).
# 2018-04-17 12:05:40,893 - stpipe.Spec2Pipeline.srctype - INFO - Input EXP_TYPE is MIR_MRS
# 2018-04-17 12:05:40,894 - stpipe.Spec2Pipeline.srctype - INFO - Using input SRCTYPE of POINT
# 2018-04-17 12:05:40,898 - stpipe.Spec2Pipeline.srctype - INFO - Step srctype done
# 2018-04-17 12:05:41,025 - stpipe.Spec2Pipeline.straylight - INFO - Step straylight running with args (<jwst.datamodels.ifuimage.IFUImageModel object at 0x1818c54908>,).
# 2018-04-17 12:05:41,026 - stpipe.Spec2Pipeline.straylight - INFO - Step skipped.
# 2018-04-17 12:05:41,029 - stpipe.Spec2Pipeline.straylight - INFO - Step straylight done
# 2018-04-17 12:05:41,156 - stpipe.Spec2Pipeline.fringe - INFO - Step fringe running with args (<jwst.datamodels.ifuimage.IFUImageModel object at 0x1818c54908>,).
# 2018-04-17 12:05:41,207 - stpipe.Spec2Pipeline.fringe - INFO - Using FRINGE reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_fringe_0031.fits
# 2018-04-17 12:05:41,335 - stpipe.Spec2Pipeline.fringe - WARNING - Keyword CDP_PARTIAL_DATA does not correspond to an existing DQ mnemonic, so will be ignored
# 2018-04-17 12:05:41,336 - stpipe.Spec2Pipeline.fringe - WARNING - Keyword CDP_LOW_QUAL does not correspond to an existing DQ mnemonic, so will be ignored
# 2018-04-17 12:05:41,337 - stpipe.Spec2Pipeline.fringe - WARNING - Keyword CDP_UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2018-04-17 12:05:42,396 - stpipe.Spec2Pipeline.fringe - INFO - The DQ values in the reference file will NOT be used to update the    DQ values in the output DQ array.
# 2018-04-17 12:05:42,400 - stpipe.Spec2Pipeline.fringe - INFO - Step fringe done
# 2018-04-17 12:05:42,562 - stpipe.Spec2Pipeline.photom - INFO - Step photom running with args (<jwst.datamodels.ifuimage.IFUImageModel object at 0x11381be48>,).
# 2018-04-17 12:05:42,624 - stpipe.Spec2Pipeline.photom - INFO - Using photom reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_photom_0020.fits
# 2018-04-17 12:05:42,630 - stpipe.Spec2Pipeline.photom - INFO - Using area reference file: N/A
# 2018-04-17 12:05:42,632 - stpipe.Spec2Pipeline.photom - INFO - Using instrument: MIRI
# 2018-04-17 12:05:42,633 - stpipe.Spec2Pipeline.photom - INFO -  detector: MIRIFUSHORT
# 2018-04-17 12:05:42,635 - stpipe.Spec2Pipeline.photom - INFO -  exp_type: MIR_MRS
# 2018-04-17 12:05:42,635 - stpipe.Spec2Pipeline.photom - INFO -  band: SHORT
# 2018-04-17 12:05:42,835 - stpipe.Spec2Pipeline.photom - WARNING - Keyword CDP_LOW_QUAL does not correspond to an existing DQ mnemonic, so will be ignored
# 2018-04-17 12:05:42,863 - stpipe.Spec2Pipeline.photom - INFO - Step photom done
# 2018-04-17 12:05:43,001 - stpipe.Spec2Pipeline.cube_build - INFO - Step cube_build running with args (<jwst.datamodels.ifuimage.IFUImageModel object at 0x1818e0eb70>,).
# 2018-04-17 12:05:43,002 - stpipe.Spec2Pipeline.cube_build - INFO - Starting IFU Cube Building Step
# 2018-04-17 12:05:43,002 - stpipe.Spec2Pipeline.cube_build - INFO - Input interpolation: pointcloud
# 2018-04-17 12:05:43,003 - stpipe.Spec2Pipeline.cube_build - INFO - Coordinate system to use: ra-dec
# 2018-04-17 12:05:43,003 - stpipe.Spec2Pipeline.cube_build - INFO - Weighting method for point cloud: msm
# 2018-04-17 12:05:43,005 - stpipe.Spec2Pipeline.cube_build - INFO - Power Weighting distance : 2.000000
# 2018-04-17 12:05:43,056 - stpipe.Spec2Pipeline.cube_build - INFO - The desired cubes covers the MIRI Channels: ['1', '2']
# 2018-04-17 12:05:43,058 - stpipe.Spec2Pipeline.cube_build - INFO - The desired cubes covers the MIRI subchannels: ['SHORT', 'SHORT']
# 2018-04-17 12:05:43,060 - stpipe.Spec2Pipeline.cube_build - INFO - Reading  cube parameter file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_cubepar_0002.fits
# 2018-04-17 12:05:46,256 - stpipe.Spec2Pipeline.cube_build - INFO - Output IFUcube are constructed from all the data
# 2018-04-17 12:05:46,257 - stpipe.Spec2Pipeline.cube_build - INFO - Number of IFUCubes produced by a this run 1
# 2018-04-17 12:05:46,288 - stpipe.Spec2Pipeline.cube_build - INFO - Increasing spatial region of interest default value set for 4 dithers 0.150000
# 2018-04-17 12:05:46,290 - stpipe.Spec2Pipeline.cube_build - INFO - Region of interest  0.150000 0.001000
# 2018-04-17 12:05:46,291 - stpipe.Spec2Pipeline.cube_build - INFO - Number of bands in cube  2
# 2018-04-17 12:05:46,937 - stpipe.Spec2Pipeline.cube_build - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/gwcs/selector.py:443: RuntimeWarning: invalid value encountered in less_equal
#   temp = np.where(np.logical_or(temp <= val_range[0],
#
# 2018-04-17 12:05:46,939 - stpipe.Spec2Pipeline.cube_build - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/gwcs/selector.py:444: RuntimeWarning: invalid value encountered in greater_equal
#   temp >= val_range[1]),
#
# 2018-04-17 12:05:47,933 - stpipe.Spec2Pipeline.cube_build - INFO - Ra average -0.00031812.8
# 2018-04-17 12:05:47,938 - stpipe.Spec2Pipeline.cube_build - INFO - Cube Geometry:
# 2018-04-17 12:05:47,939 - stpipe.Spec2Pipeline.cube_build - INFO - axis# Naxis  CRPIX    CRVAL      CDELT(arc sec)  MIN & Max (xi,eta arc sec)
# 2018-04-17 12:05:47,940 - stpipe.Spec2Pipeline.cube_build - INFO - Axis 1    42  22.00  -0.00031821   0.13000000  -2.79499990   2.79499990
# 2018-04-17 12:05:47,942 - stpipe.Spec2Pipeline.cube_build - INFO - Axis 2    40  21.00  -0.00017473   0.13000000  -2.66499990   2.66499990
# 2018-04-17 12:05:47,943 - stpipe.Spec2Pipeline.cube_build - INFO - Axis 3  4029   1.00   4.84778546   0.00100000   4.84778546   8.87678565
# 2018-04-17 12:05:47,944 - stpipe.Spec2Pipeline.cube_build - INFO - Cube covers channel, subchannel: 1 SHORT
# 2018-04-17 12:05:47,945 - stpipe.Spec2Pipeline.cube_build - INFO - Cube covers channel, subchannel: 2 SHORT
# 2018-04-17 12:05:47,946 - stpipe.Spec2Pipeline.cube_build - INFO - Output Name det_image_seq4_MIRIFUSHORT_12SHORTexp1_s3d.fits
# 2018-04-17 12:07:42,325 - stpipe.Spec2Pipeline.cube_build - INFO - Time Map All slices on Detector to Cube = 102.9.s
# 2018-04-17 12:07:46,797 - stpipe.Spec2Pipeline.cube_build - INFO - Time to interpolate at spaxel values = 4.5.s
# 2018-04-17 12:07:46,798 - stpipe.Spec2Pipeline.cube_build - INFO - Time to find Cube Flux= 4.5.s
# 2018-04-17 12:07:50,378 - stpipe.Spec2Pipeline.cube_build - INFO - Step cube_build done
# 2018-04-17 12:07:50,717 - stpipe.Spec2Pipeline - INFO - Saved model in MRS_demo_data_pipelined/det_image_seq4_MIRIFUSHORT_12SHORTexp1_s3d.fits
# 2018-04-17 12:07:51,063 - stpipe.Spec2Pipeline.extract_1d - INFO - Step extract_1d running with args (<jwst.datamodels.container.ModelContainer object at 0x181b3e3128>,).
# 2018-04-17 12:07:51,110 - stpipe.Spec2Pipeline.extract_1d - INFO - Using EXTRACT1D reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_extract1d_0003.json
# 2018-04-17 12:07:51,173 - stpipe.Spec2Pipeline.extract_1d - INFO - source_type = point
# 2018-04-17 12:08:02,462 - stpipe.Spec2Pipeline.extract_1d - INFO - Data have been flux calibrated; setting net to 0.
# 2018-04-17 12:08:02,620 - stpipe.Spec2Pipeline.extract_1d - INFO - Step extract_1d done
# 2018-04-17 12:08:02,621 - stpipe.Spec2Pipeline - INFO - Finished processing product MRS_demo_data_pipelined/det_image_seq4_MIRIFUSHORT_12SHORTexp1
# 2018-04-17 12:08:04,122 - stpipe.Spec2Pipeline - INFO - Saved model in MRS_demo_data_pipelined/det_image_seq4_MIRIFUSHORT_12SHORTexp1_cal.fits
# 2018-04-17 12:08:04,284 - stpipe.Spec2Pipeline - INFO - Ending calwebb_spec2
# 2018-04-17 12:08:04,286 - stpipe.Spec2Pipeline - INFO - Step Spec2Pipeline done
# 2018-04-17 12:08:04,302 - stpipe.Spec2Pipeline - INFO - Spec2Pipeline instance created.
# 2018-04-17 12:08:04,304 - stpipe.Spec2Pipeline.straylight - INFO - StraylightStep instance created.
# 2018-04-17 12:08:04,305 - stpipe.Spec2Pipeline.imprint_subtract - INFO - ImprintStep instance created.
# 2018-04-17 12:08:04,307 - stpipe.Spec2Pipeline.flat_field - INFO - FlatFieldStep instance created.
# 2018-04-17 12:08:04,309 - stpipe.Spec2Pipeline.extract_1d - INFO - Extract1dStep instance created.
# 2018-04-17 12:08:04,311 - stpipe.Spec2Pipeline.msa_flagging - INFO - MSAFlagOpenStep instance created.
# 2018-04-17 12:08:04,312 - stpipe.Spec2Pipeline.srctype - INFO - SourceTypeStep instance created.
# 2018-04-17 12:08:04,314 - stpipe.Spec2Pipeline.pathloss - INFO - PathLossStep instance created.
# 2018-04-17 12:08:04,316 - stpipe.Spec2Pipeline.resample_spec - INFO - ResampleSpecStep instance created.
# 2018-04-17 12:08:04,318 - stpipe.Spec2Pipeline.assign_wcs - INFO - AssignWcsStep instance created.
# 2018-04-17 12:08:04,321 - stpipe.Spec2Pipeline.cube_build - INFO - CubeBuildStep instance created.
# 2018-04-17 12:08:04,323 - stpipe.Spec2Pipeline.bkg_subtract - INFO - BackgroundStep instance created.
# 2018-04-17 12:08:04,325 - stpipe.Spec2Pipeline.photom - INFO - PhotomStep instance created.
# 2018-04-17 12:08:04,327 - stpipe.Spec2Pipeline.barshadow - INFO - BarShadowStep instance created.
# 2018-04-17 12:08:04,329 - stpipe.Spec2Pipeline.fringe - INFO - FringeStep instance created.
# 2018-04-17 12:08:04,331 - stpipe.Spec2Pipeline.extract_2d - INFO - Extract2dStep instance created.
# 2018-04-17 12:08:04,756 - stpipe.Spec2Pipeline - INFO - Prefetch for AREA reference file is 'N/A'.
# 2018-04-17 12:08:04,756 - stpipe.Spec2Pipeline - INFO - Prefetch for BARSHADOW reference file is 'N/A'.
# 2018-04-17 12:08:04,757 - stpipe.Spec2Pipeline - INFO - Prefetch for CAMERA reference file is 'N/A'.
# 2018-04-17 12:08:04,758 - stpipe.Spec2Pipeline - INFO - Prefetch for COLLIMATOR reference file is 'N/A'.
# 2018-04-17 12:08:04,759 - stpipe.Spec2Pipeline - INFO - Prefetch for CUBEPAR reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_cubepar_0002.fits'.
# 2018-04-17 12:08:04,760 - stpipe.Spec2Pipeline - INFO - Prefetch for DFLAT reference file is 'N/A'.
# 2018-04-17 12:08:04,764 - stpipe.Spec2Pipeline - INFO - Prefetch for DISPERSER reference file is 'N/A'.
# 2018-04-17 12:08:04,765 - stpipe.Spec2Pipeline - INFO - Prefetch for DISTORTION reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_distortion_0021.asdf'.
# 2018-04-17 12:08:04,766 - stpipe.Spec2Pipeline - INFO - Prefetch for DRIZPARS reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_drizpars_0001.fits'.
# 2018-04-17 12:08:04,767 - stpipe.Spec2Pipeline - INFO - Prefetch for EXTRACT1D reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_extract1d_0003.json'.
# 2018-04-17 12:08:04,768 - stpipe.Spec2Pipeline - INFO - Prefetch for FFLAT reference file is 'N/A'.
# 2018-04-17 12:08:04,770 - stpipe.Spec2Pipeline - INFO - Prefetch for FILTEROFFSET reference file is 'N/A'.
# 2018-04-17 12:08:04,771 - stpipe.Spec2Pipeline - INFO - Prefetch for FLAT reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_flat_0248.fits'.
# 2018-04-17 12:08:04,772 - stpipe.Spec2Pipeline - INFO - Prefetch for FORE reference file is 'N/A'.
# 2018-04-17 12:08:04,775 - stpipe.Spec2Pipeline - INFO - Prefetch for FPA reference file is 'N/A'.
# 2018-04-17 12:08:04,780 - stpipe.Spec2Pipeline - INFO - Prefetch for FRINGE reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_fringe_0031.fits'.
# 2018-04-17 12:08:04,781 - stpipe.Spec2Pipeline - INFO - Prefetch for IFUFORE reference file is 'N/A'.
# 2018-04-17 12:08:04,783 - stpipe.Spec2Pipeline - INFO - Prefetch for IFUPOST reference file is 'N/A'.
# 2018-04-17 12:08:04,787 - stpipe.Spec2Pipeline - INFO - Prefetch for IFUSLICER reference file is 'N/A'.
# 2018-04-17 12:08:04,788 - stpipe.Spec2Pipeline - INFO - Prefetch for MSA reference file is 'N/A'.
# 2018-04-17 12:08:04,790 - stpipe.Spec2Pipeline - INFO - Prefetch for MSAOPER reference file is 'N/A'.
# 2018-04-17 12:08:04,793 - stpipe.Spec2Pipeline - INFO - Prefetch for OTE reference file is 'N/A'.
# 2018-04-17 12:08:04,794 - stpipe.Spec2Pipeline - INFO - Prefetch for PATHLOSS reference file is 'N/A'.
# 2018-04-17 12:08:04,796 - stpipe.Spec2Pipeline - INFO - Prefetch for PHOTOM reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_photom_0020.fits'.
# 2018-04-17 12:08:04,798 - stpipe.Spec2Pipeline - INFO - Prefetch for REGIONS reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_regions_0016.asdf'.
# 2018-04-17 12:08:04,799 - stpipe.Spec2Pipeline - INFO - Prefetch for RESOL reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_resol_0003.fits'.
# 2018-04-17 12:08:04,801 - stpipe.Spec2Pipeline - INFO - Prefetch for SFLAT reference file is 'N/A'.
# 2018-04-17 12:08:04,802 - stpipe.Spec2Pipeline - INFO - Prefetch for SPECWCS reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_specwcs_0015.asdf'.
# 2018-04-17 12:08:04,805 - stpipe.Spec2Pipeline - INFO - Prefetch for WAVECORR reference file is 'N/A'.
# 2018-04-17 12:08:04,806 - stpipe.Spec2Pipeline - INFO - Prefetch for WAVELENGTHRANGE reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_wavelengthrange_0003.asdf'.
# 2018-04-17 12:08:04,807 - stpipe.Spec2Pipeline - INFO - Step Spec2Pipeline running with args ('MRS_demo_data_pipelined/det_image_seq2_MIRIFUSHORT_12SHORTexp1_rate.fits',).
# 2018-04-17 12:08:04,809 - stpipe.Spec2Pipeline - INFO - Starting calwebb_spec2 ...
# 2018-04-17 12:08:05,148 - stpipe.Spec2Pipeline - INFO - Processing product MRS_demo_data_pipelined/det_image_seq2_MIRIFUSHORT_12SHORTexp1
# 2018-04-17 12:08:05,149 - stpipe.Spec2Pipeline - INFO - Working on input MRS_demo_data_pipelined/det_image_seq2_MIRIFUSHORT_12SHORTexp1_rate.fits ...
# 2018-04-17 12:08:05,511 - stpipe.Spec2Pipeline.assign_wcs - INFO - Step assign_wcs running with args (<jwst.datamodels.ifuimage.IFUImageModel object at 0x1818c8fe80>,).
# 2018-04-17 12:08:19,376 - stpipe.Spec2Pipeline.assign_wcs - INFO - assign_wcs did not update S_REGION for type MIR_MRS
# 2018-04-17 12:08:19,377 - stpipe.Spec2Pipeline.assign_wcs - INFO - COMPLETED assign_wcs
# 2018-04-17 12:08:19,392 - stpipe.Spec2Pipeline.assign_wcs - INFO - Step assign_wcs done
# 2018-04-17 12:08:19,663 - stpipe.Spec2Pipeline.flat_field - INFO - Step flat_field running with args (<jwst.datamodels.ifuimage.IFUImageModel object at 0x181b498160>,).
# 2018-04-17 12:08:19,829 - stpipe.Spec2Pipeline.flat_field - WARNING - Keyword CDP_LOW_QUAL does not correspond to an existing DQ mnemonic, so will be ignored
# 2018-04-17 12:08:20,954 - stpipe.Spec2Pipeline.flat_field - INFO - Step flat_field done
# 2018-04-17 12:08:21,168 - stpipe.Spec2Pipeline.srctype - INFO - Step srctype running with args (<jwst.datamodels.ifuimage.IFUImageModel object at 0x181dad18d0>,).
# 2018-04-17 12:08:21,231 - stpipe.Spec2Pipeline.srctype - INFO - Input EXP_TYPE is MIR_MRS
# 2018-04-17 12:08:21,232 - stpipe.Spec2Pipeline.srctype - INFO - Using input SRCTYPE of POINT
# 2018-04-17 12:08:21,235 - stpipe.Spec2Pipeline.srctype - INFO - Step srctype done
# 2018-04-17 12:08:21,477 - stpipe.Spec2Pipeline.straylight - INFO - Step straylight running with args (<jwst.datamodels.ifuimage.IFUImageModel object at 0x181efc1048>,).
# 2018-04-17 12:08:21,479 - stpipe.Spec2Pipeline.straylight - INFO - Step skipped.
# 2018-04-17 12:08:21,481 - stpipe.Spec2Pipeline.straylight - INFO - Step straylight done
# 2018-04-17 12:08:21,679 - stpipe.Spec2Pipeline.fringe - INFO - Step fringe running with args (<jwst.datamodels.ifuimage.IFUImageModel object at 0x181efc1048>,).
# 2018-04-17 12:08:21,738 - stpipe.Spec2Pipeline.fringe - INFO - Using FRINGE reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_fringe_0031.fits
# 2018-04-17 12:08:21,843 - stpipe.Spec2Pipeline.fringe - WARNING - Keyword CDP_PARTIAL_DATA does not correspond to an existing DQ mnemonic, so will be ignored
# 2018-04-17 12:08:21,845 - stpipe.Spec2Pipeline.fringe - WARNING - Keyword CDP_LOW_QUAL does not correspond to an existing DQ mnemonic, so will be ignored
# 2018-04-17 12:08:21,845 - stpipe.Spec2Pipeline.fringe - WARNING - Keyword CDP_UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2018-04-17 12:08:23,041 - stpipe.Spec2Pipeline.fringe - INFO - The DQ values in the reference file will NOT be used to update the    DQ values in the output DQ array.
# 2018-04-17 12:08:23,047 - stpipe.Spec2Pipeline.fringe - INFO - Step fringe done
# 2018-04-17 12:08:23,404 - stpipe.Spec2Pipeline.photom - INFO - Step photom running with args (<jwst.datamodels.ifuimage.IFUImageModel object at 0x181b304240>,).
# 2018-04-17 12:08:23,485 - stpipe.Spec2Pipeline.photom - INFO - Using photom reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_photom_0020.fits
# 2018-04-17 12:08:23,490 - stpipe.Spec2Pipeline.photom - INFO - Using area reference file: N/A
# 2018-04-17 12:08:23,491 - stpipe.Spec2Pipeline.photom - INFO - Using instrument: MIRI
# 2018-04-17 12:08:23,492 - stpipe.Spec2Pipeline.photom - INFO -  detector: MIRIFUSHORT
# 2018-04-17 12:08:23,493 - stpipe.Spec2Pipeline.photom - INFO -  exp_type: MIR_MRS
# 2018-04-17 12:08:23,493 - stpipe.Spec2Pipeline.photom - INFO -  band: SHORT
# 2018-04-17 12:08:23,674 - stpipe.Spec2Pipeline.photom - WARNING - Keyword CDP_LOW_QUAL does not correspond to an existing DQ mnemonic, so will be ignored
# 2018-04-17 12:08:23,730 - stpipe.Spec2Pipeline.photom - INFO - Step photom done
# 2018-04-17 12:08:24,084 - stpipe.Spec2Pipeline.cube_build - INFO - Step cube_build running with args (<jwst.datamodels.ifuimage.IFUImageModel object at 0x181d6fc1d0>,).
# 2018-04-17 12:08:24,085 - stpipe.Spec2Pipeline.cube_build - INFO - Starting IFU Cube Building Step
# 2018-04-17 12:08:24,086 - stpipe.Spec2Pipeline.cube_build - INFO - Input interpolation: pointcloud
# 2018-04-17 12:08:24,087 - stpipe.Spec2Pipeline.cube_build - INFO - Coordinate system to use: ra-dec
# 2018-04-17 12:08:24,089 - stpipe.Spec2Pipeline.cube_build - INFO - Weighting method for point cloud: msm
# 2018-04-17 12:08:24,089 - stpipe.Spec2Pipeline.cube_build - INFO - Power Weighting distance : 2.000000
# 2018-04-17 12:08:24,160 - stpipe.Spec2Pipeline.cube_build - INFO - The desired cubes covers the MIRI Channels: ['1', '2']
# 2018-04-17 12:08:24,162 - stpipe.Spec2Pipeline.cube_build - INFO - The desired cubes covers the MIRI subchannels: ['SHORT', 'SHORT']
# 2018-04-17 12:08:24,164 - stpipe.Spec2Pipeline.cube_build - INFO - Reading  cube parameter file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_cubepar_0002.fits
# 2018-04-17 12:08:27,787 - stpipe.Spec2Pipeline.cube_build - INFO - Output IFUcube are constructed from all the data
# 2018-04-17 12:08:27,789 - stpipe.Spec2Pipeline.cube_build - INFO - Number of IFUCubes produced by a this run 1
# 2018-04-17 12:08:27,851 - stpipe.Spec2Pipeline.cube_build - INFO - Increasing spatial region of interest default value set for 4 dithers 0.150000
# 2018-04-17 12:08:27,853 - stpipe.Spec2Pipeline.cube_build - INFO - Region of interest  0.150000 0.001000
# 2018-04-17 12:08:27,854 - stpipe.Spec2Pipeline.cube_build - INFO - Number of bands in cube  2
# 2018-04-17 12:08:28,719 - stpipe.Spec2Pipeline.cube_build - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/gwcs/selector.py:443: RuntimeWarning: invalid value encountered in less_equal
#   temp = np.where(np.logical_or(temp <= val_range[0],
#
# 2018-04-17 12:08:28,722 - stpipe.Spec2Pipeline.cube_build - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/gwcs/selector.py:444: RuntimeWarning: invalid value encountered in greater_equal
#   temp >= val_range[1]),
#
# 2018-04-17 12:08:29,840 - stpipe.Spec2Pipeline.cube_build - INFO - Ra average 0.00025312.8
# 2018-04-17 12:08:29,846 - stpipe.Spec2Pipeline.cube_build - INFO - Cube Geometry:
# 2018-04-17 12:08:29,847 - stpipe.Spec2Pipeline.cube_build - INFO - axis# Naxis  CRPIX    CRVAL      CDELT(arc sec)  MIN & Max (xi,eta arc sec)
# 2018-04-17 12:08:29,848 - stpipe.Spec2Pipeline.cube_build - INFO - Axis 1    42  22.00   0.00025316   0.13000000  -2.79499990   2.79499990
# 2018-04-17 12:08:29,848 - stpipe.Spec2Pipeline.cube_build - INFO - Axis 2    40  21.00  -0.00001188   0.13000000  -2.66499990   2.66499990
# 2018-04-17 12:08:29,849 - stpipe.Spec2Pipeline.cube_build - INFO - Axis 3  4029   1.00   4.84778546   0.00100000   4.84778546   8.87678565
# 2018-04-17 12:08:29,850 - stpipe.Spec2Pipeline.cube_build - INFO - Cube covers channel, subchannel: 1 SHORT
# 2018-04-17 12:08:29,851 - stpipe.Spec2Pipeline.cube_build - INFO - Cube covers channel, subchannel: 2 SHORT
# 2018-04-17 12:08:29,851 - stpipe.Spec2Pipeline.cube_build - INFO - Output Name det_image_seq2_MIRIFUSHORT_12SHORTexp1_s3d.fits
# 2018-04-17 12:10:28,759 - stpipe.Spec2Pipeline.cube_build - INFO - Time Map All slices on Detector to Cube = 106.5.s
# 2018-04-17 12:10:33,629 - stpipe.Spec2Pipeline.cube_build - INFO - Time to interpolate at spaxel values = 4.9.s
# 2018-04-17 12:10:33,630 - stpipe.Spec2Pipeline.cube_build - INFO - Time to find Cube Flux= 4.9.s
# 2018-04-17 12:10:37,605 - stpipe.Spec2Pipeline.cube_build - INFO - Step cube_build done
# 2018-04-17 12:10:37,964 - stpipe.Spec2Pipeline - INFO - Saved model in MRS_demo_data_pipelined/det_image_seq2_MIRIFUSHORT_12SHORTexp1_s3d.fits
# 2018-04-17 12:10:38,508 - stpipe.Spec2Pipeline.extract_1d - INFO - Step extract_1d running with args (<jwst.datamodels.container.ModelContainer object at 0x181b50cbe0>,).
# 2018-04-17 12:10:38,596 - stpipe.Spec2Pipeline.extract_1d - INFO - Using EXTRACT1D reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_extract1d_0003.json
# 2018-04-17 12:10:38,695 - stpipe.Spec2Pipeline.extract_1d - INFO - source_type = point
# 2018-04-17 12:10:50,295 - stpipe.Spec2Pipeline.extract_1d - INFO - Data have been flux calibrated; setting net to 0.
# 2018-04-17 12:10:50,456 - stpipe.Spec2Pipeline.extract_1d - INFO - Step extract_1d done
# 2018-04-17 12:10:50,457 - stpipe.Spec2Pipeline - INFO - Finished processing product MRS_demo_data_pipelined/det_image_seq2_MIRIFUSHORT_12SHORTexp1
# 2018-04-17 12:10:52,036 - stpipe.Spec2Pipeline - INFO - Saved model in MRS_demo_data_pipelined/det_image_seq2_MIRIFUSHORT_12SHORTexp1_cal.fits
# 2018-04-17 12:10:52,372 - stpipe.Spec2Pipeline - INFO - Ending calwebb_spec2
# 2018-04-17 12:10:52,373 - stpipe.Spec2Pipeline - INFO - Step Spec2Pipeline done
# 2018-04-17 12:10:52,387 - stpipe.Spec2Pipeline - INFO - Spec2Pipeline instance created.
# 2018-04-17 12:10:52,390 - stpipe.Spec2Pipeline.straylight - INFO - StraylightStep instance created.
# 2018-04-17 12:10:52,392 - stpipe.Spec2Pipeline.imprint_subtract - INFO - ImprintStep instance created.
# 2018-04-17 12:10:52,394 - stpipe.Spec2Pipeline.flat_field - INFO - FlatFieldStep instance created.
# 2018-04-17 12:10:52,395 - stpipe.Spec2Pipeline.extract_1d - INFO - Extract1dStep instance created.
# 2018-04-17 12:10:52,397 - stpipe.Spec2Pipeline.msa_flagging - INFO - MSAFlagOpenStep instance created.
# 2018-04-17 12:10:52,398 - stpipe.Spec2Pipeline.srctype - INFO - SourceTypeStep instance created.
# 2018-04-17 12:10:52,400 - stpipe.Spec2Pipeline.pathloss - INFO - PathLossStep instance created.
# 2018-04-17 12:10:52,402 - stpipe.Spec2Pipeline.resample_spec - INFO - ResampleSpecStep instance created.
# 2018-04-17 12:10:52,404 - stpipe.Spec2Pipeline.assign_wcs - INFO - AssignWcsStep instance created.
# 2018-04-17 12:10:52,407 - stpipe.Spec2Pipeline.cube_build - INFO - CubeBuildStep instance created.
# 2018-04-17 12:10:52,409 - stpipe.Spec2Pipeline.bkg_subtract - INFO - BackgroundStep instance created.
# 2018-04-17 12:10:52,411 - stpipe.Spec2Pipeline.photom - INFO - PhotomStep instance created.
# 2018-04-17 12:10:52,412 - stpipe.Spec2Pipeline.barshadow - INFO - BarShadowStep instance created.
# 2018-04-17 12:10:52,414 - stpipe.Spec2Pipeline.fringe - INFO - FringeStep instance created.
# 2018-04-17 12:10:52,415 - stpipe.Spec2Pipeline.extract_2d - INFO - Extract2dStep instance created.
# 2018-04-17 12:10:52,899 - stpipe.Spec2Pipeline - INFO - Prefetch for AREA reference file is 'N/A'.
# 2018-04-17 12:10:52,901 - stpipe.Spec2Pipeline - INFO - Prefetch for BARSHADOW reference file is 'N/A'.
# 2018-04-17 12:10:52,902 - stpipe.Spec2Pipeline - INFO - Prefetch for CAMERA reference file is 'N/A'.
# 2018-04-17 12:10:52,903 - stpipe.Spec2Pipeline - INFO - Prefetch for COLLIMATOR reference file is 'N/A'.
# 2018-04-17 12:10:52,904 - stpipe.Spec2Pipeline - INFO - Prefetch for CUBEPAR reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_cubepar_0002.fits'.
# 2018-04-17 12:10:52,905 - stpipe.Spec2Pipeline - INFO - Prefetch for DFLAT reference file is 'N/A'.
# 2018-04-17 12:10:52,906 - stpipe.Spec2Pipeline - INFO - Prefetch for DISPERSER reference file is 'N/A'.
# 2018-04-17 12:10:52,907 - stpipe.Spec2Pipeline - INFO - Prefetch for DISTORTION reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_distortion_0021.asdf'.
# 2018-04-17 12:10:52,908 - stpipe.Spec2Pipeline - INFO - Prefetch for DRIZPARS reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_drizpars_0001.fits'.
# 2018-04-17 12:10:52,910 - stpipe.Spec2Pipeline - INFO - Prefetch for EXTRACT1D reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_extract1d_0003.json'.
# 2018-04-17 12:10:52,910 - stpipe.Spec2Pipeline - INFO - Prefetch for FFLAT reference file is 'N/A'.
# 2018-04-17 12:10:52,911 - stpipe.Spec2Pipeline - INFO - Prefetch for FILTEROFFSET reference file is 'N/A'.
# 2018-04-17 12:10:52,912 - stpipe.Spec2Pipeline - INFO - Prefetch for FLAT reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_flat_0248.fits'.
# 2018-04-17 12:10:52,913 - stpipe.Spec2Pipeline - INFO - Prefetch for FORE reference file is 'N/A'.
# 2018-04-17 12:10:52,913 - stpipe.Spec2Pipeline - INFO - Prefetch for FPA reference file is 'N/A'.
# 2018-04-17 12:10:52,914 - stpipe.Spec2Pipeline - INFO - Prefetch for FRINGE reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_fringe_0031.fits'.
# 2018-04-17 12:10:52,915 - stpipe.Spec2Pipeline - INFO - Prefetch for IFUFORE reference file is 'N/A'.
# 2018-04-17 12:10:52,916 - stpipe.Spec2Pipeline - INFO - Prefetch for IFUPOST reference file is 'N/A'.
# 2018-04-17 12:10:52,917 - stpipe.Spec2Pipeline - INFO - Prefetch for IFUSLICER reference file is 'N/A'.
# 2018-04-17 12:10:52,917 - stpipe.Spec2Pipeline - INFO - Prefetch for MSA reference file is 'N/A'.
# 2018-04-17 12:10:52,919 - stpipe.Spec2Pipeline - INFO - Prefetch for MSAOPER reference file is 'N/A'.
# 2018-04-17 12:10:52,920 - stpipe.Spec2Pipeline - INFO - Prefetch for OTE reference file is 'N/A'.
# 2018-04-17 12:10:52,920 - stpipe.Spec2Pipeline - INFO - Prefetch for PATHLOSS reference file is 'N/A'.
# 2018-04-17 12:10:52,921 - stpipe.Spec2Pipeline - INFO - Prefetch for PHOTOM reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_photom_0020.fits'.
# 2018-04-17 12:10:52,922 - stpipe.Spec2Pipeline - INFO - Prefetch for REGIONS reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_regions_0016.asdf'.
# 2018-04-17 12:10:52,923 - stpipe.Spec2Pipeline - INFO - Prefetch for RESOL reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_resol_0003.fits'.
# 2018-04-17 12:10:52,924 - stpipe.Spec2Pipeline - INFO - Prefetch for SFLAT reference file is 'N/A'.
# 2018-04-17 12:10:52,925 - stpipe.Spec2Pipeline - INFO - Prefetch for SPECWCS reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_specwcs_0015.asdf'.
# 2018-04-17 12:10:52,926 - stpipe.Spec2Pipeline - INFO - Prefetch for WAVECORR reference file is 'N/A'.
# 2018-04-17 12:10:52,926 - stpipe.Spec2Pipeline - INFO - Prefetch for WAVELENGTHRANGE reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_wavelengthrange_0003.asdf'.
# 2018-04-17 12:10:52,928 - stpipe.Spec2Pipeline - INFO - Step Spec2Pipeline running with args ('MRS_demo_data_pipelined/det_image_seq1_MIRIFUSHORT_12SHORTexp1_rate.fits',).
# 2018-04-17 12:10:52,928 - stpipe.Spec2Pipeline - INFO - Starting calwebb_spec2 ...
# 2018-04-17 12:10:53,195 - stpipe.Spec2Pipeline - INFO - Processing product MRS_demo_data_pipelined/det_image_seq1_MIRIFUSHORT_12SHORTexp1
# 2018-04-17 12:10:53,195 - stpipe.Spec2Pipeline - INFO - Working on input MRS_demo_data_pipelined/det_image_seq1_MIRIFUSHORT_12SHORTexp1_rate.fits ...
# 2018-04-17 12:10:53,622 - stpipe.Spec2Pipeline.assign_wcs - INFO - Step assign_wcs running with args (<jwst.datamodels.ifuimage.IFUImageModel object at 0x181de25320>,).
# 2018-04-17 12:11:06,592 - stpipe.Spec2Pipeline.assign_wcs - INFO - assign_wcs did not update S_REGION for type MIR_MRS
# 2018-04-17 12:11:06,593 - stpipe.Spec2Pipeline.assign_wcs - INFO - COMPLETED assign_wcs
# 2018-04-17 12:11:06,601 - stpipe.Spec2Pipeline.assign_wcs - INFO - Step assign_wcs done
# 2018-04-17 12:11:06,890 - stpipe.Spec2Pipeline.flat_field - INFO - Step flat_field running with args (<jwst.datamodels.ifuimage.IFUImageModel object at 0x1845fa3080>,).
# 2018-04-17 12:11:07,100 - stpipe.Spec2Pipeline.flat_field - WARNING - Keyword CDP_LOW_QUAL does not correspond to an existing DQ mnemonic, so will be ignored
# 2018-04-17 12:11:08,140 - stpipe.Spec2Pipeline.flat_field - INFO - Step flat_field done
# 2018-04-17 12:11:08,403 - stpipe.Spec2Pipeline.srctype - INFO - Step srctype running with args (<jwst.datamodels.ifuimage.IFUImageModel object at 0x181f1c4358>,).
# 2018-04-17 12:11:08,473 - stpipe.Spec2Pipeline.srctype - INFO - Input EXP_TYPE is MIR_MRS
# 2018-04-17 12:11:08,473 - stpipe.Spec2Pipeline.srctype - INFO - Using input SRCTYPE of POINT
# 2018-04-17 12:11:08,476 - stpipe.Spec2Pipeline.srctype - INFO - Step srctype done
# 2018-04-17 12:11:08,716 - stpipe.Spec2Pipeline.straylight - INFO - Step straylight running with args (<jwst.datamodels.ifuimage.IFUImageModel object at 0x11347b5f8>,).
# 2018-04-17 12:11:08,717 - stpipe.Spec2Pipeline.straylight - INFO - Step skipped.
# 2018-04-17 12:11:08,718 - stpipe.Spec2Pipeline.straylight - INFO - Step straylight done
# 2018-04-17 12:11:08,972 - stpipe.Spec2Pipeline.fringe - INFO - Step fringe running with args (<jwst.datamodels.ifuimage.IFUImageModel object at 0x11347b5f8>,).
# 2018-04-17 12:11:09,035 - stpipe.Spec2Pipeline.fringe - INFO - Using FRINGE reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_fringe_0031.fits
# 2018-04-17 12:11:09,172 - stpipe.Spec2Pipeline.fringe - WARNING - Keyword CDP_PARTIAL_DATA does not correspond to an existing DQ mnemonic, so will be ignored
# 2018-04-17 12:11:09,174 - stpipe.Spec2Pipeline.fringe - WARNING - Keyword CDP_LOW_QUAL does not correspond to an existing DQ mnemonic, so will be ignored
# 2018-04-17 12:11:09,175 - stpipe.Spec2Pipeline.fringe - WARNING - Keyword CDP_UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2018-04-17 12:11:10,216 - stpipe.Spec2Pipeline.fringe - INFO - The DQ values in the reference file will NOT be used to update the    DQ values in the output DQ array.
# 2018-04-17 12:11:10,220 - stpipe.Spec2Pipeline.fringe - INFO - Step fringe done
# 2018-04-17 12:11:10,558 - stpipe.Spec2Pipeline.photom - INFO - Step photom running with args (<jwst.datamodels.ifuimage.IFUImageModel object at 0x113827c18>,).
# 2018-04-17 12:11:10,625 - stpipe.Spec2Pipeline.photom - INFO - Using photom reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_photom_0020.fits
# 2018-04-17 12:11:10,630 - stpipe.Spec2Pipeline.photom - INFO - Using area reference file: N/A
# 2018-04-17 12:11:10,631 - stpipe.Spec2Pipeline.photom - INFO - Using instrument: MIRI
# 2018-04-17 12:11:10,632 - stpipe.Spec2Pipeline.photom - INFO -  detector: MIRIFUSHORT
# 2018-04-17 12:11:10,632 - stpipe.Spec2Pipeline.photom - INFO -  exp_type: MIR_MRS
# 2018-04-17 12:11:10,633 - stpipe.Spec2Pipeline.photom - INFO -  band: SHORT
# 2018-04-17 12:11:10,901 - stpipe.Spec2Pipeline.photom - WARNING - Keyword CDP_LOW_QUAL does not correspond to an existing DQ mnemonic, so will be ignored
# 2018-04-17 12:11:10,925 - stpipe.Spec2Pipeline.photom - INFO - Step photom done
# 2018-04-17 12:11:11,219 - stpipe.Spec2Pipeline.cube_build - INFO - Step cube_build running with args (<jwst.datamodels.ifuimage.IFUImageModel object at 0x181e172eb8>,).
# 2018-04-17 12:11:11,220 - stpipe.Spec2Pipeline.cube_build - INFO - Starting IFU Cube Building Step
# 2018-04-17 12:11:11,221 - stpipe.Spec2Pipeline.cube_build - INFO - Input interpolation: pointcloud
# 2018-04-17 12:11:11,221 - stpipe.Spec2Pipeline.cube_build - INFO - Coordinate system to use: ra-dec
# 2018-04-17 12:11:11,222 - stpipe.Spec2Pipeline.cube_build - INFO - Weighting method for point cloud: msm
# 2018-04-17 12:11:11,223 - stpipe.Spec2Pipeline.cube_build - INFO - Power Weighting distance : 2.000000
# 2018-04-17 12:11:11,292 - stpipe.Spec2Pipeline.cube_build - INFO - The desired cubes covers the MIRI Channels: ['1', '2']
# 2018-04-17 12:11:11,293 - stpipe.Spec2Pipeline.cube_build - INFO - The desired cubes covers the MIRI subchannels: ['SHORT', 'SHORT']
# 2018-04-17 12:11:11,293 - stpipe.Spec2Pipeline.cube_build - INFO - Reading  cube parameter file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_cubepar_0002.fits
# 2018-04-17 12:11:14,629 - stpipe.Spec2Pipeline.cube_build - INFO - Output IFUcube are constructed from all the data
# 2018-04-17 12:11:14,630 - stpipe.Spec2Pipeline.cube_build - INFO - Number of IFUCubes produced by a this run 1
# 2018-04-17 12:11:14,689 - stpipe.Spec2Pipeline.cube_build - INFO - Increasing spatial region of interest default value set for 4 dithers 0.150000
# 2018-04-17 12:11:14,690 - stpipe.Spec2Pipeline.cube_build - INFO - Region of interest  0.150000 0.001000
# 2018-04-17 12:11:14,691 - stpipe.Spec2Pipeline.cube_build - INFO - Number of bands in cube  2
# 2018-04-17 12:11:15,278 - stpipe.Spec2Pipeline.cube_build - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/gwcs/selector.py:443: RuntimeWarning: invalid value encountered in less_equal
#   temp = np.where(np.logical_or(temp <= val_range[0],
#
# 2018-04-17 12:11:15,279 - stpipe.Spec2Pipeline.cube_build - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/gwcs/selector.py:444: RuntimeWarning: invalid value encountered in greater_equal
#   temp >= val_range[1]),
# 2018-04-17 12:11:16,111 - stpipe.Spec2Pipeline.cube_build - INFO - Ra average -0.00034912.8
# 2018-04-17 12:11:16,115 - stpipe.Spec2Pipeline.cube_build - INFO - Cube Geometry:
# 2018-04-17 12:11:16,115 - stpipe.Spec2Pipeline.cube_build - INFO - axis# Naxis  CRPIX    CRVAL      CDELT(arc sec)  MIN & Max (xi,eta arc sec)
# 2018-04-17 12:11:16,116 - stpipe.Spec2Pipeline.cube_build - INFO - Axis 1    42  22.00  -0.00034857   0.13000000  -2.79499990   2.79499990
# 2018-04-17 12:11:16,117 - stpipe.Spec2Pipeline.cube_build - INFO - Axis 2    40  21.00  -0.00019485   0.13000000  -2.66499990   2.66499990
# 2018-04-17 12:11:16,118 - stpipe.Spec2Pipeline.cube_build - INFO - Axis 3  4029   1.00   4.84778546   0.00100000   4.84778546   8.87678565
# 2018-04-17 12:11:16,119 - stpipe.Spec2Pipeline.cube_build - INFO - Cube covers channel, subchannel: 1 SHORT
# 2018-04-17 12:11:16,119 - stpipe.Spec2Pipeline.cube_build - INFO - Cube covers channel, subchannel: 2 SHORT
# 2018-04-17 12:11:16,120 - stpipe.Spec2Pipeline.cube_build - INFO - Output Name det_image_seq1_MIRIFUSHORT_12SHORTexp1_s3d.fits
# 2018-04-17 12:13:13,112 - stpipe.Spec2Pipeline.cube_build - INFO - Time Map All slices on Detector to Cube = 104.2.s
# 2018-04-17 12:13:17,930 - stpipe.Spec2Pipeline.cube_build - INFO - Time to interpolate at spaxel values = 4.8.s
# 2018-04-17 12:13:17,931 - stpipe.Spec2Pipeline.cube_build - INFO - Time to find Cube Flux= 4.8.s
# 2018-04-17 12:13:21,660 - stpipe.Spec2Pipeline.cube_build - INFO - Step cube_build done
# 2018-04-17 12:13:21,994 - stpipe.Spec2Pipeline - INFO - Saved model in MRS_demo_data_pipelined/det_image_seq1_MIRIFUSHORT_12SHORTexp1_s3d.fits
# 2018-04-17 12:13:22,512 - stpipe.Spec2Pipeline.extract_1d - INFO - Step extract_1d running with args (<jwst.datamodels.container.ModelContainer object at 0x181ef54b70>,).
# 2018-04-17 12:13:22,608 - stpipe.Spec2Pipeline.extract_1d - INFO - Using EXTRACT1D reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_extract1d_0003.json
# 2018-04-17 12:13:22,722 - stpipe.Spec2Pipeline.extract_1d - INFO - source_type = point
# 2018-04-17 12:13:34,470 - stpipe.Spec2Pipeline.extract_1d - INFO - Data have been flux calibrated; setting net to 0.
# 2018-04-17 12:13:34,694 - stpipe.Spec2Pipeline.extract_1d - INFO - Step extract_1d done
# 2018-04-17 12:13:34,695 - stpipe.Spec2Pipeline - INFO - Finished processing product MRS_demo_data_pipelined/det_image_seq1_MIRIFUSHORT_12SHORTexp1
# 2018-04-17 12:13:36,147 - stpipe.Spec2Pipeline - INFO - Saved model in MRS_demo_data_pipelined/det_image_seq1_MIRIFUSHORT_12SHORTexp1_cal.fits
# 2018-04-17 12:13:36,439 - stpipe.Spec2Pipeline - INFO - Ending calwebb_spec2
# 2018-04-17 12:13:36,440 - stpipe.Spec2Pipeline - INFO - Step Spec2Pipeline done
# 2018-04-17 12:13:36,454 - stpipe.Spec2Pipeline - INFO - Spec2Pipeline instance created.
# 2018-04-17 12:13:36,456 - stpipe.Spec2Pipeline.straylight - INFO - StraylightStep instance created.
# 2018-04-17 12:13:36,458 - stpipe.Spec2Pipeline.imprint_subtract - INFO - ImprintStep instance created.
# 2018-04-17 12:13:36,460 - stpipe.Spec2Pipeline.flat_field - INFO - FlatFieldStep instance created.
# 2018-04-17 12:13:36,462 - stpipe.Spec2Pipeline.extract_1d - INFO - Extract1dStep instance created.
# 2018-04-17 12:13:36,463 - stpipe.Spec2Pipeline.msa_flagging - INFO - MSAFlagOpenStep instance created.
# 2018-04-17 12:13:36,465 - stpipe.Spec2Pipeline.srctype - INFO - SourceTypeStep instance created.
# 2018-04-17 12:13:36,466 - stpipe.Spec2Pipeline.pathloss - INFO - PathLossStep instance created.
# 2018-04-17 12:13:36,468 - stpipe.Spec2Pipeline.resample_spec - INFO - ResampleSpecStep instance created.
# 2018-04-17 12:13:36,470 - stpipe.Spec2Pipeline.assign_wcs - INFO - AssignWcsStep instance created.
# 2018-04-17 12:13:36,474 - stpipe.Spec2Pipeline.cube_build - INFO - CubeBuildStep instance created.
# 2018-04-17 12:13:36,475 - stpipe.Spec2Pipeline.bkg_subtract - INFO - BackgroundStep instance created.
# 2018-04-17 12:13:36,477 - stpipe.Spec2Pipeline.photom - INFO - PhotomStep instance created.
# 2018-04-17 12:13:36,479 - stpipe.Spec2Pipeline.barshadow - INFO - BarShadowStep instance created.
# 2018-04-17 12:13:36,480 - stpipe.Spec2Pipeline.fringe - INFO - FringeStep instance created.
# 2018-04-17 12:13:36,482 - stpipe.Spec2Pipeline.extract_2d - INFO - Extract2dStep instance created.
# 2018-04-17 12:13:37,096 - stpipe.Spec2Pipeline - INFO - Prefetch for AREA reference file is 'N/A'.
# 2018-04-17 12:13:37,098 - stpipe.Spec2Pipeline - INFO - Prefetch for BARSHADOW reference file is 'N/A'.
# 2018-04-17 12:13:37,098 - stpipe.Spec2Pipeline - INFO - Prefetch for CAMERA reference file is 'N/A'.
# 2018-04-17 12:13:37,100 - stpipe.Spec2Pipeline - INFO - Prefetch for COLLIMATOR reference file is 'N/A'.
# 2018-04-17 12:13:37,101 - stpipe.Spec2Pipeline - INFO - Prefetch for CUBEPAR reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_cubepar_0002.fits'.
# 2018-04-17 12:13:37,102 - stpipe.Spec2Pipeline - INFO - Prefetch for DFLAT reference file is 'N/A'.
# 2018-04-17 12:13:37,103 - stpipe.Spec2Pipeline - INFO - Prefetch for DISPERSER reference file is 'N/A'.
# 2018-04-17 12:13:37,104 - stpipe.Spec2Pipeline - INFO - Prefetch for DISTORTION reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_distortion_0021.asdf'.
# 2018-04-17 12:13:37,106 - stpipe.Spec2Pipeline - INFO - Prefetch for DRIZPARS reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_drizpars_0001.fits'.
# 2018-04-17 12:13:37,108 - stpipe.Spec2Pipeline - INFO - Prefetch for EXTRACT1D reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_extract1d_0003.json'.
# 2018-04-17 12:13:37,110 - stpipe.Spec2Pipeline - INFO - Prefetch for FFLAT reference file is 'N/A'.
# 2018-04-17 12:13:37,111 - stpipe.Spec2Pipeline - INFO - Prefetch for FILTEROFFSET reference file is 'N/A'.
# 2018-04-17 12:13:37,112 - stpipe.Spec2Pipeline - INFO - Prefetch for FLAT reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_flat_0248.fits'.
# 2018-04-17 12:13:37,113 - stpipe.Spec2Pipeline - INFO - Prefetch for FORE reference file is 'N/A'.
# 2018-04-17 12:13:37,114 - stpipe.Spec2Pipeline - INFO - Prefetch for FPA reference file is 'N/A'.
# 2018-04-17 12:13:37,115 - stpipe.Spec2Pipeline - INFO - Prefetch for FRINGE reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_fringe_0031.fits'.
# 2018-04-17 12:13:37,116 - stpipe.Spec2Pipeline - INFO - Prefetch for IFUFORE reference file is 'N/A'.
# 2018-04-17 12:13:37,117 - stpipe.Spec2Pipeline - INFO - Prefetch for IFUPOST reference file is 'N/A'.
# 2018-04-17 12:13:37,118 - stpipe.Spec2Pipeline - INFO - Prefetch for IFUSLICER reference file is 'N/A'.
# 2018-04-17 12:13:37,118 - stpipe.Spec2Pipeline - INFO - Prefetch for MSA reference file is 'N/A'.
# 2018-04-17 12:13:37,119 - stpipe.Spec2Pipeline - INFO - Prefetch for MSAOPER reference file is 'N/A'.
# 2018-04-17 12:13:37,120 - stpipe.Spec2Pipeline - INFO - Prefetch for OTE reference file is 'N/A'.
# 2018-04-17 12:13:37,122 - stpipe.Spec2Pipeline - INFO - Prefetch for PATHLOSS reference file is 'N/A'.
# 2018-04-17 12:13:37,123 - stpipe.Spec2Pipeline - INFO - Prefetch for PHOTOM reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_photom_0020.fits'.
# 2018-04-17 12:13:37,126 - stpipe.Spec2Pipeline - INFO - Prefetch for REGIONS reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_regions_0016.asdf'.
# 2018-04-17 12:13:37,127 - stpipe.Spec2Pipeline - INFO - Prefetch for RESOL reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_resol_0003.fits'.
# 2018-04-17 12:13:37,128 - stpipe.Spec2Pipeline - INFO - Prefetch for SFLAT reference file is 'N/A'.
# 2018-04-17 12:13:37,129 - stpipe.Spec2Pipeline - INFO - Prefetch for SPECWCS reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_specwcs_0015.asdf'.
# 2018-04-17 12:13:37,130 - stpipe.Spec2Pipeline - INFO - Prefetch for WAVECORR reference file is 'N/A'.
# 2018-04-17 12:13:37,132 - stpipe.Spec2Pipeline - INFO - Prefetch for WAVELENGTHRANGE reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_wavelengthrange_0003.asdf'.
# 2018-04-17 12:13:37,134 - stpipe.Spec2Pipeline - INFO - Step Spec2Pipeline running with args ('MRS_demo_data_pipelined/det_image_seq3_MIRIFUSHORT_12SHORTexp1_rate.fits',).
# 2018-04-17 12:13:37,134 - stpipe.Spec2Pipeline - INFO - Starting calwebb_spec2 ...
# 2018-04-17 12:13:37,406 - stpipe.Spec2Pipeline - INFO - Processing product MRS_demo_data_pipelined/det_image_seq3_MIRIFUSHORT_12SHORTexp1
# 2018-04-17 12:13:37,408 - stpipe.Spec2Pipeline - INFO - Working on input MRS_demo_data_pipelined/det_image_seq3_MIRIFUSHORT_12SHORTexp1_rate.fits ...
# 2018-04-17 12:13:37,988 - stpipe.Spec2Pipeline.assign_wcs - INFO - Step assign_wcs running with args (<jwst.datamodels.ifuimage.IFUImageModel object at 0x181ec94048>,).
# 2018-04-17 12:13:51,162 - stpipe.Spec2Pipeline.assign_wcs - INFO - assign_wcs did not update S_REGION for type MIR_MRS
# 2018-04-17 12:13:51,163 - stpipe.Spec2Pipeline.assign_wcs - INFO - COMPLETED assign_wcs
# 2018-04-17 12:13:51,176 - stpipe.Spec2Pipeline.assign_wcs - INFO - Step assign_wcs done
# 2018-04-17 12:13:51,537 - stpipe.Spec2Pipeline.flat_field - INFO - Step flat_field running with args (<jwst.datamodels.ifuimage.IFUImageModel object at 0x1818c8ff60>,).
# 2018-04-17 12:13:51,769 - stpipe.Spec2Pipeline.flat_field - WARNING - Keyword CDP_LOW_QUAL does not correspond to an existing DQ mnemonic, so will be ignored
# 2018-04-17 12:13:52,817 - stpipe.Spec2Pipeline.flat_field - INFO - Step flat_field done
# 2018-04-17 12:13:53,211 - stpipe.Spec2Pipeline.srctype - INFO - Step srctype running with args (<jwst.datamodels.ifuimage.IFUImageModel object at 0x18203bba58>,).
# 2018-04-17 12:13:53,297 - stpipe.Spec2Pipeline.srctype - INFO - Input EXP_TYPE is MIR_MRS
# 2018-04-17 12:13:53,298 - stpipe.Spec2Pipeline.srctype - INFO - Using input SRCTYPE of POINT
# 2018-04-17 12:13:53,301 - stpipe.Spec2Pipeline.srctype - INFO - Step srctype done
# 2018-04-17 12:13:53,769 - stpipe.Spec2Pipeline.straylight - INFO - Step straylight running with args (<jwst.datamodels.ifuimage.IFUImageModel object at 0x181f3a7048>,).
# 2018-04-17 12:13:53,770 - stpipe.Spec2Pipeline.straylight - INFO - Step skipped.
# 2018-04-17 12:13:53,772 - stpipe.Spec2Pipeline.straylight - INFO - Step straylight done
# 2018-04-17 12:13:54,140 - stpipe.Spec2Pipeline.fringe - INFO - Step fringe running with args (<jwst.datamodels.ifuimage.IFUImageModel object at 0x181f3a7048>,).
# 2018-04-17 12:13:54,219 - stpipe.Spec2Pipeline.fringe - INFO - Using FRINGE reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_fringe_0031.fits
# 2018-04-17 12:13:54,357 - stpipe.Spec2Pipeline.fringe - WARNING - Keyword CDP_PARTIAL_DATA does not correspond to an existing DQ mnemonic, so will be ignored
# 2018-04-17 12:13:54,358 - stpipe.Spec2Pipeline.fringe - WARNING - Keyword CDP_LOW_QUAL does not correspond to an existing DQ mnemonic, so will be ignored
# 2018-04-17 12:13:54,358 - stpipe.Spec2Pipeline.fringe - WARNING - Keyword CDP_UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2018-04-17 12:13:55,489 - stpipe.Spec2Pipeline.fringe - INFO - The DQ values in the reference file will NOT be used to update the    DQ values in the output DQ array.
# 2018-04-17 12:13:55,493 - stpipe.Spec2Pipeline.fringe - INFO - Step fringe done
# 2018-04-17 12:13:55,835 - stpipe.Spec2Pipeline.photom - INFO - Step photom running with args (<jwst.datamodels.ifuimage.IFUImageModel object at 0x181e37a7f0>,).
# 2018-04-17 12:13:55,913 - stpipe.Spec2Pipeline.photom - INFO - Using photom reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_photom_0020.fits
# 2018-04-17 12:13:55,918 - stpipe.Spec2Pipeline.photom - INFO - Using area reference file: N/A
# 2018-04-17 12:13:55,919 - stpipe.Spec2Pipeline.photom - INFO - Using instrument: MIRI
# 2018-04-17 12:13:55,919 - stpipe.Spec2Pipeline.photom - INFO -  detector: MIRIFUSHORT
# 2018-04-17 12:13:55,920 - stpipe.Spec2Pipeline.photom - INFO -  exp_type: MIR_MRS
# 2018-04-17 12:13:55,921 - stpipe.Spec2Pipeline.photom - INFO -  band: SHORT
# 2018-04-17 12:13:56,108 - stpipe.Spec2Pipeline.photom - WARNING - Keyword CDP_LOW_QUAL does not correspond to an existing DQ mnemonic, so will be ignored
# 2018-04-17 12:13:56,144 - stpipe.Spec2Pipeline.photom - INFO - Step photom done
# 2018-04-17 12:13:56,585 - stpipe.Spec2Pipeline.cube_build - INFO - Step cube_build running with args (<jwst.datamodels.ifuimage.IFUImageModel object at 0x1820588da0>,).
# 2018-04-17 12:13:56,586 - stpipe.Spec2Pipeline.cube_build - INFO - Starting IFU Cube Building Step
# 2018-04-17 12:13:56,587 - stpipe.Spec2Pipeline.cube_build - INFO - Input interpolation: pointcloud
# 2018-04-17 12:13:56,587 - stpipe.Spec2Pipeline.cube_build - INFO - Coordinate system to use: ra-dec
# 2018-04-17 12:13:56,588 - stpipe.Spec2Pipeline.cube_build - INFO - Weighting method for point cloud: msm
# 2018-04-17 12:13:56,589 - stpipe.Spec2Pipeline.cube_build - INFO - Power Weighting distance : 2.000000
# 2018-04-17 12:13:56,681 - stpipe.Spec2Pipeline.cube_build - INFO - The desired cubes covers the MIRI Channels: ['1', '2']
# 2018-04-17 12:13:56,682 - stpipe.Spec2Pipeline.cube_build - INFO - The desired cubes covers the MIRI subchannels: ['SHORT', 'SHORT']
# 2018-04-17 12:13:56,682 - stpipe.Spec2Pipeline.cube_build - INFO - Reading  cube parameter file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_cubepar_0002.fits
# 2018-04-17 12:13:59,857 - stpipe.Spec2Pipeline.cube_build - INFO - Output IFUcube are constructed from all the data
# 2018-04-17 12:13:59,858 - stpipe.Spec2Pipeline.cube_build - INFO - Number of IFUCubes produced by a this run 1
# 2018-04-17 12:13:59,936 - stpipe.Spec2Pipeline.cube_build - INFO - Increasing spatial region of interest default value set for 4 dithers 0.150000
# 2018-04-17 12:13:59,937 - stpipe.Spec2Pipeline.cube_build - INFO - Region of interest  0.150000 0.001000
# 2018-04-17 12:13:59,938 - stpipe.Spec2Pipeline.cube_build - INFO - Number of bands in cube  2
# 2018-04-17 12:14:00,593 - stpipe.Spec2Pipeline.cube_build - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/gwcs/selector.py:443: RuntimeWarning: invalid value encountered in less_equal
#   temp = np.where(np.logical_or(temp <= val_range[0],
#
# 2018-04-17 12:14:00,595 - stpipe.Spec2Pipeline.cube_build - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/gwcs/selector.py:444: RuntimeWarning: invalid value encountered in greater_equal
#   temp >= val_range[1]),
#
# 2018-04-17 12:14:01,481 - stpipe.Spec2Pipeline.cube_build - INFO - Ra average 0.00028312.8
# 2018-04-17 12:14:01,485 - stpipe.Spec2Pipeline.cube_build - INFO - Cube Geometry:
# 2018-04-17 12:14:01,486 - stpipe.Spec2Pipeline.cube_build - INFO - axis# Naxis  CRPIX    CRVAL      CDELT(arc sec)  MIN & Max (xi,eta arc sec)
# 2018-04-17 12:14:01,486 - stpipe.Spec2Pipeline.cube_build - INFO - Axis 1    42  22.00   0.00028335   0.13000000  -2.79499990   2.79499990
# 2018-04-17 12:14:01,487 - stpipe.Spec2Pipeline.cube_build - INFO - Axis 2    40  21.00   0.00000855   0.13000000  -2.66499990   2.66499990
# 2018-04-17 12:14:01,488 - stpipe.Spec2Pipeline.cube_build - INFO - Axis 3  4029   1.00   4.84778546   0.00100000   4.84778546   8.87678565
# 2018-04-17 12:14:01,489 - stpipe.Spec2Pipeline.cube_build - INFO - Cube covers channel, subchannel: 1 SHORT
# 2018-04-17 12:14:01,490 - stpipe.Spec2Pipeline.cube_build - INFO - Cube covers channel, subchannel: 2 SHORT
# 2018-04-17 12:14:01,490 - stpipe.Spec2Pipeline.cube_build - INFO - Output Name det_image_seq3_MIRIFUSHORT_12SHORTexp1_s3d.fits
# 2018-04-17 12:15:54,378 - stpipe.Spec2Pipeline.cube_build - INFO - Time Map All slices on Detector to Cube = 100.5.s
# 2018-04-17 12:15:58,790 - stpipe.Spec2Pipeline.cube_build - INFO - Time to interpolate at spaxel values = 4.4.s
# 2018-04-17 12:15:58,791 - stpipe.Spec2Pipeline.cube_build - INFO - Time to find Cube Flux= 4.4.s
# 2018-04-17 12:16:02,561 - stpipe.Spec2Pipeline.cube_build - INFO - Step cube_build done
# 2018-04-17 12:16:02,930 - stpipe.Spec2Pipeline - INFO - Saved model in MRS_demo_data_pipelined/det_image_seq3_MIRIFUSHORT_12SHORTexp1_s3d.fits
# 2018-04-17 12:16:03,592 - stpipe.Spec2Pipeline.extract_1d - INFO - Step extract_1d running with args (<jwst.datamodels.container.ModelContainer object at 0x18203f5080>,).
# 2018-04-17 12:16:03,708 - stpipe.Spec2Pipeline.extract_1d - INFO - Using EXTRACT1D reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_extract1d_0003.json
# 2018-04-17 12:16:03,825 - stpipe.Spec2Pipeline.extract_1d - INFO - source_type = point
# 2018-04-17 12:16:15,135 - stpipe.Spec2Pipeline.extract_1d - INFO - Data have been flux calibrated; setting net to 0.
# 2018-04-17 12:16:15,392 - stpipe.Spec2Pipeline.extract_1d - INFO - Step extract_1d done
# 2018-04-17 12:16:15,393 - stpipe.Spec2Pipeline - INFO - Finished processing product MRS_demo_data_pipelined/det_image_seq3_MIRIFUSHORT_12SHORTexp1
# 2018-04-17 12:16:16,910 - stpipe.Spec2Pipeline - INFO - Saved model in MRS_demo_data_pipelined/det_image_seq3_MIRIFUSHORT_12SHORTexp1_cal.fits
# 2018-04-17 12:16:17,315 - stpipe.Spec2Pipeline - INFO - Ending calwebb_spec2
# 2018-04-17 12:16:17,316 - stpipe.Spec2Pipeline - INFO - Step Spec2Pipeline done

# %% [markdown]
# ### check of output
#
# The level 2B pipeline for the MRS produces three files for each input:
#
# _cal.fits - the calibrated level 2B file from each dither
#
# _s3d.fits - the cube from each dither
#
# _x1d.fits - the 1d spectrum from each dither

# %%
# set the output file names
level2B_files = glob.glob(os.path.join(output_dir,'*_cal.fits'))
cube_files = glob.glob(os.path.join(output_dir,'*_s3d.fits'))

# %% [markdown]
# #### level 2B file

# %%
with datamodels.open(level2B_files[0]) as dm:
    # check the calibration step information
    print('Check step information status:')
    print('assign_wcs: %s' % dm.meta.cal_step.assign_wcs)
    print('flat_field: %s' % dm.meta.cal_step.flat_field)
    print('srctype: %s' % dm.meta.cal_step.srctype)
    print('straylight: %s' % dm.meta.cal_step.straylight)
    print('fringe: %s' % dm.meta.cal_step.fringe)
    print('photom: %s' % dm.meta.cal_step.photom)
# Out:
# Check step information status:
# assign_wcs: COMPLETE
# flat_field: COMPLETE
# srctype: COMPLETE
# straylight: None
# fringe: COMPLETE
# photom: COMPLETE

# %% [markdown]
# #### Look at level 1B and calibrated level 2B image. We'll look at the first dither only

# %%
# open the input image as a jwst data model
with datamodels.MIRIRampModel(input_files[0]) as in_dm:
    with datamodels.open(level2B_files[0]) as out_dm:
        
        # plot--------------------------------------
        # show the input ramp image and the calibrated
        # slope image. Note the user may have to adjust
        # the scale parameters
        fig, axs = plt.subplots(1, 2, figsize=(12, 6))

        # sum the groups in the first integration of the input ramp image and plot
        axs[0].imshow(in_dm.data[0,-1,:,:], cmap='jet', interpolation='nearest', origin='lower', norm=LogNorm(vmin=1e4,vmax=1.5e4))
        axs[0].annotate('Input ramp image', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')
        axs[0].set_facecolor('black')
        axs[1].imshow(out_dm.data, cmap='jet', interpolation='nearest', origin='lower', vmin=0, vmax=500)
        axs[1].annotate('Calibrated slope image', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')
        axs[1].set_facecolor('black')

        plt.tight_layout()
        plt.show()

# %% [markdown]
# #### Look at cube file. We'll look at the first dither only

# %%
# open the cube as a jwst data model
with datamodels.open(cube_files[0]) as cube_dm:
    
    # plot--------------------------------------
    # sum some of the the frames in each channel
    # Note the user may have to adjust the scaling
    # parameters
    fig, axs = plt.subplots(1, 2, figsize=(12, 6))

    axs[0].imshow(np.sum(cube_dm.data[100:300], axis=0), cmap='jet', interpolation='nearest', origin='lower', norm=LogNorm(vmin=10,vmax=1e4))
    axs[0].annotate('Collapsed cube: short channel', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')
    axs[0].set_facecolor('black')
    axs[1].imshow(np.sum(cube_dm.data[3000:3200], axis=0), cmap='jet', interpolation='nearest', origin='lower', norm=LogNorm(vmin=10,vmax=1e4))
    axs[1].annotate('Collapsed cube: long channel', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')
    axs[1].set_facecolor('black')
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Level 3 pipeline
#
# The Spec3Pipeline is not quite working in jwst-0.9.2.
#
# For now, we just use the cube_build and extract_1d steps to produce level 3 cube and spectral products.
#
# We first create an association file in the output directory containing the list of level 2B files ("_cal.fits") produced by the level 2B pipeline.

# %% [markdown]
# #### create the level 3 association using the asn_from_list tool

# %%
call(["asn_from_list", "-o", "MRS_asn.json"] + level2B_files + ["--product-name", "dither"])
# Out:
# 0

# %%
from jwst.extract_1d import extract_1d_step
from jwst.cube_build import cube_build_step

dms = datamodels.open("MRS_asn.json")
cube_dms = cube_build_step.CubeBuildStep.call(dms, save_results=True, output_dir=output_dir)
spec_dms = extract_1d_step.Extract1dStep.call(cube_dms, output_use_model=True, save_results=True, 
                                              output_dir=output_dir)
# Out:
# 2018-04-17 12:16:37,094 - stpipe.CubeBuildStep - INFO - CubeBuildStep instance created.
# 2018-04-17 12:16:37,565 - stpipe.CubeBuildStep - INFO - Step CubeBuildStep running with args (<jwst.datamodels.container.ModelContainer object at 0x1820430278>,).
# 2018-04-17 12:16:37,566 - stpipe.CubeBuildStep - INFO - Starting IFU Cube Building Step
# 2018-04-17 12:16:37,567 - stpipe.CubeBuildStep - INFO - Input interpolation: pointcloud
# 2018-04-17 12:16:37,568 - stpipe.CubeBuildStep - INFO - Coordinate system to use: ra-dec
# 2018-04-17 12:16:37,568 - stpipe.CubeBuildStep - INFO - Weighting method for point cloud: msm
# 2018-04-17 12:16:37,569 - stpipe.CubeBuildStep - INFO - Power Weighting distance : 2.000000
# 2018-04-17 12:17:09,584 - stpipe.CubeBuildStep - INFO - The desired cubes covers the MIRI Channels: ['1', '2']
# 2018-04-17 12:17:09,585 - stpipe.CubeBuildStep - INFO - The desired cubes covers the MIRI subchannels: ['SHORT', 'SHORT']
# 2018-04-17 12:17:09,586 - stpipe.CubeBuildStep - INFO - Reading  cube parameter file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_cubepar_0002.fits
# 2018-04-17 12:17:12,818 - stpipe.CubeBuildStep - INFO - Output Cubes are single channel, single sub-channel IFU Cubes
# 2018-04-17 12:17:12,820 - stpipe.CubeBuildStep - INFO - Number of IFUCubes produced by a this run 2
# 2018-04-17 12:17:12,943 - stpipe.CubeBuildStep - INFO - Region of interest  0.100000 0.001000
# 2018-04-17 12:17:12,944 - stpipe.CubeBuildStep - INFO - Number of bands in cube  1
# 2018-04-17 12:17:13,606 - stpipe.CubeBuildStep - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/gwcs/selector.py:443: RuntimeWarning: invalid value encountered in less_equal
#   temp = np.where(np.logical_or(temp <= val_range[0],
#
# 2018-04-17 12:17:13,607 - stpipe.CubeBuildStep - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/gwcs/selector.py:444: RuntimeWarning: invalid value encountered in greater_equal
#   temp >= val_range[1]),
#
# 2018-04-17 12:17:16,145 - stpipe.CubeBuildStep - INFO - Ra average -0.00001612.8
# 2018-04-17 12:17:16,148 - stpipe.CubeBuildStep - INFO - Cube Geometry:
# 2018-04-17 12:17:16,148 - stpipe.CubeBuildStep - INFO - axis# Naxis  CRPIX    CRVAL      CDELT(arc sec)  MIN & Max (xi,eta arc sec)
# 2018-04-17 12:17:16,149 - stpipe.CubeBuildStep - INFO - Axis 1    52  27.00  -0.00001638   0.13000000  -3.44499987   3.44499987
# 2018-04-17 12:17:16,150 - stpipe.CubeBuildStep - INFO - Axis 2    38  20.00  -0.00000771   0.13000000  -2.53499991   2.53499991
# 2018-04-17 12:17:16,151 - stpipe.CubeBuildStep - INFO - Axis 3   929   1.00   4.84761370   0.00100000   4.84761370   5.77661375
# 2018-04-17 12:17:16,151 - stpipe.CubeBuildStep - INFO - Cube covers channel, subchannel: 1 SHORT
# 2018-04-17 12:17:16,152 - stpipe.CubeBuildStep - INFO - Output Name MRS_demo_data_pipelined/dither_ch1-short_s3d.fits
# 2018-04-17 12:19:25,492 - stpipe.CubeBuildStep - INFO - Time Map All slices on Detector to Cube = 124.9.s
# 2018-04-17 12:19:27,162 - stpipe.CubeBuildStep - INFO - Time to interpolate at spaxel values = 1.7.s
# 2018-04-17 12:19:27,163 - stpipe.CubeBuildStep - INFO - Time to find Cube Flux= 1.7.s
# 2018-04-17 12:19:28,629 - stpipe.CubeBuildStep - INFO - Region of interest  0.150000 0.002000
# 2018-04-17 12:19:28,630 - stpipe.CubeBuildStep - INFO - Number of bands in cube  1
# 2018-04-17 12:19:31,510 - stpipe.CubeBuildStep - INFO - Ra average -0.00003312.8
# 2018-04-17 12:19:31,512 - stpipe.CubeBuildStep - INFO - Cube Geometry:
# 2018-04-17 12:19:31,513 - stpipe.CubeBuildStep - INFO - axis# Naxis  CRPIX    CRVAL      CDELT(arc sec)  MIN & Max (xi,eta arc sec)
# 2018-04-17 12:19:31,513 - stpipe.CubeBuildStep - INFO - Axis 1    46  24.00  -0.00003261   0.17000000  -3.99500004   3.99500004
# 2018-04-17 12:19:31,514 - stpipe.CubeBuildStep - INFO - Axis 2    36  19.00  -0.00009315   0.17000000  -3.14500003   3.14500003
# 2018-04-17 12:19:31,515 - stpipe.CubeBuildStep - INFO - Axis 3   716   1.00   7.44517473   0.00200000   7.44517473   8.87717480
# 2018-04-17 12:19:31,516 - stpipe.CubeBuildStep - INFO - Cube covers channel, subchannel: 2 SHORT
# 2018-04-17 12:19:31,516 - stpipe.CubeBuildStep - INFO - Output Name MRS_demo_data_pipelined/dither_ch2-short_s3d.fits
# 2018-04-17 12:21:43,691 - stpipe.CubeBuildStep - INFO - Time Map All slices on Detector to Cube = 129.3.s
# 2018-04-17 12:21:44,808 - stpipe.CubeBuildStep - INFO - Time to interpolate at spaxel values = 1.1.s
# 2018-04-17 12:21:44,809 - stpipe.CubeBuildStep - INFO - Time to find Cube Flux= 1.1.s
# 2018-04-17 12:21:46,035 - stpipe.CubeBuildStep - INFO - Saved model in MRS_demo_data_pipelined/dither_ch1-short_cubebuildstep.fits
# 2018-04-17 12:21:46,227 - stpipe.CubeBuildStep - INFO - Saved model in MRS_demo_data_pipelined/dither_ch2-short_cubebuildstep.fits
# 2018-04-17 12:21:46,228 - stpipe.CubeBuildStep - INFO - Step CubeBuildStep done
# 2018-04-17 12:21:46,230 - stpipe.Extract1dStep - INFO - Extract1dStep instance created.
# 2018-04-17 12:21:46,749 - stpipe.Extract1dStep - INFO - Step Extract1dStep running with args (<jwst.datamodels.container.ModelContainer object at 0x182358df60>,).
# 2018-04-17 12:21:47,006 - stpipe.Extract1dStep - INFO - Using EXTRACT1D reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_extract1d_0003.json
# 2018-04-17 12:21:47,137 - stpipe.Extract1dStep - INFO - source_type = point
# 2018-04-17 12:21:49,662 - stpipe.Extract1dStep - INFO - Data have been flux calibrated; setting net to 0.
# 2018-04-17 12:21:49,925 - stpipe.Extract1dStep - INFO - Using EXTRACT1D reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_extract1d_0003.json
# 2018-04-17 12:21:50,050 - stpipe.Extract1dStep - INFO - source_type = point
# 2018-04-17 12:21:52,054 - stpipe.Extract1dStep - INFO - Data have been flux calibrated; setting net to 0.
# 2018-04-17 12:21:52,465 - stpipe.Extract1dStep - INFO - Saved model in MRS_demo_data_pipelined/dither_ch1-short_cubebuildstep_extract1dstep.fits
# 2018-04-17 12:21:52,589 - stpipe.Extract1dStep - INFO - Saved model in MRS_demo_data_pipelined/dither_ch2-short_cubebuildstep_extract1dstep.fits
# 2018-04-17 12:21:52,590 - stpipe.Extract1dStep - INFO - Step Extract1dStep done

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 6))

axs[0].imshow(np.sum(cube_dms[0].data[100:-100], axis=0), cmap='jet', interpolation='nearest', origin='lower', norm=LogNorm(vmin=20,vmax=1e4))
axs[0].annotate('Collapsed cube: short channel', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')
axs[0].set_facecolor('black')
axs[1].imshow(np.sum(cube_dms[1].data[100:-100], axis=0), cmap='jet', interpolation='nearest', origin='lower', norm=LogNorm(vmin=20,vmax=1e4))
axs[1].annotate('Collapsed cube: long channel', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')
axs[1].set_facecolor('black')

plt.tight_layout()
plt.show()

# %% [markdown]
# Note that since we have set the source type to 'POINT' above, the extract_1d step will use an aperture extraction and subtract a background with default values. The aperture centre is at pixel x/2, y/2, the radius is y/4, and the background annulus is from the radius to the radius*sqrt(2). In the future, more advanced extraction methods are planned. One can set also the aperture properties using a custom aperture reference file. Please contact pkavanagh@cp.dias.ie if you want to do this.

# %% [markdown]
# The extracted spectra are in units of mJy/arcsec^2. To convert these to mJy we multiply by the spaxel area. Note that an additional aperture correction factor for the encircled energy in the aperture should also be applied but we forego this here since the CDPs are currently not available.

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 5), sharey=True)

# plot the spectrum in the channel 2 wavelength range
spaxel_area = cube_dms[0].meta.wcsinfo.cdelt1 * cube_dms[0].meta.wcsinfo.cdelt2 * 3600**2
axs[0].plot(spec_dms[0].spec[0].spec_table['WAVELENGTH'], spec_dms[0].spec[0].spec_table['FLUX'] * spaxel_area, c='orange', marker='.', markersize=0, linestyle='-', linewidth=2)
axs[0].set_ylabel(r'Flux (mJy)')
axs[0].set_xlabel(r'Wavelength ($\mu$m)')
axs[0].set_xlim(4.9,5.7)
axs[0].set_ylim(75,200)
axs[0].annotate('Channel 1', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')
axs[0].grid()
spaxel_area = cube_dms[1].meta.wcsinfo.cdelt1 * cube_dms[1].meta.wcsinfo.cdelt2 * 3600**2
axs[1].plot(spec_dms[1].spec[0].spec_table['WAVELENGTH'], spec_dms[1].spec[0].spec_table['FLUX']  * spaxel_area, c='g', marker='.', markersize=0, linestyle='-', linewidth=2)
axs[1].set_xlabel(r'Wavelength ($\mu$m)')
axs[1].set_xlim(7.5,8.7)
axs[1].annotate('Channel 2', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')
axs[1].grid()

plt.tight_layout()
plt.show()
