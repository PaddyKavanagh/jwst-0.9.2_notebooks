# %% [markdown]
# # Run level 2A and 2B pipelines on LRS-SLITLESS data using jwst.pipeline classes

# %% [markdown]
# ### by Patrick Kavanagh (DIAS, Ireland) April 30th 2018

# %% [markdown]
# This notebook demonstrates the execution of the level 2A, 2B and 3 pipelines for LRS-SLITLESS data in Python using the jwst step classes.
#
# Documentation on each pipeline step can be found here:
#
# https://jwst-pipeline.readthedocs.io/en/latest/jwst/pipeline/index.html
#
# The file used in this notebook is a MIRISim simulation (no dithering for LRS-SLITLESS) of a point source with a blackbody spectrum plus emission lines, with a variable absorption component. Because LRS-SLITLESS is TSO mode, there are 3 exposures of 20 integrations, with 20 groups per integration. The data arrays of each exposure are the same, i.e., they are clones only separated in time.
#
# Note that, because of the current uncertainty in some metadata in slitless prism subarray data, we must manually set the array name to what the pipeline expects, ie.:
#
# dm.meta.subarray.name = 'SUBPRISM'
#
# which is done below prior to the Detector1Pipeline call.
#
# LRS-SLITLESS is intended for TSOs, therefore, unlike LRS-SLIT, MRS and IMA, we want to get output products per integration rather than per exposure. This is facilitated through the 'rateints' product of the Detector1Pipeline (i.e., a slope-per-integration product). This product is then put through the Spec2Pipeline where calibrations are applied to the slope image of each integration where appropriate, yielding a 'calints' product. The Spec2Pipeline will also output the 'x1dints' file which contains a spectrum extract from each integration. In level 3, the 'calints' products are combined into a single product and white-light photometry is performed to show the variation in integrated flux during the three exposures.
#
# The following steps are applied:
#
# - ramps to slopes pipeline (Detector1Pipeline)
#
# - CALSPEC2 steps (Spec2Pipeline), including spectral extraction from each integration
#
# - combination of multiple exposure products and white-light photometry (Tso3Pipeline)
#
# - manual conversion of extracted spectra to Jy using SRF
#
#
# #### NB: The final extracted spectra will not have the correct shape. This is due to CDP/CRDS conflict in the reference position for the slitless prism subarray. This will be resolved when the latest CDP is ingested to CRDS.

# %% [markdown]
# #### Imports

# %%
import os, glob, shutil

import numpy as np
from astropy.io import fits
from matplotlib.colors import LogNorm
import matplotlib.pyplot as plt
from subprocess import call

from jwst import datamodels

# %matplotlib inline
# %matplotlib notebook # if you want interactive plots

# %% [markdown]
# #### Set input file:

# %%
# set input filenames and directory. 
input_dir = 'LRS-SLITLESS_demo_data'
input_files = glob.glob(os.path.join(input_dir,'det*.fits'))

# set the output directory name
output_dir = input_dir + '_pipelined'

# if the output directory exists, delete it
if os.path.exists(output_dir): shutil.rmtree(output_dir)

# create the output directory
os.mkdir(output_dir)

# %% [markdown]
# #### print some information about the input files. We will just look at the first file

# %%
# print some info on input file
with fits.open(input_files[0]) as hdulist:
        
    if hdulist[0].header['ORIGIN'] == 'STScI':
        # specific information on instrument/exposure
        identifier = hdulist[0].header['OBS_ID']
        detector = hdulist[0].header['EXP_TYPE']
        im_filter = hdulist[0].header['FILTER']
        nInts = hdulist[0].header['NINTS']
        nGroups = hdulist[0].header['NGROUPS']
        readPatt = hdulist[0].header['READPATT']
        expTime = hdulist[0].header['EFFEXPTM']
        subArr = hdulist[0].header['SUBARRAY']
        channel = hdulist[0].header['CHANNEL']
        band = hdulist[0].header['BAND']
        print("ID\t\t\t Detector\t Filter\t subAr\t\t nInts\t nGrps\t rdPatt\t ExpTime (s)")
        print("--------------------------------------------------------------------------------------------------")
        print("%s\t %s\t %s\t %s\t %d\t %d\t %s\t %0.1f" % (identifier,detector,im_filter,subArr,nInts,nGroups,readPatt,expTime))
        print("\n\n")
            
    else:
        # specific information on instrument/exposure
        detector = hdulist[0].header['EXP_TYPE']
        im_filter = hdulist[0].header['FILTER']
        nInts = hdulist[0].header['NINTS']
        nGroups = hdulist[0].header['NGROUPS']
        readPatt = hdulist[0].header['READPATT']
        expTime = hdulist[0].header['EFFEXPTM']
        subArr = hdulist[0].header['SUBARRAY']
        print("ID\t Type\t\t\t Filter\t subAr\t\t nInts\t nGrps\t rdPatt\t ExpTime (s)")
        print("--------------------------------------------------------------------------------------------------")
        print("MIRISim\t %s\t %s\t %s\t %d\t %d\t %s\t %0.1f" % (detector,im_filter,subArr, nInts,nGroups,readPatt,expTime))
        print("\n\n")

    # fits extension table
    hdulist.info()
# Out:
# ID	 Type			 Filter	 subAr		 nInts	 nGrps	 rdPatt	 ExpTime (s)
# --------------------------------------------------------------------------------------------------
# MIRISim	 MIR_LRS-SLITLESS	 P750L	 SLITLESSPRISM	 20	 20	 FAST	 63.6
#
#
#
# Filename: LRS-SLITLESS_demo_data/det_image_1_MIRIMAGE_P750Lexp2.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      93   ()
#   1  SCI           1 ImageHDU        62   (72, 416, 20, 20)   float32
#   2  PIXELDQ       1 ImageHDU        11   (72, 416)   int32 (rescales to uint32)
#   3  GROUPDQ       1 ImageHDU        11   (72, 416, 20, 20)   uint8
#   4  ERR           1 ImageHDU        11   (72, 416, 20, 20)   float32
#   5  REFOUT        1 ImageHDU        12   (18, 416, 20, 20)   float32
#   6  ASDF          1 ImageHDU         7   (18485,)   uint8
#   7  PIXELDQ_DEF    1 BinTableHDU     17   31R x 4C   [J, J, 40A, 128A]

# %% [markdown]
# #### show the last frame of each integration in the first exposure

# %%
fig, axs = plt.subplots(2, 10, figsize=(12, 10), sharey=True, sharex=True)
axs = axs.ravel()

with datamodels.open(input_files[0]) as in_dm:
    for n in range(20):
        axs[n].imshow(in_dm.data[n,-1,:,:], cmap='jet', interpolation='nearest', origin='lower', norm=LogNorm(vmin=1.1e4,vmax=1.2e4))
        axs[n].set_facecolor('black')

plt.tight_layout(pad=0.2)
plt.show()

# %% [markdown]
# ### Level 2A pipeline (ramps-to-slopes)

# %% [markdown]
# #### import the level 2A pipeline class and print description

# %%
from jwst.pipeline import Detector1Pipeline
print(Detector1Pipeline.__doc__)
# Out:
#     Detector1Pipeline: Apply all calibration steps to raw JWST
#     ramps to produce a 2-D slope product. Included steps are:
#     group_scale, dq_init, saturation, ipc, superbias, refpix, rscd,
#     lastframe, linearity, dark_current, persistence, jump detection,
#     ramp_fit, and gain_scale.

# %% [markdown]
# #### run pipeline
# We pass the level 1B files (demo data). The output level 2A files with slopes-per-integration will be saved in the output_dir as '*_rateints.fits'.
#
# As described above, we manually set the array name to what the pipeline expects, ie.:
#
# dm.meta.subarray.name = 'SUBPRISM'
#
# The JCCWG has determined that several steps in the calwebb_detector1 pipeline should not be applied to exposures from Time-Series Observations (TSO). At this time, the steps to be skipped for MIRI TSO exposures are:
#
# ipc
# lastframe

# %%
# set the subarray name here
for f in input_files:
    dm = datamodels.open(f)
    dm.meta.subarray.name = 'SUBPRISM'
    dm_2A = Detector1Pipeline.call(dm, output_use_model=True, save_results=True, output_dir=output_dir, steps={'ipc':{'skip':True},
                                                                                        'lastframe':{'skip':True}})
# Out:
# 2018-05-01 19:51:51,784 - stpipe.Detector1Pipeline - INFO - Detector1Pipeline instance created.
# 2018-05-01 19:51:51,785 - stpipe.Detector1Pipeline.ipc - INFO - IPCStep instance created.
# 2018-05-01 19:51:51,788 - stpipe.Detector1Pipeline.firstframe - INFO - FirstFrameStep instance created.
# 2018-05-01 19:51:51,789 - stpipe.Detector1Pipeline.superbias - INFO - SuperBiasStep instance created.
# 2018-05-01 19:51:51,791 - stpipe.Detector1Pipeline.rscd - INFO - RSCD_Step instance created.
# 2018-05-01 19:51:51,793 - stpipe.Detector1Pipeline.refpix - INFO - RefPixStep instance created.
# 2018-05-01 19:51:51,795 - stpipe.Detector1Pipeline.group_scale - INFO - GroupScaleStep instance created.
# 2018-05-01 19:51:51,797 - stpipe.Detector1Pipeline.dark_current - INFO - DarkCurrentStep instance created.
# 2018-05-01 19:51:51,799 - stpipe.Detector1Pipeline.persistence - INFO - PersistenceStep instance created.
# 2018-05-01 19:51:51,801 - stpipe.Detector1Pipeline.lastframe - INFO - LastFrameStep instance created.
# 2018-05-01 19:51:51,803 - stpipe.Detector1Pipeline.jump - INFO - JumpStep instance created.
# 2018-05-01 19:51:51,805 - stpipe.Detector1Pipeline.ramp_fit - INFO - RampFitStep instance created.
# 2018-05-01 19:51:51,807 - stpipe.Detector1Pipeline.dq_init - INFO - DQInitStep instance created.
# 2018-05-01 19:51:51,808 - stpipe.Detector1Pipeline.linearity - INFO - LinearityStep instance created.
# 2018-05-01 19:51:51,810 - stpipe.Detector1Pipeline.saturation - INFO - SaturationStep instance created.
# 2018-05-01 19:51:51,812 - stpipe.Detector1Pipeline.gain_scale - INFO - GainScaleStep instance created.
# 2018-05-01 19:51:53,777 - stpipe.Detector1Pipeline - INFO - Prefetch for DARK reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_dark_0048.fits'.
# 2018-05-01 19:51:53,779 - stpipe.Detector1Pipeline - INFO - Prefetch for GAIN reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_gain_0008.fits'.
# 2018-05-01 19:51:53,780 - stpipe.Detector1Pipeline - INFO - Prefetch for LINEARITY reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_linearity_0024.fits'.
# 2018-05-01 19:51:53,781 - stpipe.Detector1Pipeline - INFO - Prefetch for MASK reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_mask_0019.fits'.
# 2018-05-01 19:51:53,785 - stpipe.Detector1Pipeline - INFO - Prefetch for PERSAT reference file is 'N/A'.
# 2018-05-01 19:51:53,788 - stpipe.Detector1Pipeline - INFO - Prefetch for READNOISE reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_readnoise_0039.fits'.
# 2018-05-01 19:51:53,789 - stpipe.Detector1Pipeline - INFO - Prefetch for REFPIX reference file is 'N/A'.
# 2018-05-01 19:51:53,790 - stpipe.Detector1Pipeline - INFO - Prefetch for RSCD reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_rscd_0004.fits'.
# 2018-05-01 19:51:53,792 - stpipe.Detector1Pipeline - INFO - Prefetch for SATURATION reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_saturation_0019.fits'.
# 2018-05-01 19:51:53,793 - stpipe.Detector1Pipeline - INFO - Prefetch for SUPERBIAS reference file is 'N/A'.
# 2018-05-01 19:51:53,794 - stpipe.Detector1Pipeline - INFO - Prefetch for TRAPDENSITY reference file is 'N/A'.
# 2018-05-01 19:51:53,795 - stpipe.Detector1Pipeline - INFO - Prefetch for TRAPPARS reference file is 'N/A'.
# 2018-05-01 19:51:53,795 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x1c2cce21d0>,).
# 2018-05-01 19:51:53,797 - stpipe.Detector1Pipeline - INFO - Starting calwebb_detector1 ...
# 2018-05-01 19:51:53,993 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale running with args (<jwst.datamodels.ramp.RampModel object at 0x1c340c3e48>,).
# 2018-05-01 19:51:54,038 - stpipe.Detector1Pipeline.group_scale - WARNING - NFRAMES=1 is a power of 2
# 2018-05-01 19:51:54,039 - stpipe.Detector1Pipeline.group_scale - WARNING - Step will be skipped
# 2018-05-01 19:51:54,041 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale done
# 2018-05-01 19:51:54,128 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init running with args (<jwst.datamodels.ramp.RampModel object at 0x1c340b69b0>,).
# 2018-05-01 19:51:54,174 - stpipe.Detector1Pipeline.dq_init - INFO - Using MASK reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_mask_0019.fits
# 2018-05-01 19:51:54,490 - stpipe.Detector1Pipeline.dq_init - INFO - Extracting mask subarray to match science data
# 2018-05-01 19:51:54,514 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init done
# 2018-05-01 19:51:54,599 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation running with args (<jwst.datamodels.ramp.RampModel object at 0x1c342e4588>,).
# 2018-05-01 19:51:54,645 - stpipe.Detector1Pipeline.saturation - INFO - Using SATURATION reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_saturation_0019.fits
# 2018-05-01 19:51:54,849 - stpipe.Detector1Pipeline.saturation - INFO - Extracting reference file subarray to match science data
# 2018-05-01 19:51:54,909 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation done
# 2018-05-01 19:51:54,991 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc running with args (<jwst.datamodels.ramp.RampModel object at 0x1c2cce2f28>,).
# 2018-05-01 19:51:54,992 - stpipe.Detector1Pipeline.ipc - INFO - Step skipped.
# 2018-05-01 19:51:54,994 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc done
# 2018-05-01 19:51:55,062 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity running with args (<jwst.datamodels.ramp.RampModel object at 0x1c2cce2f28>,).
# 2018-05-01 19:51:55,102 - stpipe.Detector1Pipeline.linearity - INFO - Using Linearity reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_linearity_0024.fits
# 2018-05-01 19:51:55,274 - stpipe.Detector1Pipeline.linearity - INFO - Extracting linearity subarray to match science data
# 2018-05-01 19:51:55,401 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity done
# 2018-05-01 19:51:55,500 - stpipe.Detector1Pipeline.rscd - INFO - Step rscd running with args (<jwst.datamodels.ramp.RampModel object at 0x181e9504a8>,).
# 2018-05-01 19:51:55,542 - stpipe.Detector1Pipeline.rscd - INFO - Using RSCD reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_rscd_0004.fits
# 2018-05-01 19:52:19,946 - stpipe.Detector1Pipeline.rscd - INFO - Step rscd done
# 2018-05-01 19:52:20,041 - stpipe.Detector1Pipeline.firstframe - INFO - Step firstframe running with args (<jwst.datamodels.ramp.RampModel object at 0x1c341d88d0>,).
# 2018-05-01 19:52:20,187 - stpipe.Detector1Pipeline.firstframe - INFO - Step firstframe done
# 2018-05-01 19:52:20,274 - stpipe.Detector1Pipeline.lastframe - INFO - Step lastframe running with args (<jwst.datamodels.ramp.RampModel object at 0x1c2cd3be10>,).
# 2018-05-01 19:52:20,275 - stpipe.Detector1Pipeline.lastframe - INFO - Step skipped.
# 2018-05-01 19:52:20,277 - stpipe.Detector1Pipeline.lastframe - INFO - Step lastframe done
# 2018-05-01 19:52:20,351 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current running with args (<jwst.datamodels.ramp.RampModel object at 0x1c2cd3be10>,).
# 2018-05-01 19:52:20,391 - stpipe.Detector1Pipeline.dark_current - INFO - Using DARK reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_dark_0048.fits
# 2018-05-01 19:52:20,477 - stpipe.Detector1Pipeline.dark_current - INFO - Science data nints=20, ngroups=20, nframes=1, groupgap=0
# 2018-05-01 19:52:20,478 - stpipe.Detector1Pipeline.dark_current - INFO - Dark data nints=2, ngroups=1000, nframes=1, groupgap=0
# 2018-05-01 19:52:20,785 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current done
# 2018-05-01 19:52:20,883 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix running with args (<jwst.datamodels.ramp.RampModel object at 0x1c341de9b0>,).
# 2018-05-01 19:52:20,918 - stpipe.Detector1Pipeline.refpix - INFO - use_side_ref_pixels = True
# 2018-05-01 19:52:20,919 - stpipe.Detector1Pipeline.refpix - INFO - odd_even_columns = True
# 2018-05-01 19:52:20,919 - stpipe.Detector1Pipeline.refpix - INFO - side_smoothing_length = 11
# 2018-05-01 19:52:20,920 - stpipe.Detector1Pipeline.refpix - INFO - side_gain = 1.000000
# 2018-05-01 19:52:20,921 - stpipe.Detector1Pipeline.refpix - INFO - odd_even_rows = True
# 2018-05-01 19:52:21,012 - stpipe.Detector1Pipeline.refpix - INFO - Reference pixel correction disabled for subarray exposures
# 2018-05-01 19:52:21,117 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix done
# 2018-05-01 19:52:21,193 - stpipe.Detector1Pipeline.jump - INFO - Step jump running with args (<jwst.datamodels.ramp.RampModel object at 0x1c34093cf8>,).
# 2018-05-01 19:52:21,230 - stpipe.Detector1Pipeline.jump - INFO - CR rejection threshold = 4 sigma
# 2018-05-01 19:52:21,238 - stpipe.Detector1Pipeline.jump - INFO - Using GAIN reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_gain_0008.fits
# 2018-05-01 19:52:21,283 - stpipe.Detector1Pipeline.jump - INFO - Using READNOISE reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_readnoise_0039.fits
# 2018-05-01 19:52:21,421 - stpipe.Detector1Pipeline.jump - INFO - Extracting gain subarray to match science data
# 2018-05-01 19:52:21,451 - stpipe.Detector1Pipeline.jump - INFO - Executing two-point difference method
# 2018-05-01 19:52:21,544 - stpipe.Detector1Pipeline.jump - INFO -  working on integration 1
# 2018-05-01 19:52:21,576 - stpipe.Detector1Pipeline.jump - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/jump/twopoint_difference.py:83: RuntimeWarning: invalid value encountered in sqrt
#   poisson_noise = np.sqrt(np.abs(med_diffs))
#
# 2018-05-01 19:52:21,959 - stpipe.Detector1Pipeline.jump - INFO -  working on integration 2
# 2018-05-01 19:52:22,346 - stpipe.Detector1Pipeline.jump - INFO -  working on integration 3
# 2018-05-01 19:52:22,751 - stpipe.Detector1Pipeline.jump - INFO -  working on integration 4
# 2018-05-01 19:52:23,170 - stpipe.Detector1Pipeline.jump - INFO -  working on integration 5
# 2018-05-01 19:52:23,618 - stpipe.Detector1Pipeline.jump - INFO -  working on integration 6
# 2018-05-01 19:52:24,039 - stpipe.Detector1Pipeline.jump - INFO -  working on integration 7
# 2018-05-01 19:52:24,415 - stpipe.Detector1Pipeline.jump - INFO -  working on integration 8
# 2018-05-01 19:52:24,808 - stpipe.Detector1Pipeline.jump - INFO -  working on integration 9
# 2018-05-01 19:52:25,181 - stpipe.Detector1Pipeline.jump - INFO -  working on integration 10
# 2018-05-01 19:52:25,578 - stpipe.Detector1Pipeline.jump - INFO -  working on integration 11
# 2018-05-01 19:52:25,964 - stpipe.Detector1Pipeline.jump - INFO -  working on integration 12
# 2018-05-01 19:52:26,357 - stpipe.Detector1Pipeline.jump - INFO -  working on integration 13
# 2018-05-01 19:52:26,764 - stpipe.Detector1Pipeline.jump - INFO -  working on integration 14
# 2018-05-01 19:52:27,147 - stpipe.Detector1Pipeline.jump - INFO -  working on integration 15
# 2018-05-01 19:52:27,544 - stpipe.Detector1Pipeline.jump - INFO -  working on integration 16
# 2018-05-01 19:52:27,960 - stpipe.Detector1Pipeline.jump - INFO -  working on integration 17
# 2018-05-01 19:52:28,340 - stpipe.Detector1Pipeline.jump - INFO -  working on integration 18
# 2018-05-01 19:52:28,749 - stpipe.Detector1Pipeline.jump - INFO -  working on integration 19
# 2018-05-01 19:52:29,139 - stpipe.Detector1Pipeline.jump - INFO -  working on integration 20
# 2018-05-01 19:52:29,541 - stpipe.Detector1Pipeline.jump - INFO - Step jump done
# 2018-05-01 19:52:29,620 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit running with args (<jwst.datamodels.ramp.RampModel object at 0x1c342e23c8>,).
# 2018-05-01 19:52:29,678 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using READNOISE reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_readnoise_0039.fits
# 2018-05-01 19:52:29,735 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using GAIN reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_gain_0008.fits
# 2018-05-01 19:52:29,773 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using algorithm = ols
# 2018-05-01 19:52:29,774 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using weighting = optimal
# 2018-05-01 19:52:29,776 - stpipe.Detector1Pipeline.ramp_fit - INFO - Effective integration time per group: 0.15904
# 2018-05-01 19:52:29,824 - stpipe.Detector1Pipeline.ramp_fit - INFO - Extracting gain subarray to match science data
# 2018-05-01 19:52:30,585 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/utils.py:475: RuntimeWarning: divide by zero encountered in true_divide
#   var_poisson = sum_p / (sum_wgt_p * nsegs_pix)
#
# 2018-05-01 19:52:30,586 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/utils.py:475: RuntimeWarning: invalid value encountered in true_divide
#   var_poisson = sum_p / (sum_wgt_p * nsegs_pix)
#
# 2018-05-01 19:52:30,682 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/utils.py:481: RuntimeWarning: divide by zero encountered in true_divide
#   var_r = rn_1d**2 * 12./(segments**3. - segments)
#
# 2018-05-01 19:52:30,690 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/utils.py:485: RuntimeWarning: divide by zero encountered in true_divide
#   sum_r = (segments*var_r[:]/((nsegs_pix)**3.)).sum(axis=0)
#
# 2018-05-01 19:52:30,692 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/utils.py:485: RuntimeWarning: invalid value encountered in true_divide
#   sum_r = (segments*var_r[:]/((nsegs_pix)**3.)).sum(axis=0)
#
# 2018-05-01 19:52:30,694 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/utils.py:489: RuntimeWarning: divide by zero encountered in true_divide
#   var_readnoise = sum_r/nsegs_pix
#
# 2018-05-01 19:52:30,695 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/utils.py:489: RuntimeWarning: invalid value encountered in true_divide
#   var_readnoise = sum_r/nsegs_pix
#
# 2018-05-01 19:52:46,305 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/ramp_fit.py:324: RuntimeWarning: invalid value encountered in sqrt
#   err_2d_all = np.sqrt( var_p_2d_all + var_r_2d_all )
#
# 2018-05-01 19:52:52,939 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/utils.py:620: RuntimeWarning: invalid value encountered in sqrt
#   cubemod.err = np.sqrt(var_p_int + var_r_int)
#
# 2018-05-01 19:52:52,953 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of groups per integration: 20
# 2018-05-01 19:52:52,954 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of integrations: 20
# 2018-05-01 19:52:53,074 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit done
# 2018-05-01 19:52:53,179 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<jwst.datamodels.image.ImageModel object at 0x1c342f43c8>,).
# 2018-05-01 19:52:53,255 - stpipe.Detector1Pipeline.gain_scale - INFO - GAINFACT not found in gain reference file
# 2018-05-01 19:52:53,256 - stpipe.Detector1Pipeline.gain_scale - INFO - Step will be skipped
# 2018-05-01 19:52:53,260 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# 2018-05-01 19:52:53,346 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<jwst.datamodels.cube.CubeModel object at 0x1c33fc9240>,).
# 2018-05-01 19:52:53,421 - stpipe.Detector1Pipeline.gain_scale - INFO - GAINFACT not found in gain reference file
# 2018-05-01 19:52:53,422 - stpipe.Detector1Pipeline.gain_scale - INFO - Step will be skipped
# 2018-05-01 19:52:53,425 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# 2018-05-01 19:52:53,518 - stpipe.Detector1Pipeline - INFO - Saved model in LRS-SLITLESS_demo_data_pipelined/det_image_1_MIRIMAGE_P750Lexp2_rateints.fits
# 2018-05-01 19:52:53,519 - stpipe.Detector1Pipeline - INFO - ... ending calwebb_detector1
# 2018-05-01 19:52:53,588 - stpipe.Detector1Pipeline - INFO - Saved model in LRS-SLITLESS_demo_data_pipelined/det_image_1_MIRIMAGE_P750Lexp2_rate.fits
# 2018-05-01 19:52:53,589 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline done
# 2018-05-01 19:52:53,762 - stpipe.Detector1Pipeline - INFO - Detector1Pipeline instance created.
# 2018-05-01 19:52:53,764 - stpipe.Detector1Pipeline.ipc - INFO - IPCStep instance created.
# 2018-05-01 19:52:53,766 - stpipe.Detector1Pipeline.firstframe - INFO - FirstFrameStep instance created.
# 2018-05-01 19:52:53,768 - stpipe.Detector1Pipeline.superbias - INFO - SuperBiasStep instance created.
# 2018-05-01 19:52:53,770 - stpipe.Detector1Pipeline.rscd - INFO - RSCD_Step instance created.
# 2018-05-01 19:52:53,772 - stpipe.Detector1Pipeline.refpix - INFO - RefPixStep instance created.
# 2018-05-01 19:52:53,774 - stpipe.Detector1Pipeline.group_scale - INFO - GroupScaleStep instance created.
# 2018-05-01 19:52:53,776 - stpipe.Detector1Pipeline.dark_current - INFO - DarkCurrentStep instance created.
# 2018-05-01 19:52:53,779 - stpipe.Detector1Pipeline.persistence - INFO - PersistenceStep instance created.
# 2018-05-01 19:52:53,780 - stpipe.Detector1Pipeline.lastframe - INFO - LastFrameStep instance created.
# 2018-05-01 19:52:53,782 - stpipe.Detector1Pipeline.jump - INFO - JumpStep instance created.
# 2018-05-01 19:52:53,784 - stpipe.Detector1Pipeline.ramp_fit - INFO - RampFitStep instance created.
# 2018-05-01 19:52:53,787 - stpipe.Detector1Pipeline.dq_init - INFO - DQInitStep instance created.
# 2018-05-01 19:52:53,789 - stpipe.Detector1Pipeline.linearity - INFO - LinearityStep instance created.
# 2018-05-01 19:52:53,792 - stpipe.Detector1Pipeline.saturation - INFO - SaturationStep instance created.
# 2018-05-01 19:52:53,795 - stpipe.Detector1Pipeline.gain_scale - INFO - GainScaleStep instance created.
# 2018-05-01 19:52:53,939 - stpipe.Detector1Pipeline - INFO - Prefetch for DARK reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_dark_0048.fits'.
# 2018-05-01 19:52:53,940 - stpipe.Detector1Pipeline - INFO - Prefetch for GAIN reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_gain_0008.fits'.
# 2018-05-01 19:52:53,941 - stpipe.Detector1Pipeline - INFO - Prefetch for LINEARITY reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_linearity_0024.fits'.
# 2018-05-01 19:52:53,942 - stpipe.Detector1Pipeline - INFO - Prefetch for MASK reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_mask_0019.fits'.
# 2018-05-01 19:52:53,943 - stpipe.Detector1Pipeline - INFO - Prefetch for PERSAT reference file is 'N/A'.
# 2018-05-01 19:52:53,944 - stpipe.Detector1Pipeline - INFO - Prefetch for READNOISE reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_readnoise_0039.fits'.
# 2018-05-01 19:52:53,945 - stpipe.Detector1Pipeline - INFO - Prefetch for REFPIX reference file is 'N/A'.
# 2018-05-01 19:52:53,945 - stpipe.Detector1Pipeline - INFO - Prefetch for RSCD reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_rscd_0004.fits'.
# 2018-05-01 19:52:53,946 - stpipe.Detector1Pipeline - INFO - Prefetch for SATURATION reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_saturation_0019.fits'.
# 2018-05-01 19:52:53,947 - stpipe.Detector1Pipeline - INFO - Prefetch for SUPERBIAS reference file is 'N/A'.
# 2018-05-01 19:52:53,948 - stpipe.Detector1Pipeline - INFO - Prefetch for TRAPDENSITY reference file is 'N/A'.
# 2018-05-01 19:52:53,948 - stpipe.Detector1Pipeline - INFO - Prefetch for TRAPPARS reference file is 'N/A'.
# 2018-05-01 19:52:53,949 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x1c34170320>,).
# 2018-05-01 19:52:53,949 - stpipe.Detector1Pipeline - INFO - Starting calwebb_detector1 ...
# 2018-05-01 19:52:54,072 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale running with args (<jwst.datamodels.ramp.RampModel object at 0x1c34208898>,).
# 2018-05-01 19:52:54,108 - stpipe.Detector1Pipeline.group_scale - WARNING - NFRAMES=1 is a power of 2
# 2018-05-01 19:52:54,109 - stpipe.Detector1Pipeline.group_scale - WARNING - Step will be skipped
# 2018-05-01 19:52:54,111 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale done
# 2018-05-01 19:52:54,195 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init running with args (<jwst.datamodels.ramp.RampModel object at 0x1c2cbedd30>,).
# 2018-05-01 19:52:54,236 - stpipe.Detector1Pipeline.dq_init - INFO - Using MASK reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_mask_0019.fits
# 2018-05-01 19:52:54,454 - stpipe.Detector1Pipeline.dq_init - INFO - Extracting mask subarray to match science data
# 2018-05-01 19:52:54,473 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init done
# 2018-05-01 19:52:54,550 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation running with args (<jwst.datamodels.ramp.RampModel object at 0x1c33fcf160>,).
# 2018-05-01 19:52:54,590 - stpipe.Detector1Pipeline.saturation - INFO - Using SATURATION reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_saturation_0019.fits
# 2018-05-01 19:52:54,782 - stpipe.Detector1Pipeline.saturation - INFO - Extracting reference file subarray to match science data
# 2018-05-01 19:52:54,844 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation done
# 2018-05-01 19:52:54,926 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc running with args (<jwst.datamodels.ramp.RampModel object at 0x1c2cd05278>,).
# 2018-05-01 19:52:54,926 - stpipe.Detector1Pipeline.ipc - INFO - Step skipped.
# 2018-05-01 19:52:54,928 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc done
# 2018-05-01 19:52:55,003 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity running with args (<jwst.datamodels.ramp.RampModel object at 0x1c2cd05278>,).
# 2018-05-01 19:52:55,048 - stpipe.Detector1Pipeline.linearity - INFO - Using Linearity reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_linearity_0024.fits
# 2018-05-01 19:52:55,214 - stpipe.Detector1Pipeline.linearity - INFO - Extracting linearity subarray to match science data
# 2018-05-01 19:52:55,334 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity done
# 2018-05-01 19:52:55,430 - stpipe.Detector1Pipeline.rscd - INFO - Step rscd running with args (<jwst.datamodels.ramp.RampModel object at 0x181e93ab38>,).
# 2018-05-01 19:52:55,472 - stpipe.Detector1Pipeline.rscd - INFO - Using RSCD reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_rscd_0004.fits
# 2018-05-01 19:53:19,659 - stpipe.Detector1Pipeline.rscd - INFO - Step rscd done
# 2018-05-01 19:53:19,739 - stpipe.Detector1Pipeline.firstframe - INFO - Step firstframe running with args (<jwst.datamodels.ramp.RampModel object at 0x1c342f4470>,).
# 2018-05-01 19:53:19,869 - stpipe.Detector1Pipeline.firstframe - INFO - Step firstframe done
# 2018-05-01 19:53:19,957 - stpipe.Detector1Pipeline.lastframe - INFO - Step lastframe running with args (<jwst.datamodels.ramp.RampModel object at 0x1c342f47b8>,).
# 2018-05-01 19:53:19,958 - stpipe.Detector1Pipeline.lastframe - INFO - Step skipped.
# 2018-05-01 19:53:19,960 - stpipe.Detector1Pipeline.lastframe - INFO - Step lastframe done
# 2018-05-01 19:53:20,044 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current running with args (<jwst.datamodels.ramp.RampModel object at 0x1c342f47b8>,).
# 2018-05-01 19:53:20,084 - stpipe.Detector1Pipeline.dark_current - INFO - Using DARK reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_dark_0048.fits
# 2018-05-01 19:53:20,158 - stpipe.Detector1Pipeline.dark_current - INFO - Science data nints=20, ngroups=20, nframes=1, groupgap=0
# 2018-05-01 19:53:20,159 - stpipe.Detector1Pipeline.dark_current - INFO - Dark data nints=2, ngroups=1000, nframes=1, groupgap=0
# 2018-05-01 19:53:20,463 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current done
# 2018-05-01 19:53:20,562 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix running with args (<jwst.datamodels.ramp.RampModel object at 0x1c341f9320>,).
# 2018-05-01 19:53:20,596 - stpipe.Detector1Pipeline.refpix - INFO - use_side_ref_pixels = True
# 2018-05-01 19:53:20,597 - stpipe.Detector1Pipeline.refpix - INFO - odd_even_columns = True
# 2018-05-01 19:53:20,598 - stpipe.Detector1Pipeline.refpix - INFO - side_smoothing_length = 11
# 2018-05-01 19:53:20,598 - stpipe.Detector1Pipeline.refpix - INFO - side_gain = 1.000000
# 2018-05-01 19:53:20,599 - stpipe.Detector1Pipeline.refpix - INFO - odd_even_rows = True
# 2018-05-01 19:53:20,691 - stpipe.Detector1Pipeline.refpix - INFO - Reference pixel correction disabled for subarray exposures
# 2018-05-01 19:53:20,794 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix done
# 2018-05-01 19:53:20,873 - stpipe.Detector1Pipeline.jump - INFO - Step jump running with args (<jwst.datamodels.ramp.RampModel object at 0x181e93d518>,).
# 2018-05-01 19:53:20,908 - stpipe.Detector1Pipeline.jump - INFO - CR rejection threshold = 4 sigma
# 2018-05-01 19:53:20,913 - stpipe.Detector1Pipeline.jump - INFO - Using GAIN reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_gain_0008.fits
# 2018-05-01 19:53:20,958 - stpipe.Detector1Pipeline.jump - INFO - Using READNOISE reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_readnoise_0039.fits
# 2018-05-01 19:53:21,100 - stpipe.Detector1Pipeline.jump - INFO - Extracting gain subarray to match science data
# 2018-05-01 19:53:21,137 - stpipe.Detector1Pipeline.jump - INFO - Executing two-point difference method
# 2018-05-01 19:53:21,238 - stpipe.Detector1Pipeline.jump - INFO -  working on integration 1
# 2018-05-01 19:53:21,649 - stpipe.Detector1Pipeline.jump - INFO -  working on integration 2
# 2018-05-01 19:53:22,068 - stpipe.Detector1Pipeline.jump - INFO -  working on integration 3
# 2018-05-01 19:53:22,499 - stpipe.Detector1Pipeline.jump - INFO -  working on integration 4
# 2018-05-01 19:53:22,882 - stpipe.Detector1Pipeline.jump - INFO -  working on integration 5
# 2018-05-01 19:53:23,270 - stpipe.Detector1Pipeline.jump - INFO -  working on integration 6
# 2018-05-01 19:53:23,676 - stpipe.Detector1Pipeline.jump - INFO -  working on integration 7
# 2018-05-01 19:53:23,696 - stpipe.Detector1Pipeline.jump - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/jump/twopoint_difference.py:83: RuntimeWarning: invalid value encountered in sqrt
#   poisson_noise = np.sqrt(np.abs(med_diffs))
#
# 2018-05-01 19:53:24,077 - stpipe.Detector1Pipeline.jump - INFO -  working on integration 8
# 2018-05-01 19:53:24,461 - stpipe.Detector1Pipeline.jump - INFO -  working on integration 9
# 2018-05-01 19:53:24,862 - stpipe.Detector1Pipeline.jump - INFO -  working on integration 10
# 2018-05-01 19:53:25,265 - stpipe.Detector1Pipeline.jump - INFO -  working on integration 11
# 2018-05-01 19:53:25,647 - stpipe.Detector1Pipeline.jump - INFO -  working on integration 12
# 2018-05-01 19:53:26,039 - stpipe.Detector1Pipeline.jump - INFO -  working on integration 13
# 2018-05-01 19:53:26,414 - stpipe.Detector1Pipeline.jump - INFO -  working on integration 14
# 2018-05-01 19:53:26,803 - stpipe.Detector1Pipeline.jump - INFO -  working on integration 15
# 2018-05-01 19:53:27,224 - stpipe.Detector1Pipeline.jump - INFO -  working on integration 16
# 2018-05-01 19:53:27,615 - stpipe.Detector1Pipeline.jump - INFO -  working on integration 17
# 2018-05-01 19:53:28,002 - stpipe.Detector1Pipeline.jump - INFO -  working on integration 18
# 2018-05-01 19:53:28,428 - stpipe.Detector1Pipeline.jump - INFO -  working on integration 19
# 2018-05-01 19:53:28,828 - stpipe.Detector1Pipeline.jump - INFO -  working on integration 20
# 2018-05-01 19:53:29,241 - stpipe.Detector1Pipeline.jump - INFO - Step jump done
# 2018-05-01 19:53:29,326 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit running with args (<jwst.datamodels.ramp.RampModel object at 0x1c2cd4d8d0>,).
# 2018-05-01 19:53:29,385 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using READNOISE reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_readnoise_0039.fits
# 2018-05-01 19:53:29,435 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using GAIN reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_gain_0008.fits
# 2018-05-01 19:53:29,472 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using algorithm = ols
# 2018-05-01 19:53:29,473 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using weighting = optimal
# 2018-05-01 19:53:29,479 - stpipe.Detector1Pipeline.ramp_fit - INFO - Effective integration time per group: 0.15904
# 2018-05-01 19:53:29,529 - stpipe.Detector1Pipeline.ramp_fit - INFO - Extracting gain subarray to match science data
# 2018-05-01 19:53:30,255 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/utils.py:475: RuntimeWarning: divide by zero encountered in true_divide
#   var_poisson = sum_p / (sum_wgt_p * nsegs_pix)
#
# 2018-05-01 19:53:30,256 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/utils.py:475: RuntimeWarning: invalid value encountered in true_divide
#   var_poisson = sum_p / (sum_wgt_p * nsegs_pix)
#
# 2018-05-01 19:53:30,346 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/utils.py:481: RuntimeWarning: divide by zero encountered in true_divide
#   var_r = rn_1d**2 * 12./(segments**3. - segments)
#
# 2018-05-01 19:53:30,353 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/utils.py:485: RuntimeWarning: divide by zero encountered in true_divide
#   sum_r = (segments*var_r[:]/((nsegs_pix)**3.)).sum(axis=0)
#
# 2018-05-01 19:53:30,354 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/utils.py:485: RuntimeWarning: invalid value encountered in true_divide
#   sum_r = (segments*var_r[:]/((nsegs_pix)**3.)).sum(axis=0)
#
# 2018-05-01 19:53:30,356 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/utils.py:489: RuntimeWarning: divide by zero encountered in true_divide
#   var_readnoise = sum_r/nsegs_pix
#
# 2018-05-01 19:53:30,357 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/utils.py:489: RuntimeWarning: invalid value encountered in true_divide
#   var_readnoise = sum_r/nsegs_pix
#
# 2018-05-01 19:53:45,994 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/ramp_fit.py:324: RuntimeWarning: invalid value encountered in sqrt
#   err_2d_all = np.sqrt( var_p_2d_all + var_r_2d_all )
#
# 2018-05-01 19:53:52,535 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/utils.py:620: RuntimeWarning: invalid value encountered in sqrt
#   cubemod.err = np.sqrt(var_p_int + var_r_int)
#
# 2018-05-01 19:53:52,549 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of groups per integration: 20
# 2018-05-01 19:53:52,550 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of integrations: 20
# 2018-05-01 19:53:52,667 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit done
# 2018-05-01 19:53:52,775 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<jwst.datamodels.image.ImageModel object at 0x1c33fdc4e0>,).
# 2018-05-01 19:53:52,851 - stpipe.Detector1Pipeline.gain_scale - INFO - GAINFACT not found in gain reference file
# 2018-05-01 19:53:52,851 - stpipe.Detector1Pipeline.gain_scale - INFO - Step will be skipped
# 2018-05-01 19:53:52,855 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# 2018-05-01 19:53:52,938 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<jwst.datamodels.cube.CubeModel object at 0x181e8f8e48>,).
# 2018-05-01 19:53:53,013 - stpipe.Detector1Pipeline.gain_scale - INFO - GAINFACT not found in gain reference file
# 2018-05-01 19:53:53,014 - stpipe.Detector1Pipeline.gain_scale - INFO - Step will be skipped
# 2018-05-01 19:53:53,018 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# 2018-05-01 19:53:53,099 - stpipe.Detector1Pipeline - INFO - Saved model in LRS-SLITLESS_demo_data_pipelined/det_image_1_MIRIMAGE_P750Lexp3_rateints.fits
# 2018-05-01 19:53:53,100 - stpipe.Detector1Pipeline - INFO - ... ending calwebb_detector1
# 2018-05-01 19:53:53,170 - stpipe.Detector1Pipeline - INFO - Saved model in LRS-SLITLESS_demo_data_pipelined/det_image_1_MIRIMAGE_P750Lexp3_rate.fits
# 2018-05-01 19:53:53,170 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline done
# 2018-05-01 19:53:53,342 - stpipe.Detector1Pipeline - INFO - Detector1Pipeline instance created.
# 2018-05-01 19:53:53,344 - stpipe.Detector1Pipeline.ipc - INFO - IPCStep instance created.
# 2018-05-01 19:53:53,345 - stpipe.Detector1Pipeline.firstframe - INFO - FirstFrameStep instance created.
# 2018-05-01 19:53:53,347 - stpipe.Detector1Pipeline.superbias - INFO - SuperBiasStep instance created.
# 2018-05-01 19:53:53,348 - stpipe.Detector1Pipeline.rscd - INFO - RSCD_Step instance created.
# 2018-05-01 19:53:53,350 - stpipe.Detector1Pipeline.refpix - INFO - RefPixStep instance created.
# 2018-05-01 19:53:53,352 - stpipe.Detector1Pipeline.group_scale - INFO - GroupScaleStep instance created.
# 2018-05-01 19:53:53,353 - stpipe.Detector1Pipeline.dark_current - INFO - DarkCurrentStep instance created.
# 2018-05-01 19:53:53,355 - stpipe.Detector1Pipeline.persistence - INFO - PersistenceStep instance created.
# 2018-05-01 19:53:53,357 - stpipe.Detector1Pipeline.lastframe - INFO - LastFrameStep instance created.
# 2018-05-01 19:53:53,359 - stpipe.Detector1Pipeline.jump - INFO - JumpStep instance created.
# 2018-05-01 19:53:53,361 - stpipe.Detector1Pipeline.ramp_fit - INFO - RampFitStep instance created.
# 2018-05-01 19:53:53,362 - stpipe.Detector1Pipeline.dq_init - INFO - DQInitStep instance created.
# 2018-05-01 19:53:53,364 - stpipe.Detector1Pipeline.linearity - INFO - LinearityStep instance created.
# 2018-05-01 19:53:53,366 - stpipe.Detector1Pipeline.saturation - INFO - SaturationStep instance created.
# 2018-05-01 19:53:53,368 - stpipe.Detector1Pipeline.gain_scale - INFO - GainScaleStep instance created.
# 2018-05-01 19:53:53,496 - stpipe.Detector1Pipeline - INFO - Prefetch for DARK reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_dark_0048.fits'.
# 2018-05-01 19:53:53,497 - stpipe.Detector1Pipeline - INFO - Prefetch for GAIN reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_gain_0008.fits'.
# 2018-05-01 19:53:53,498 - stpipe.Detector1Pipeline - INFO - Prefetch for LINEARITY reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_linearity_0024.fits'.
# 2018-05-01 19:53:53,501 - stpipe.Detector1Pipeline - INFO - Prefetch for MASK reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_mask_0019.fits'.
# 2018-05-01 19:53:53,502 - stpipe.Detector1Pipeline - INFO - Prefetch for PERSAT reference file is 'N/A'.
# 2018-05-01 19:53:53,502 - stpipe.Detector1Pipeline - INFO - Prefetch for READNOISE reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_readnoise_0039.fits'.
# 2018-05-01 19:53:53,503 - stpipe.Detector1Pipeline - INFO - Prefetch for REFPIX reference file is 'N/A'.
# 2018-05-01 19:53:53,504 - stpipe.Detector1Pipeline - INFO - Prefetch for RSCD reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_rscd_0004.fits'.
# 2018-05-01 19:53:53,505 - stpipe.Detector1Pipeline - INFO - Prefetch for SATURATION reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_saturation_0019.fits'.
# 2018-05-01 19:53:53,506 - stpipe.Detector1Pipeline - INFO - Prefetch for SUPERBIAS reference file is 'N/A'.
# 2018-05-01 19:53:53,507 - stpipe.Detector1Pipeline - INFO - Prefetch for TRAPDENSITY reference file is 'N/A'.
# 2018-05-01 19:53:53,507 - stpipe.Detector1Pipeline - INFO - Prefetch for TRAPPARS reference file is 'N/A'.
# 2018-05-01 19:53:53,508 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x1c33fc99b0>,).
# 2018-05-01 19:53:53,509 - stpipe.Detector1Pipeline - INFO - Starting calwebb_detector1 ...
# 2018-05-01 19:53:53,621 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale running with args (<jwst.datamodels.ramp.RampModel object at 0x181e93afd0>,).
# 2018-05-01 19:53:53,656 - stpipe.Detector1Pipeline.group_scale - WARNING - NFRAMES=1 is a power of 2
# 2018-05-01 19:53:53,657 - stpipe.Detector1Pipeline.group_scale - WARNING - Step will be skipped
# 2018-05-01 19:53:53,659 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale done
# 2018-05-01 19:53:53,733 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init running with args (<jwst.datamodels.ramp.RampModel object at 0x1c340a6470>,).
# 2018-05-01 19:53:53,773 - stpipe.Detector1Pipeline.dq_init - INFO - Using MASK reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_mask_0019.fits
# 2018-05-01 19:53:53,988 - stpipe.Detector1Pipeline.dq_init - INFO - Extracting mask subarray to match science data
# 2018-05-01 19:53:54,009 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init done
# 2018-05-01 19:53:54,085 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation running with args (<jwst.datamodels.ramp.RampModel object at 0x10f98c668>,).
# 2018-05-01 19:53:54,125 - stpipe.Detector1Pipeline.saturation - INFO - Using SATURATION reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_saturation_0019.fits
# 2018-05-01 19:53:54,314 - stpipe.Detector1Pipeline.saturation - INFO - Extracting reference file subarray to match science data
# 2018-05-01 19:53:54,373 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation done
# 2018-05-01 19:53:54,461 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc running with args (<jwst.datamodels.ramp.RampModel object at 0x1c341f07b8>,).
# 2018-05-01 19:53:54,462 - stpipe.Detector1Pipeline.ipc - INFO - Step skipped.
# 2018-05-01 19:53:54,464 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc done
# 2018-05-01 19:53:54,540 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity running with args (<jwst.datamodels.ramp.RampModel object at 0x1c341f07b8>,).
# 2018-05-01 19:53:54,582 - stpipe.Detector1Pipeline.linearity - INFO - Using Linearity reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_linearity_0024.fits
# 2018-05-01 19:53:54,745 - stpipe.Detector1Pipeline.linearity - INFO - Extracting linearity subarray to match science data
# 2018-05-01 19:53:54,864 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity done
# 2018-05-01 19:53:54,966 - stpipe.Detector1Pipeline.rscd - INFO - Step rscd running with args (<jwst.datamodels.ramp.RampModel object at 0x1c33fd2e10>,).
# 2018-05-01 19:53:55,011 - stpipe.Detector1Pipeline.rscd - INFO - Using RSCD reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_rscd_0004.fits
# 2018-05-01 19:54:18,487 - stpipe.Detector1Pipeline.rscd - INFO - Step rscd done
# 2018-05-01 19:54:18,582 - stpipe.Detector1Pipeline.firstframe - INFO - Step firstframe running with args (<jwst.datamodels.ramp.RampModel object at 0x1c3427ba90>,).
# 2018-05-01 19:54:18,719 - stpipe.Detector1Pipeline.firstframe - INFO - Step firstframe done
# 2018-05-01 19:54:18,805 - stpipe.Detector1Pipeline.lastframe - INFO - Step lastframe running with args (<jwst.datamodels.ramp.RampModel object at 0x1c342c34e0>,).
# 2018-05-01 19:54:18,806 - stpipe.Detector1Pipeline.lastframe - INFO - Step skipped.
# 2018-05-01 19:54:18,808 - stpipe.Detector1Pipeline.lastframe - INFO - Step lastframe done
# 2018-05-01 19:54:18,886 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current running with args (<jwst.datamodels.ramp.RampModel object at 0x1c342c34e0>,).
# 2018-05-01 19:54:18,926 - stpipe.Detector1Pipeline.dark_current - INFO - Using DARK reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_dark_0048.fits
# 2018-05-01 19:54:18,999 - stpipe.Detector1Pipeline.dark_current - INFO - Science data nints=20, ngroups=20, nframes=1, groupgap=0
# 2018-05-01 19:54:19,000 - stpipe.Detector1Pipeline.dark_current - INFO - Dark data nints=2, ngroups=1000, nframes=1, groupgap=0
# 2018-05-01 19:54:19,319 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current done
# 2018-05-01 19:54:19,409 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix running with args (<jwst.datamodels.ramp.RampModel object at 0x1c33fd2780>,).
# 2018-05-01 19:54:19,445 - stpipe.Detector1Pipeline.refpix - INFO - use_side_ref_pixels = True
# 2018-05-01 19:54:19,446 - stpipe.Detector1Pipeline.refpix - INFO - odd_even_columns = True
# 2018-05-01 19:54:19,446 - stpipe.Detector1Pipeline.refpix - INFO - side_smoothing_length = 11
# 2018-05-01 19:54:19,447 - stpipe.Detector1Pipeline.refpix - INFO - side_gain = 1.000000
# 2018-05-01 19:54:19,448 - stpipe.Detector1Pipeline.refpix - INFO - odd_even_rows = True
# 2018-05-01 19:54:19,539 - stpipe.Detector1Pipeline.refpix - INFO - Reference pixel correction disabled for subarray exposures
# 2018-05-01 19:54:19,666 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix done
# 2018-05-01 19:54:19,757 - stpipe.Detector1Pipeline.jump - INFO - Step jump running with args (<jwst.datamodels.ramp.RampModel object at 0x10f984ac8>,).
# 2018-05-01 19:54:19,791 - stpipe.Detector1Pipeline.jump - INFO - CR rejection threshold = 4 sigma
# 2018-05-01 19:54:19,798 - stpipe.Detector1Pipeline.jump - INFO - Using GAIN reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_gain_0008.fits
# 2018-05-01 19:54:19,840 - stpipe.Detector1Pipeline.jump - INFO - Using READNOISE reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_readnoise_0039.fits
# 2018-05-01 19:54:19,975 - stpipe.Detector1Pipeline.jump - INFO - Extracting gain subarray to match science data
# 2018-05-01 19:54:20,006 - stpipe.Detector1Pipeline.jump - INFO - Executing two-point difference method
# 2018-05-01 19:54:20,099 - stpipe.Detector1Pipeline.jump - INFO -  working on integration 1
# 2018-05-01 19:54:20,485 - stpipe.Detector1Pipeline.jump - INFO -  working on integration 2
# 2018-05-01 19:54:20,509 - stpipe.Detector1Pipeline.jump - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/jump/twopoint_difference.py:83: RuntimeWarning: invalid value encountered in sqrt
#   poisson_noise = np.sqrt(np.abs(med_diffs))
#
# 2018-05-01 19:54:20,892 - stpipe.Detector1Pipeline.jump - INFO -  working on integration 3
# 2018-05-01 19:54:21,278 - stpipe.Detector1Pipeline.jump - INFO -  working on integration 4
# 2018-05-01 19:54:21,655 - stpipe.Detector1Pipeline.jump - INFO -  working on integration 5
# 2018-05-01 19:54:22,025 - stpipe.Detector1Pipeline.jump - INFO -  working on integration 6
# 2018-05-01 19:54:22,402 - stpipe.Detector1Pipeline.jump - INFO -  working on integration 7
# 2018-05-01 19:54:22,776 - stpipe.Detector1Pipeline.jump - INFO -  working on integration 8
# 2018-05-01 19:54:23,157 - stpipe.Detector1Pipeline.jump - INFO -  working on integration 9
# 2018-05-01 19:54:23,527 - stpipe.Detector1Pipeline.jump - INFO -  working on integration 10
# 2018-05-01 19:54:23,912 - stpipe.Detector1Pipeline.jump - INFO -  working on integration 11
# 2018-05-01 19:54:24,302 - stpipe.Detector1Pipeline.jump - INFO -  working on integration 12
# 2018-05-01 19:54:24,677 - stpipe.Detector1Pipeline.jump - INFO -  working on integration 13
# 2018-05-01 19:54:25,059 - stpipe.Detector1Pipeline.jump - INFO -  working on integration 14
# 2018-05-01 19:54:25,437 - stpipe.Detector1Pipeline.jump - INFO -  working on integration 15
# 2018-05-01 19:54:25,818 - stpipe.Detector1Pipeline.jump - INFO -  working on integration 16
# 2018-05-01 19:54:26,189 - stpipe.Detector1Pipeline.jump - INFO -  working on integration 17
# 2018-05-01 19:54:26,563 - stpipe.Detector1Pipeline.jump - INFO -  working on integration 18
# 2018-05-01 19:54:26,936 - stpipe.Detector1Pipeline.jump - INFO -  working on integration 19
# 2018-05-01 19:54:27,314 - stpipe.Detector1Pipeline.jump - INFO -  working on integration 20
# 2018-05-01 19:54:27,728 - stpipe.Detector1Pipeline.jump - INFO - Step jump done
# 2018-05-01 19:54:27,816 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit running with args (<jwst.datamodels.ramp.RampModel object at 0x1c341e2ef0>,).
# 2018-05-01 19:54:27,878 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using READNOISE reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_readnoise_0039.fits
# 2018-05-01 19:54:27,931 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using GAIN reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_gain_0008.fits
# 2018-05-01 19:54:27,966 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using algorithm = ols
# 2018-05-01 19:54:27,966 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using weighting = optimal
# 2018-05-01 19:54:27,969 - stpipe.Detector1Pipeline.ramp_fit - INFO - Effective integration time per group: 0.15904
# 2018-05-01 19:54:28,012 - stpipe.Detector1Pipeline.ramp_fit - INFO - Extracting gain subarray to match science data
# 2018-05-01 19:54:28,746 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/utils.py:475: RuntimeWarning: divide by zero encountered in true_divide
#   var_poisson = sum_p / (sum_wgt_p * nsegs_pix)
#
# 2018-05-01 19:54:28,747 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/utils.py:475: RuntimeWarning: invalid value encountered in true_divide
#   var_poisson = sum_p / (sum_wgt_p * nsegs_pix)
#
# 2018-05-01 19:54:28,837 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/utils.py:481: RuntimeWarning: divide by zero encountered in true_divide
#   var_r = rn_1d**2 * 12./(segments**3. - segments)
#
# 2018-05-01 19:54:28,844 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/utils.py:485: RuntimeWarning: divide by zero encountered in true_divide
#   sum_r = (segments*var_r[:]/((nsegs_pix)**3.)).sum(axis=0)
#
# 2018-05-01 19:54:28,844 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/utils.py:485: RuntimeWarning: invalid value encountered in true_divide
#   sum_r = (segments*var_r[:]/((nsegs_pix)**3.)).sum(axis=0)
#
# 2018-05-01 19:54:28,847 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/utils.py:489: RuntimeWarning: divide by zero encountered in true_divide
#   var_readnoise = sum_r/nsegs_pix
#
# 2018-05-01 19:54:28,848 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/utils.py:489: RuntimeWarning: invalid value encountered in true_divide
#   var_readnoise = sum_r/nsegs_pix
# 2018-05-01 19:54:44,161 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/ramp_fit.py:324: RuntimeWarning: invalid value encountered in sqrt
#   err_2d_all = np.sqrt( var_p_2d_all + var_r_2d_all )
#
# 2018-05-01 19:54:50,649 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/utils.py:620: RuntimeWarning: invalid value encountered in sqrt
#   cubemod.err = np.sqrt(var_p_int + var_r_int)
#
# 2018-05-01 19:54:50,663 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of groups per integration: 20
# 2018-05-01 19:54:50,664 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of integrations: 20
# 2018-05-01 19:54:50,780 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit done
# 2018-05-01 19:54:50,887 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<jwst.datamodels.image.ImageModel object at 0x1c2ccb6550>,).
# 2018-05-01 19:54:50,964 - stpipe.Detector1Pipeline.gain_scale - INFO - GAINFACT not found in gain reference file
# 2018-05-01 19:54:50,964 - stpipe.Detector1Pipeline.gain_scale - INFO - Step will be skipped
# 2018-05-01 19:54:50,968 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# 2018-05-01 19:54:51,047 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<jwst.datamodels.cube.CubeModel object at 0x110620128>,).
# 2018-05-01 19:54:51,121 - stpipe.Detector1Pipeline.gain_scale - INFO - GAINFACT not found in gain reference file
# 2018-05-01 19:54:51,122 - stpipe.Detector1Pipeline.gain_scale - INFO - Step will be skipped
# 2018-05-01 19:54:51,126 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# 2018-05-01 19:54:51,205 - stpipe.Detector1Pipeline - INFO - Saved model in LRS-SLITLESS_demo_data_pipelined/det_image_1_MIRIMAGE_P750Lexp1_rateints.fits
# 2018-05-01 19:54:51,206 - stpipe.Detector1Pipeline - INFO - ... ending calwebb_detector1
# 2018-05-01 19:54:51,275 - stpipe.Detector1Pipeline - INFO - Saved model in LRS-SLITLESS_demo_data_pipelined/det_image_1_MIRIMAGE_P750Lexp1_rate.fits
# 2018-05-01 19:54:51,276 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline done

# %% [markdown]
# #### Quick check of the pipeline steps applied in the output:

# %%
level2A_files = glob.glob(os.path.join(output_dir,'*_rateints.fits'))

with datamodels.open(level2A_files[0]) as dm:
    # check the calibration step information
    print('Check step information status:')
    print('dq_init: %s' % dm.meta.cal_step.dq_init)
    print('saturation: %s' % dm.meta.cal_step.saturation)
    print('linearity: %s' % dm.meta.cal_step.linearity)
    print('rscd: %s' % dm.meta.cal_step.rscd)
    print('lastframe: %s' % dm.meta.cal_step.lastframe)
    print('dark_current: %s' % dm.meta.cal_step.dark_sub)
    print('jump: %s' % dm.meta.cal_step.jump)
    print('ramp_fit: %s' % dm.meta.cal_step.ramp_fit)
# Out:
# Check step information status:
# dq_init: COMPLETE
# saturation: COMPLETE
# linearity: COMPLETE
# rscd: COMPLETE
# lastframe: None
# dark_current: COMPLETE
# jump: COMPLETE
# ramp_fit: COMPLETE

# %% [markdown]
# ### Level 2B pipeline

# %% [markdown]
# #### import the level 2B pipeline class and print description

# %%
from jwst.pipeline import Spec2Pipeline
print(Spec2Pipeline.__doc__)
# Out:
#     Spec2Pipeline: Processes JWST spectroscopic exposures from Level 2a to 2b.
#     Accepts a single exposure or an association as input.
#
#     Included steps are:
#     assign_wcs, background subtraction, NIRSpec MSA imprint subtraction,
#     NIRSpec MSA bad shutter flagging, 2-D subwindow extraction, flat field,
#     source type decision, straylight, fringe, pathloss, barshadow,  photom,
#     resample_spec, cube_build, and extract_1d.

# %% [markdown]
# #### run pipeline
# We pass each of the 'rateints.fits' files to the Spec2Pipeline and the outputs are saved in the 'calints.fits' files. We will also save the spectra extracted from each integration for each exposure ('x1dints.fits files).

# %%
for f in level2A_files:
    Spec2Pipeline.call(f, output_use_model=True, save_results=True, output_dir=output_dir, steps={'extract_1d':{'save_results':True}})
# Out:
# 2018-05-01 19:54:51,468 - stpipe.Spec2Pipeline - INFO - Spec2Pipeline instance created.
# 2018-05-01 19:54:51,471 - stpipe.Spec2Pipeline.barshadow - INFO - BarShadowStep instance created.
# 2018-05-01 19:54:51,473 - stpipe.Spec2Pipeline.msa_flagging - INFO - MSAFlagOpenStep instance created.
# 2018-05-01 19:54:51,474 - stpipe.Spec2Pipeline.bkg_subtract - INFO - BackgroundStep instance created.
# 2018-05-01 19:54:51,478 - stpipe.Spec2Pipeline.cube_build - INFO - CubeBuildStep instance created.
# 2018-05-01 19:54:51,479 - stpipe.Spec2Pipeline.extract_1d - INFO - Extract1dStep instance created.
# 2018-05-01 19:54:51,481 - stpipe.Spec2Pipeline.assign_wcs - INFO - AssignWcsStep instance created.
# 2018-05-01 19:54:51,483 - stpipe.Spec2Pipeline.straylight - INFO - StraylightStep instance created.
# 2018-05-01 19:54:51,485 - stpipe.Spec2Pipeline.pathloss - INFO - PathLossStep instance created.
# 2018-05-01 19:54:51,486 - stpipe.Spec2Pipeline.srctype - INFO - SourceTypeStep instance created.
# 2018-05-01 19:54:51,488 - stpipe.Spec2Pipeline.photom - INFO - PhotomStep instance created.
# 2018-05-01 19:54:51,490 - stpipe.Spec2Pipeline.resample_spec - INFO - ResampleSpecStep instance created.
# 2018-05-01 19:54:51,492 - stpipe.Spec2Pipeline.fringe - INFO - FringeStep instance created.
# 2018-05-01 19:54:51,494 - stpipe.Spec2Pipeline.flat_field - INFO - FlatFieldStep instance created.
# 2018-05-01 19:54:51,496 - stpipe.Spec2Pipeline.imprint_subtract - INFO - ImprintStep instance created.
# 2018-05-01 19:54:51,498 - stpipe.Spec2Pipeline.extract_2d - INFO - Extract2dStep instance created.
# 2018-05-01 19:54:51,784 - stpipe.Spec2Pipeline - INFO - Prefetch for AREA reference file is 'N/A'.
# 2018-05-01 19:54:51,785 - stpipe.Spec2Pipeline - INFO - Prefetch for BARSHADOW reference file is 'N/A'.
# 2018-05-01 19:54:51,786 - stpipe.Spec2Pipeline - INFO - Prefetch for CAMERA reference file is 'N/A'.
# 2018-05-01 19:54:51,787 - stpipe.Spec2Pipeline - INFO - Prefetch for COLLIMATOR reference file is 'N/A'.
# 2018-05-01 19:54:51,787 - stpipe.Spec2Pipeline - INFO - Prefetch for CUBEPAR reference file is 'N/A'.
# 2018-05-01 19:54:51,788 - stpipe.Spec2Pipeline - INFO - Prefetch for DFLAT reference file is 'N/A'.
# 2018-05-01 19:54:51,789 - stpipe.Spec2Pipeline - INFO - Prefetch for DISPERSER reference file is 'N/A'.
# 2018-05-01 19:54:51,790 - stpipe.Spec2Pipeline - INFO - Prefetch for DISTORTION reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_distortion_0023.asdf'.
# 2018-05-01 19:54:51,791 - stpipe.Spec2Pipeline - INFO - Prefetch for DRIZPARS reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_drizpars_0001.fits'.
# 2018-05-01 19:54:51,793 - stpipe.Spec2Pipeline - INFO - Prefetch for EXTRACT1D reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_extract1d_0004.json'.
# 2018-05-01 19:54:51,794 - stpipe.Spec2Pipeline - INFO - Prefetch for FFLAT reference file is 'N/A'.
# 2018-05-01 19:54:51,794 - stpipe.Spec2Pipeline - INFO - Prefetch for FILTEROFFSET reference file is 'N/A'.
# 2018-05-01 19:54:51,795 - stpipe.Spec2Pipeline - INFO - Prefetch for FLAT reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_flat_0245.fits'.
# 2018-05-01 19:54:51,796 - stpipe.Spec2Pipeline - INFO - Prefetch for FORE reference file is 'N/A'.
# 2018-05-01 19:54:51,796 - stpipe.Spec2Pipeline - INFO - Prefetch for FPA reference file is 'N/A'.
# 2018-05-01 19:54:51,797 - stpipe.Spec2Pipeline - INFO - Prefetch for FRINGE reference file is 'N/A'.
# 2018-05-01 19:54:51,798 - stpipe.Spec2Pipeline - INFO - Prefetch for IFUFORE reference file is 'N/A'.
# 2018-05-01 19:54:51,798 - stpipe.Spec2Pipeline - INFO - Prefetch for IFUPOST reference file is 'N/A'.
# 2018-05-01 19:54:51,799 - stpipe.Spec2Pipeline - INFO - Prefetch for IFUSLICER reference file is 'N/A'.
# 2018-05-01 19:54:51,800 - stpipe.Spec2Pipeline - INFO - Prefetch for MSA reference file is 'N/A'.
# 2018-05-01 19:54:51,801 - stpipe.Spec2Pipeline - INFO - Prefetch for MSAOPER reference file is 'N/A'.
# 2018-05-01 19:54:51,802 - stpipe.Spec2Pipeline - INFO - Prefetch for OTE reference file is 'N/A'.
# 2018-05-01 19:54:51,802 - stpipe.Spec2Pipeline - INFO - Prefetch for PATHLOSS reference file is 'N/A'.
# 2018-05-01 19:54:51,803 - stpipe.Spec2Pipeline - INFO - Prefetch for PHOTOM reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_photom_0014.fits'.
# 2018-05-01 19:54:51,804 - stpipe.Spec2Pipeline - INFO - Prefetch for REGIONS reference file is 'N/A'.
# 2018-05-01 19:54:51,805 - stpipe.Spec2Pipeline - INFO - Prefetch for RESOL reference file is 'N/A'.
# 2018-05-01 19:54:51,805 - stpipe.Spec2Pipeline - INFO - Prefetch for SFLAT reference file is 'N/A'.
# 2018-05-01 19:54:51,806 - stpipe.Spec2Pipeline - INFO - Prefetch for SPECWCS reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_specwcs_0001.fits'.
# 2018-05-01 19:54:51,807 - stpipe.Spec2Pipeline - INFO - Prefetch for STRAYMASK reference file is 'N/A'.
# 2018-05-01 19:54:51,808 - stpipe.Spec2Pipeline - INFO - Prefetch for WAVECORR reference file is 'N/A'.
# 2018-05-01 19:54:51,809 - stpipe.Spec2Pipeline - INFO - Prefetch for WAVELENGTHRANGE reference file is 'N/A'.
# 2018-05-01 19:54:51,810 - stpipe.Spec2Pipeline - INFO - Step Spec2Pipeline running with args ('LRS-SLITLESS_demo_data_pipelined/det_image_1_MIRIMAGE_P750Lexp3_rateints.fits',).
# 2018-05-01 19:54:51,810 - stpipe.Spec2Pipeline - INFO - Starting calwebb_spec2 ...
# 2018-05-01 19:54:52,172 - stpipe.Spec2Pipeline - INFO - Processing product LRS-SLITLESS_demo_data_pipelined/det_image_1_MIRIMAGE_P750Lexp3
# 2018-05-01 19:54:52,172 - stpipe.Spec2Pipeline - INFO - Working on input LRS-SLITLESS_demo_data_pipelined/det_image_1_MIRIMAGE_P750Lexp3_rateints.fits ...
# 2018-05-01 19:54:52,410 - stpipe.Spec2Pipeline.assign_wcs - INFO - Step assign_wcs running with args (<jwst.datamodels.cube.CubeModel object at 0x1c2cce8eb8>,).
# 2018-05-01 19:54:53,727 - stpipe.Spec2Pipeline.assign_wcs - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/assign_wcs/util.py:559: RuntimeWarning: invalid value encountered in less
#   negative_ind = footprint[0] < 0
#
# 2018-05-01 19:54:53,727 - stpipe.Spec2Pipeline.assign_wcs - INFO - There are NaNs in s_region
# 2018-05-01 19:54:53,728 - stpipe.Spec2Pipeline.assign_wcs - INFO - COMPLETED assign_wcs
# 2018-05-01 19:54:53,738 - stpipe.Spec2Pipeline.assign_wcs - INFO - Step assign_wcs done
# 2018-05-01 19:54:53,821 - stpipe.Spec2Pipeline.flat_field - INFO - Step flat_field running with args (<jwst.datamodels.cube.CubeModel object at 0x1c2cd31198>,).
# 2018-05-01 19:54:53,918 - stpipe.Spec2Pipeline.flat_field - WARNING - Keyword CDP_PARTIAL_DATA does not correspond to an existing DQ mnemonic, so will be ignored
# 2018-05-01 19:54:53,919 - stpipe.Spec2Pipeline.flat_field - WARNING - Keyword CDP_LOW_QUAL does not correspond to an existing DQ mnemonic, so will be ignored
# 2018-05-01 19:54:53,920 - stpipe.Spec2Pipeline.flat_field - WARNING - Keyword CDP_UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2018-05-01 19:54:53,921 - stpipe.Spec2Pipeline.flat_field - WARNING - Keyword DIFF_PATTERN does not correspond to an existing DQ mnemonic, so will be ignored
# 2018-05-01 19:54:54,027 - stpipe.Spec2Pipeline.flat_field - INFO - Step flat_field done
# 2018-05-01 19:54:54,111 - stpipe.Spec2Pipeline.srctype - INFO - Step srctype running with args (<jwst.datamodels.cube.CubeModel object at 0x1106168d0>,).
# 2018-05-01 19:54:54,146 - stpipe.Spec2Pipeline.srctype - INFO - Input EXP_TYPE is MIR_LRS-SLITLESS
# 2018-05-01 19:54:54,147 - stpipe.Spec2Pipeline.srctype - INFO - Input SRCTYPE is unknown. Setting to default value of POINT
# 2018-05-01 19:54:54,150 - stpipe.Spec2Pipeline.srctype - INFO - Step srctype done
# 2018-05-01 19:54:54,232 - stpipe.Spec2Pipeline.photom - INFO - Step photom running with args (<jwst.datamodels.cube.CubeModel object at 0x1c341ec320>,).
# 2018-05-01 19:54:54,272 - stpipe.Spec2Pipeline.photom - INFO - Using photom reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_photom_0014.fits
# 2018-05-01 19:54:54,277 - stpipe.Spec2Pipeline.photom - INFO - Using area reference file: N/A
# 2018-05-01 19:54:54,278 - stpipe.Spec2Pipeline.photom - INFO - Using instrument: MIRI
# 2018-05-01 19:54:54,278 - stpipe.Spec2Pipeline.photom - INFO -  detector: MIRIMAGE
# 2018-05-01 19:54:54,279 - stpipe.Spec2Pipeline.photom - INFO -  exp_type: MIR_LRS-SLITLESS
# 2018-05-01 19:54:54,280 - stpipe.Spec2Pipeline.photom - INFO -  filter: P750L
# 2018-05-01 19:54:54,351 - stpipe.Spec2Pipeline.photom - INFO -  subarray: SUBPRISM
# 2018-05-01 19:54:54,354 - stpipe.Spec2Pipeline.photom - INFO - PHOTMJSR value: 1
# 2018-05-01 19:54:54,358 - stpipe.Spec2Pipeline.photom - INFO - Storing relative response table
# 2018-05-01 19:54:54,364 - stpipe.Spec2Pipeline.photom - INFO - Step photom done
# 2018-05-01 19:54:54,448 - stpipe.Spec2Pipeline.extract_1d - INFO - Step extract_1d running with args (<jwst.datamodels.cube.CubeModel object at 0x1c341ec550>,).
# 2018-05-01 19:54:54,488 - stpipe.Spec2Pipeline.extract_1d - INFO - Using EXTRACT1D reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_extract1d_0004.json
# 2018-05-01 19:54:54,537 - stpipe.Spec2Pipeline.extract_1d - WARNING - spectral_order is None; using 1
# 2018-05-01 19:54:54,581 - stpipe.Spec2Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:54:54,712 - stpipe.Spec2Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:54:54,842 - stpipe.Spec2Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:54:54,977 - stpipe.Spec2Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:54:55,115 - stpipe.Spec2Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:54:55,248 - stpipe.Spec2Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:54:55,380 - stpipe.Spec2Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:54:55,510 - stpipe.Spec2Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:54:55,638 - stpipe.Spec2Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:54:55,770 - stpipe.Spec2Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:54:55,903 - stpipe.Spec2Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:54:56,034 - stpipe.Spec2Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:54:56,163 - stpipe.Spec2Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:54:56,293 - stpipe.Spec2Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:54:56,431 - stpipe.Spec2Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:54:56,704 - stpipe.Spec2Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:54:56,832 - stpipe.Spec2Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:54:56,959 - stpipe.Spec2Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:54:57,088 - stpipe.Spec2Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:54:57,219 - stpipe.Spec2Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:54:58,026 - stpipe.Spec2Pipeline.extract_1d - INFO - Saved model in LRS-SLITLESS_demo_data_pipelined/det_image_1_MIRIMAGE_P750Lexp3_x1dints.fits
# 2018-05-01 19:54:58,027 - stpipe.Spec2Pipeline.extract_1d - INFO - Step extract_1d done
# 2018-05-01 19:54:58,028 - stpipe.Spec2Pipeline - INFO - Finished processing product LRS-SLITLESS_demo_data_pipelined/det_image_1_MIRIMAGE_P750Lexp3
# 2018-05-01 19:54:58,184 - stpipe.Spec2Pipeline - INFO - Saved model in LRS-SLITLESS_demo_data_pipelined/det_image_1_MIRIMAGE_P750Lexp3_calints.fits
# 2018-05-01 19:54:58,297 - stpipe.Spec2Pipeline - INFO - Ending calwebb_spec2
# 2018-05-01 19:54:58,299 - stpipe.Spec2Pipeline - INFO - Step Spec2Pipeline done
# 2018-05-01 19:54:58,314 - stpipe.Spec2Pipeline - INFO - Spec2Pipeline instance created.
# 2018-05-01 19:54:58,316 - stpipe.Spec2Pipeline.barshadow - INFO - BarShadowStep instance created.
# 2018-05-01 19:54:58,319 - stpipe.Spec2Pipeline.msa_flagging - INFO - MSAFlagOpenStep instance created.
# 2018-05-01 19:54:58,322 - stpipe.Spec2Pipeline.bkg_subtract - INFO - BackgroundStep instance created.
# 2018-05-01 19:54:58,324 - stpipe.Spec2Pipeline.cube_build - INFO - CubeBuildStep instance created.
# 2018-05-01 19:54:58,326 - stpipe.Spec2Pipeline.extract_1d - INFO - Extract1dStep instance created.
# 2018-05-01 19:54:58,328 - stpipe.Spec2Pipeline.assign_wcs - INFO - AssignWcsStep instance created.
# 2018-05-01 19:54:58,330 - stpipe.Spec2Pipeline.straylight - INFO - StraylightStep instance created.
# 2018-05-01 19:54:58,331 - stpipe.Spec2Pipeline.pathloss - INFO - PathLossStep instance created.
# 2018-05-01 19:54:58,334 - stpipe.Spec2Pipeline.srctype - INFO - SourceTypeStep instance created.
# 2018-05-01 19:54:58,336 - stpipe.Spec2Pipeline.photom - INFO - PhotomStep instance created.
# 2018-05-01 19:54:58,339 - stpipe.Spec2Pipeline.resample_spec - INFO - ResampleSpecStep instance created.
# 2018-05-01 19:54:58,341 - stpipe.Spec2Pipeline.fringe - INFO - FringeStep instance created.
# 2018-05-01 19:54:58,343 - stpipe.Spec2Pipeline.flat_field - INFO - FlatFieldStep instance created.
# 2018-05-01 19:54:58,345 - stpipe.Spec2Pipeline.imprint_subtract - INFO - ImprintStep instance created.
# 2018-05-01 19:54:58,347 - stpipe.Spec2Pipeline.extract_2d - INFO - Extract2dStep instance created.
# 2018-05-01 19:54:58,672 - stpipe.Spec2Pipeline - INFO - Prefetch for AREA reference file is 'N/A'.
# 2018-05-01 19:54:58,673 - stpipe.Spec2Pipeline - INFO - Prefetch for BARSHADOW reference file is 'N/A'.
# 2018-05-01 19:54:58,674 - stpipe.Spec2Pipeline - INFO - Prefetch for CAMERA reference file is 'N/A'.
# 2018-05-01 19:54:58,675 - stpipe.Spec2Pipeline - INFO - Prefetch for COLLIMATOR reference file is 'N/A'.
# 2018-05-01 19:54:58,675 - stpipe.Spec2Pipeline - INFO - Prefetch for CUBEPAR reference file is 'N/A'.
# 2018-05-01 19:54:58,676 - stpipe.Spec2Pipeline - INFO - Prefetch for DFLAT reference file is 'N/A'.
# 2018-05-01 19:54:58,677 - stpipe.Spec2Pipeline - INFO - Prefetch for DISPERSER reference file is 'N/A'.
# 2018-05-01 19:54:58,678 - stpipe.Spec2Pipeline - INFO - Prefetch for DISTORTION reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_distortion_0023.asdf'.
# 2018-05-01 19:54:58,680 - stpipe.Spec2Pipeline - INFO - Prefetch for DRIZPARS reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_drizpars_0001.fits'.
# 2018-05-01 19:54:58,681 - stpipe.Spec2Pipeline - INFO - Prefetch for EXTRACT1D reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_extract1d_0004.json'.
# 2018-05-01 19:54:58,682 - stpipe.Spec2Pipeline - INFO - Prefetch for FFLAT reference file is 'N/A'.
# 2018-05-01 19:54:58,683 - stpipe.Spec2Pipeline - INFO - Prefetch for FILTEROFFSET reference file is 'N/A'.
# 2018-05-01 19:54:58,684 - stpipe.Spec2Pipeline - INFO - Prefetch for FLAT reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_flat_0245.fits'.
# 2018-05-01 19:54:58,685 - stpipe.Spec2Pipeline - INFO - Prefetch for FORE reference file is 'N/A'.
# 2018-05-01 19:54:58,686 - stpipe.Spec2Pipeline - INFO - Prefetch for FPA reference file is 'N/A'.
# 2018-05-01 19:54:58,687 - stpipe.Spec2Pipeline - INFO - Prefetch for FRINGE reference file is 'N/A'.
# 2018-05-01 19:54:58,687 - stpipe.Spec2Pipeline - INFO - Prefetch for IFUFORE reference file is 'N/A'.
# 2018-05-01 19:54:58,688 - stpipe.Spec2Pipeline - INFO - Prefetch for IFUPOST reference file is 'N/A'.
# 2018-05-01 19:54:58,688 - stpipe.Spec2Pipeline - INFO - Prefetch for IFUSLICER reference file is 'N/A'.
# 2018-05-01 19:54:58,689 - stpipe.Spec2Pipeline - INFO - Prefetch for MSA reference file is 'N/A'.
# 2018-05-01 19:54:58,689 - stpipe.Spec2Pipeline - INFO - Prefetch for MSAOPER reference file is 'N/A'.
# 2018-05-01 19:54:58,690 - stpipe.Spec2Pipeline - INFO - Prefetch for OTE reference file is 'N/A'.
# 2018-05-01 19:54:58,690 - stpipe.Spec2Pipeline - INFO - Prefetch for PATHLOSS reference file is 'N/A'.
# 2018-05-01 19:54:58,691 - stpipe.Spec2Pipeline - INFO - Prefetch for PHOTOM reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_photom_0014.fits'.
# 2018-05-01 19:54:58,693 - stpipe.Spec2Pipeline - INFO - Prefetch for REGIONS reference file is 'N/A'.
# 2018-05-01 19:54:58,694 - stpipe.Spec2Pipeline - INFO - Prefetch for RESOL reference file is 'N/A'.
# 2018-05-01 19:54:58,694 - stpipe.Spec2Pipeline - INFO - Prefetch for SFLAT reference file is 'N/A'.
# 2018-05-01 19:54:58,695 - stpipe.Spec2Pipeline - INFO - Prefetch for SPECWCS reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_specwcs_0001.fits'.
# 2018-05-01 19:54:58,696 - stpipe.Spec2Pipeline - INFO - Prefetch for STRAYMASK reference file is 'N/A'.
# 2018-05-01 19:54:58,697 - stpipe.Spec2Pipeline - INFO - Prefetch for WAVECORR reference file is 'N/A'.
# 2018-05-01 19:54:58,697 - stpipe.Spec2Pipeline - INFO - Prefetch for WAVELENGTHRANGE reference file is 'N/A'.
# 2018-05-01 19:54:58,698 - stpipe.Spec2Pipeline - INFO - Step Spec2Pipeline running with args ('LRS-SLITLESS_demo_data_pipelined/det_image_1_MIRIMAGE_P750Lexp2_rateints.fits',).
# 2018-05-01 19:54:58,699 - stpipe.Spec2Pipeline - INFO - Starting calwebb_spec2 ...
# 2018-05-01 19:54:59,029 - stpipe.Spec2Pipeline - INFO - Processing product LRS-SLITLESS_demo_data_pipelined/det_image_1_MIRIMAGE_P750Lexp2
# 2018-05-01 19:54:59,030 - stpipe.Spec2Pipeline - INFO - Working on input LRS-SLITLESS_demo_data_pipelined/det_image_1_MIRIMAGE_P750Lexp2_rateints.fits ...
# 2018-05-01 19:54:59,278 - stpipe.Spec2Pipeline.assign_wcs - INFO - Step assign_wcs running with args (<jwst.datamodels.cube.CubeModel object at 0x1c34203b38>,).
# 2018-05-01 19:55:00,536 - stpipe.Spec2Pipeline.assign_wcs - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/assign_wcs/util.py:559: RuntimeWarning: invalid value encountered in less
#   negative_ind = footprint[0] < 0
#
# 2018-05-01 19:55:00,537 - stpipe.Spec2Pipeline.assign_wcs - INFO - There are NaNs in s_region
# 2018-05-01 19:55:00,537 - stpipe.Spec2Pipeline.assign_wcs - INFO - COMPLETED assign_wcs
# 2018-05-01 19:55:00,547 - stpipe.Spec2Pipeline.assign_wcs - INFO - Step assign_wcs done
# 2018-05-01 19:55:00,632 - stpipe.Spec2Pipeline.flat_field - INFO - Step flat_field running with args (<jwst.datamodels.cube.CubeModel object at 0x1c2f460b38>,).
# 2018-05-01 19:55:00,729 - stpipe.Spec2Pipeline.flat_field - WARNING - Keyword CDP_PARTIAL_DATA does not correspond to an existing DQ mnemonic, so will be ignored
# 2018-05-01 19:55:00,729 - stpipe.Spec2Pipeline.flat_field - WARNING - Keyword CDP_LOW_QUAL does not correspond to an existing DQ mnemonic, so will be ignored
# 2018-05-01 19:55:00,730 - stpipe.Spec2Pipeline.flat_field - WARNING - Keyword CDP_UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2018-05-01 19:55:00,731 - stpipe.Spec2Pipeline.flat_field - WARNING - Keyword DIFF_PATTERN does not correspond to an existing DQ mnemonic, so will be ignored
# 2018-05-01 19:55:00,837 - stpipe.Spec2Pipeline.flat_field - INFO - Step flat_field done
# 2018-05-01 19:55:00,946 - stpipe.Spec2Pipeline.srctype - INFO - Step srctype running with args (<jwst.datamodels.cube.CubeModel object at 0x1c34170240>,).
# 2018-05-01 19:55:00,983 - stpipe.Spec2Pipeline.srctype - INFO - Input EXP_TYPE is MIR_LRS-SLITLESS
# 2018-05-01 19:55:00,984 - stpipe.Spec2Pipeline.srctype - INFO - Input SRCTYPE is unknown. Setting to default value of POINT
# 2018-05-01 19:55:00,987 - stpipe.Spec2Pipeline.srctype - INFO - Step srctype done
# 2018-05-01 19:55:01,074 - stpipe.Spec2Pipeline.photom - INFO - Step photom running with args (<jwst.datamodels.cube.CubeModel object at 0x1c342033c8>,).
# 2018-05-01 19:55:01,116 - stpipe.Spec2Pipeline.photom - INFO - Using photom reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_photom_0014.fits
# 2018-05-01 19:55:01,120 - stpipe.Spec2Pipeline.photom - INFO - Using area reference file: N/A
# 2018-05-01 19:55:01,121 - stpipe.Spec2Pipeline.photom - INFO - Using instrument: MIRI
# 2018-05-01 19:55:01,122 - stpipe.Spec2Pipeline.photom - INFO -  detector: MIRIMAGE
# 2018-05-01 19:55:01,123 - stpipe.Spec2Pipeline.photom - INFO -  exp_type: MIR_LRS-SLITLESS
# 2018-05-01 19:55:01,124 - stpipe.Spec2Pipeline.photom - INFO -  filter: P750L
# 2018-05-01 19:55:01,192 - stpipe.Spec2Pipeline.photom - INFO -  subarray: SUBPRISM
# 2018-05-01 19:55:01,195 - stpipe.Spec2Pipeline.photom - INFO - PHOTMJSR value: 1
# 2018-05-01 19:55:01,197 - stpipe.Spec2Pipeline.photom - INFO - Storing relative response table
# 2018-05-01 19:55:01,203 - stpipe.Spec2Pipeline.photom - INFO - Step photom done
# 2018-05-01 19:55:01,290 - stpipe.Spec2Pipeline.extract_1d - INFO - Step extract_1d running with args (<jwst.datamodels.cube.CubeModel object at 0x1c3065c9e8>,).
# 2018-05-01 19:55:01,329 - stpipe.Spec2Pipeline.extract_1d - INFO - Using EXTRACT1D reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_extract1d_0004.json
# 2018-05-01 19:55:01,376 - stpipe.Spec2Pipeline.extract_1d - WARNING - spectral_order is None; using 1
# 2018-05-01 19:55:01,421 - stpipe.Spec2Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:01,555 - stpipe.Spec2Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:01,690 - stpipe.Spec2Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:01,827 - stpipe.Spec2Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:01,958 - stpipe.Spec2Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:02,090 - stpipe.Spec2Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:02,218 - stpipe.Spec2Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:02,349 - stpipe.Spec2Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:02,479 - stpipe.Spec2Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:02,609 - stpipe.Spec2Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:02,737 - stpipe.Spec2Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:02,866 - stpipe.Spec2Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:03,001 - stpipe.Spec2Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:03,145 - stpipe.Spec2Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:03,295 - stpipe.Spec2Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:03,566 - stpipe.Spec2Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:03,698 - stpipe.Spec2Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:03,832 - stpipe.Spec2Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:03,968 - stpipe.Spec2Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:04,107 - stpipe.Spec2Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:04,952 - stpipe.Spec2Pipeline.extract_1d - INFO - Saved model in LRS-SLITLESS_demo_data_pipelined/det_image_1_MIRIMAGE_P750Lexp2_x1dints.fits
# 2018-05-01 19:55:04,953 - stpipe.Spec2Pipeline.extract_1d - INFO - Step extract_1d done
# 2018-05-01 19:55:04,955 - stpipe.Spec2Pipeline - INFO - Finished processing product LRS-SLITLESS_demo_data_pipelined/det_image_1_MIRIMAGE_P750Lexp2
# 2018-05-01 19:55:05,137 - stpipe.Spec2Pipeline - INFO - Saved model in LRS-SLITLESS_demo_data_pipelined/det_image_1_MIRIMAGE_P750Lexp2_calints.fits
# 2018-05-01 19:55:05,282 - stpipe.Spec2Pipeline - INFO - Ending calwebb_spec2
# 2018-05-01 19:55:05,282 - stpipe.Spec2Pipeline - INFO - Step Spec2Pipeline done
# 2018-05-01 19:55:05,300 - stpipe.Spec2Pipeline - INFO - Spec2Pipeline instance created.
# 2018-05-01 19:55:05,301 - stpipe.Spec2Pipeline.barshadow - INFO - BarShadowStep instance created.
# 2018-05-01 19:55:05,303 - stpipe.Spec2Pipeline.msa_flagging - INFO - MSAFlagOpenStep instance created.
# 2018-05-01 19:55:05,305 - stpipe.Spec2Pipeline.bkg_subtract - INFO - BackgroundStep instance created.
# 2018-05-01 19:55:05,308 - stpipe.Spec2Pipeline.cube_build - INFO - CubeBuildStep instance created.
# 2018-05-01 19:55:05,310 - stpipe.Spec2Pipeline.extract_1d - INFO - Extract1dStep instance created.
# 2018-05-01 19:55:05,312 - stpipe.Spec2Pipeline.assign_wcs - INFO - AssignWcsStep instance created.
# 2018-05-01 19:55:05,314 - stpipe.Spec2Pipeline.straylight - INFO - StraylightStep instance created.
# 2018-05-01 19:55:05,316 - stpipe.Spec2Pipeline.pathloss - INFO - PathLossStep instance created.
# 2018-05-01 19:55:05,317 - stpipe.Spec2Pipeline.srctype - INFO - SourceTypeStep instance created.
# 2018-05-01 19:55:05,320 - stpipe.Spec2Pipeline.photom - INFO - PhotomStep instance created.
# 2018-05-01 19:55:05,323 - stpipe.Spec2Pipeline.resample_spec - INFO - ResampleSpecStep instance created.
# 2018-05-01 19:55:05,325 - stpipe.Spec2Pipeline.fringe - INFO - FringeStep instance created.
# 2018-05-01 19:55:05,327 - stpipe.Spec2Pipeline.flat_field - INFO - FlatFieldStep instance created.
# 2018-05-01 19:55:05,330 - stpipe.Spec2Pipeline.imprint_subtract - INFO - ImprintStep instance created.
# 2018-05-01 19:55:05,331 - stpipe.Spec2Pipeline.extract_2d - INFO - Extract2dStep instance created.
# 2018-05-01 19:55:05,681 - stpipe.Spec2Pipeline - INFO - Prefetch for AREA reference file is 'N/A'.
# 2018-05-01 19:55:05,682 - stpipe.Spec2Pipeline - INFO - Prefetch for BARSHADOW reference file is 'N/A'.
# 2018-05-01 19:55:05,682 - stpipe.Spec2Pipeline - INFO - Prefetch for CAMERA reference file is 'N/A'.
# 2018-05-01 19:55:05,684 - stpipe.Spec2Pipeline - INFO - Prefetch for COLLIMATOR reference file is 'N/A'.
# 2018-05-01 19:55:05,685 - stpipe.Spec2Pipeline - INFO - Prefetch for CUBEPAR reference file is 'N/A'.
# 2018-05-01 19:55:05,686 - stpipe.Spec2Pipeline - INFO - Prefetch for DFLAT reference file is 'N/A'.
# 2018-05-01 19:55:05,687 - stpipe.Spec2Pipeline - INFO - Prefetch for DISPERSER reference file is 'N/A'.
# 2018-05-01 19:55:05,688 - stpipe.Spec2Pipeline - INFO - Prefetch for DISTORTION reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_distortion_0023.asdf'.
# 2018-05-01 19:55:05,691 - stpipe.Spec2Pipeline - INFO - Prefetch for DRIZPARS reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_drizpars_0001.fits'.
# 2018-05-01 19:55:05,691 - stpipe.Spec2Pipeline - INFO - Prefetch for EXTRACT1D reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_extract1d_0004.json'.
# 2018-05-01 19:55:05,693 - stpipe.Spec2Pipeline - INFO - Prefetch for FFLAT reference file is 'N/A'.
# 2018-05-01 19:55:05,693 - stpipe.Spec2Pipeline - INFO - Prefetch for FILTEROFFSET reference file is 'N/A'.
# 2018-05-01 19:55:05,694 - stpipe.Spec2Pipeline - INFO - Prefetch for FLAT reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_flat_0245.fits'.
# 2018-05-01 19:55:05,696 - stpipe.Spec2Pipeline - INFO - Prefetch for FORE reference file is 'N/A'.
# 2018-05-01 19:55:05,696 - stpipe.Spec2Pipeline - INFO - Prefetch for FPA reference file is 'N/A'.
# 2018-05-01 19:55:05,697 - stpipe.Spec2Pipeline - INFO - Prefetch for FRINGE reference file is 'N/A'.
# 2018-05-01 19:55:05,698 - stpipe.Spec2Pipeline - INFO - Prefetch for IFUFORE reference file is 'N/A'.
# 2018-05-01 19:55:05,699 - stpipe.Spec2Pipeline - INFO - Prefetch for IFUPOST reference file is 'N/A'.
# 2018-05-01 19:55:05,699 - stpipe.Spec2Pipeline - INFO - Prefetch for IFUSLICER reference file is 'N/A'.
# 2018-05-01 19:55:05,700 - stpipe.Spec2Pipeline - INFO - Prefetch for MSA reference file is 'N/A'.
# 2018-05-01 19:55:05,701 - stpipe.Spec2Pipeline - INFO - Prefetch for MSAOPER reference file is 'N/A'.
# 2018-05-01 19:55:05,702 - stpipe.Spec2Pipeline - INFO - Prefetch for OTE reference file is 'N/A'.
# 2018-05-01 19:55:05,703 - stpipe.Spec2Pipeline - INFO - Prefetch for PATHLOSS reference file is 'N/A'.
# 2018-05-01 19:55:05,704 - stpipe.Spec2Pipeline - INFO - Prefetch for PHOTOM reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_photom_0014.fits'.
# 2018-05-01 19:55:05,706 - stpipe.Spec2Pipeline - INFO - Prefetch for REGIONS reference file is 'N/A'.
# 2018-05-01 19:55:05,706 - stpipe.Spec2Pipeline - INFO - Prefetch for RESOL reference file is 'N/A'.
# 2018-05-01 19:55:05,707 - stpipe.Spec2Pipeline - INFO - Prefetch for SFLAT reference file is 'N/A'.
# 2018-05-01 19:55:05,708 - stpipe.Spec2Pipeline - INFO - Prefetch for SPECWCS reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_specwcs_0001.fits'.
# 2018-05-01 19:55:05,710 - stpipe.Spec2Pipeline - INFO - Prefetch for STRAYMASK reference file is 'N/A'.
# 2018-05-01 19:55:05,710 - stpipe.Spec2Pipeline - INFO - Prefetch for WAVECORR reference file is 'N/A'.
# 2018-05-01 19:55:05,711 - stpipe.Spec2Pipeline - INFO - Prefetch for WAVELENGTHRANGE reference file is 'N/A'.
# 2018-05-01 19:55:05,712 - stpipe.Spec2Pipeline - INFO - Step Spec2Pipeline running with args ('LRS-SLITLESS_demo_data_pipelined/det_image_1_MIRIMAGE_P750Lexp1_rateints.fits',).
# 2018-05-01 19:55:05,712 - stpipe.Spec2Pipeline - INFO - Starting calwebb_spec2 ...
# 2018-05-01 19:55:06,072 - stpipe.Spec2Pipeline - INFO - Processing product LRS-SLITLESS_demo_data_pipelined/det_image_1_MIRIMAGE_P750Lexp1
# 2018-05-01 19:55:06,073 - stpipe.Spec2Pipeline - INFO - Working on input LRS-SLITLESS_demo_data_pipelined/det_image_1_MIRIMAGE_P750Lexp1_rateints.fits ...
# 2018-05-01 19:55:06,329 - stpipe.Spec2Pipeline.assign_wcs - INFO - Step assign_wcs running with args (<jwst.datamodels.cube.CubeModel object at 0x1c2cce8898>,).
# 2018-05-01 19:55:07,606 - stpipe.Spec2Pipeline.assign_wcs - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/assign_wcs/util.py:559: RuntimeWarning: invalid value encountered in less
#   negative_ind = footprint[0] < 0
#
# 2018-05-01 19:55:07,607 - stpipe.Spec2Pipeline.assign_wcs - INFO - There are NaNs in s_region
# 2018-05-01 19:55:07,608 - stpipe.Spec2Pipeline.assign_wcs - INFO - COMPLETED assign_wcs
# 2018-05-01 19:55:07,617 - stpipe.Spec2Pipeline.assign_wcs - INFO - Step assign_wcs done
# 2018-05-01 19:55:07,730 - stpipe.Spec2Pipeline.flat_field - INFO - Step flat_field running with args (<jwst.datamodels.cube.CubeModel object at 0x1c305da940>,).
# 2018-05-01 19:55:07,827 - stpipe.Spec2Pipeline.flat_field - WARNING - Keyword CDP_PARTIAL_DATA does not correspond to an existing DQ mnemonic, so will be ignored
# 2018-05-01 19:55:07,828 - stpipe.Spec2Pipeline.flat_field - WARNING - Keyword CDP_LOW_QUAL does not correspond to an existing DQ mnemonic, so will be ignored
# 2018-05-01 19:55:07,829 - stpipe.Spec2Pipeline.flat_field - WARNING - Keyword CDP_UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2018-05-01 19:55:07,831 - stpipe.Spec2Pipeline.flat_field - WARNING - Keyword DIFF_PATTERN does not correspond to an existing DQ mnemonic, so will be ignored
# 2018-05-01 19:55:07,933 - stpipe.Spec2Pipeline.flat_field - INFO - Step flat_field done
# 2018-05-01 19:55:08,044 - stpipe.Spec2Pipeline.srctype - INFO - Step srctype running with args (<jwst.datamodels.cube.CubeModel object at 0x1c2f4bb828>,).
# 2018-05-01 19:55:08,081 - stpipe.Spec2Pipeline.srctype - INFO - Input EXP_TYPE is MIR_LRS-SLITLESS
# 2018-05-01 19:55:08,082 - stpipe.Spec2Pipeline.srctype - INFO - Input SRCTYPE is unknown. Setting to default value of POINT
# 2018-05-01 19:55:08,084 - stpipe.Spec2Pipeline.srctype - INFO - Step srctype done
# 2018-05-01 19:55:08,174 - stpipe.Spec2Pipeline.photom - INFO - Step photom running with args (<jwst.datamodels.cube.CubeModel object at 0x1c305f3a20>,).
# 2018-05-01 19:55:08,214 - stpipe.Spec2Pipeline.photom - INFO - Using photom reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_photom_0014.fits
# 2018-05-01 19:55:08,219 - stpipe.Spec2Pipeline.photom - INFO - Using area reference file: N/A
# 2018-05-01 19:55:08,220 - stpipe.Spec2Pipeline.photom - INFO - Using instrument: MIRI
# 2018-05-01 19:55:08,221 - stpipe.Spec2Pipeline.photom - INFO -  detector: MIRIMAGE
# 2018-05-01 19:55:08,221 - stpipe.Spec2Pipeline.photom - INFO -  exp_type: MIR_LRS-SLITLESS
# 2018-05-01 19:55:08,222 - stpipe.Spec2Pipeline.photom - INFO -  filter: P750L
# 2018-05-01 19:55:08,293 - stpipe.Spec2Pipeline.photom - INFO -  subarray: SUBPRISM
# 2018-05-01 19:55:08,296 - stpipe.Spec2Pipeline.photom - INFO - PHOTMJSR value: 1
# 2018-05-01 19:55:08,300 - stpipe.Spec2Pipeline.photom - INFO - Storing relative response table
# 2018-05-01 19:55:08,306 - stpipe.Spec2Pipeline.photom - INFO - Step photom done
# 2018-05-01 19:55:08,400 - stpipe.Spec2Pipeline.extract_1d - INFO - Step extract_1d running with args (<jwst.datamodels.cube.CubeModel object at 0x1c3035aeb8>,).
# 2018-05-01 19:55:08,442 - stpipe.Spec2Pipeline.extract_1d - INFO - Using EXTRACT1D reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_extract1d_0004.json
# 2018-05-01 19:55:08,488 - stpipe.Spec2Pipeline.extract_1d - WARNING - spectral_order is None; using 1
# 2018-05-01 19:55:08,532 - stpipe.Spec2Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:08,665 - stpipe.Spec2Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:08,801 - stpipe.Spec2Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:08,945 - stpipe.Spec2Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:09,084 - stpipe.Spec2Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:09,218 - stpipe.Spec2Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:09,350 - stpipe.Spec2Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:09,499 - stpipe.Spec2Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:09,655 - stpipe.Spec2Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:09,806 - stpipe.Spec2Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:09,956 - stpipe.Spec2Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:10,115 - stpipe.Spec2Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:10,272 - stpipe.Spec2Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:10,429 - stpipe.Spec2Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:10,569 - stpipe.Spec2Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:10,860 - stpipe.Spec2Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:10,996 - stpipe.Spec2Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:11,130 - stpipe.Spec2Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:11,266 - stpipe.Spec2Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:11,398 - stpipe.Spec2Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:12,160 - stpipe.Spec2Pipeline.extract_1d - INFO - Saved model in LRS-SLITLESS_demo_data_pipelined/det_image_1_MIRIMAGE_P750Lexp1_x1dints.fits
# 2018-05-01 19:55:12,161 - stpipe.Spec2Pipeline.extract_1d - INFO - Step extract_1d done
# 2018-05-01 19:55:12,162 - stpipe.Spec2Pipeline - INFO - Finished processing product LRS-SLITLESS_demo_data_pipelined/det_image_1_MIRIMAGE_P750Lexp1
# 2018-05-01 19:55:12,317 - stpipe.Spec2Pipeline - INFO - Saved model in LRS-SLITLESS_demo_data_pipelined/det_image_1_MIRIMAGE_P750Lexp1_calints.fits
# 2018-05-01 19:55:12,441 - stpipe.Spec2Pipeline - INFO - Ending calwebb_spec2
# 2018-05-01 19:55:12,442 - stpipe.Spec2Pipeline - INFO - Step Spec2Pipeline done

# %% [markdown]
# ### check of output
#
# We can have a look at the steps applied to the files in the level 2B pipeline

# %%
# set the output file names
level2B_files = glob.glob(os.path.join(output_dir,'*_calints.fits'))

with datamodels.open(level2B_files[0]) as dm:
    # check the calibration step information
    print('Check step information status:')
    print('assign_wcs: %s' % dm.meta.cal_step.assign_wcs)
    print('flat_field: %s' % dm.meta.cal_step.flat_field)
    print('srctype: %s' % dm.meta.cal_step.srctype)
    print('photom: %s' % dm.meta.cal_step.photom)
# Out:
# Check step information status:
# assign_wcs: COMPLETE
# flat_field: COMPLETE
# srctype: COMPLETE
# photom: COMPLETE

# %% [markdown]
# While the photom step attaches the SRF to the _calints.fits files, it does not actually apply it so we must manually convert the extracted spectrum from DN/s to Jy using the SRF. We can look at the SRF while is located in the 'relsens' object in the metadata.

# %%
with datamodels.open(level2B_files[0]) as dm:  
    #print(dm.relsens)
    relsens = np.array(dm.relsens, dtype=[('wavelength', 'f4'), ('response', 'i8')])
    # plot--------------------------------------
    fig, axs = plt.subplots(1, 1, figsize=(8, 6))

    # plot input and output ramps of the first integration
    axs.plot(relsens['wavelength'], relsens['response'], c='b', marker='o', markersize=2, 
             markeredgewidth=3, linestyle='-', linewidth=1, label='relsens')
    axs.set_title('RELSENS', fontsize=15)
    axs.set_xlabel('wavelength (micron)', fontsize=15)
    axs.set_ylabel('SRF (DN/s/Jy)', fontsize=15)

    plt.tight_layout(h_pad=0)
    plt.show()

# %% [markdown]
# #### plot the spectra extracted from the integrations
# Using the SRF, we can flux calibrate and plot the extracted spectra

# %%
spec_files = glob.glob(os.path.join(output_dir,"*x1dints.fits"))
dm = datamodels.open(spec_files[0])

fig, axs = plt.subplots(5, 4, figsize=(12, 15), sharey=True, sharex=True)
axs = axs.ravel()

for n in range(20):

    # convert the flux
    response_at_data = np.interp(dm.spec[n].spec_table['WAVELENGTH'][1:-1], relsens['wavelength'], relsens['response'])
    flux_Jy = dm.spec[n].spec_table['FLUX'][1:-1] / response_at_data
    
    # plot the spectrum 
    axs[n].plot(dm.spec[n].spec_table['WAVELENGTH'][1:-1], flux_Jy, c='b', marker='.', 
             markersize=0, linestyle='-', linewidth=2)
    axs[n].grid()
    
    if n in [0, 4, 8, 12, 16]: axs[n].set_ylabel(r'Flux (Jy)')
    if n in [16, 17 , 18, 19]: axs[n].set_xlabel(r'Wavelength ($\mu$m)')

plt.tight_layout(pad=0.0)
plt.show()

# %% [markdown]
# ### Level 3 TSO pipeline

# %% [markdown]
# The Tso3Pipeline requires an association as input. Therefore, we generate a level 3 association file containing the three calints files:

# %%
call(["asn_from_list", "-o", "LRS-SLITLESS_asn.json"] + level2B_files + ["--product-name", "tso"])
# Out:
# 0

# %% [markdown]
# #### import the level 3 TSO pipeline class and print description

# %%
from jwst.pipeline import Tso3Pipeline
print(Tso3Pipeline.__doc__)
# Out:
#     TSO3Pipeline: Applies level 3 processing to TSO-mode data from
#                     any JWST instrument.
#
#     Included steps are:
#
#         * outlier_detection
#         * tso_photometry
#         * extract_1d
#         * white_light

# %% [markdown]
# #### run pipeline

# %%
Tso3Pipeline.call('LRS-SLITLESS_asn.json', output_dir=output_dir)
# Out:
# 2018-05-01 19:55:17,336 - stpipe.Tso3Pipeline - INFO - Tso3Pipeline instance created.
# 2018-05-01 19:55:17,338 - stpipe.Tso3Pipeline.extract_1d - INFO - Extract1dStep instance created.
# 2018-05-01 19:55:17,340 - stpipe.Tso3Pipeline.tso_photometry - INFO - TSOPhotometryStep instance created.
# 2018-05-01 19:55:17,342 - stpipe.Tso3Pipeline.white_light - INFO - WhiteLightStep instance created.
# 2018-05-01 19:55:17,345 - stpipe.Tso3Pipeline.outlier_detection - INFO - OutlierDetectionStep instance created.
# 2018-05-01 19:55:17,791 - stpipe.Tso3Pipeline - INFO - Prefetch for EXTRACT1D reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_extract1d_0004.json'.
# 2018-05-01 19:55:18,053 - stpipe.Tso3Pipeline - INFO - Prefetch for EXTRACT1D reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_extract1d_0004.json'.
# 2018-05-01 19:55:18,301 - stpipe.Tso3Pipeline - INFO - Prefetch for EXTRACT1D reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_extract1d_0004.json'.
# 2018-05-01 19:55:18,302 - stpipe.Tso3Pipeline - INFO - Step Tso3Pipeline running with args ('LRS-SLITLESS_asn.json',).
# 2018-05-01 19:55:18,303 - stpipe.Tso3Pipeline - INFO - Starting calwebb_tso3...
# 2018-05-01 19:55:19,967 - stpipe.Tso3Pipeline - INFO - Performing outlier detection on input images...
# 2018-05-01 19:55:20,092 - stpipe.Tso3Pipeline.outlier_detection - INFO - Step outlier_detection running with args (<jwst.datamodels.container.ModelContainer object at 0x181e86f550>,).
# 2018-05-01 19:55:20,118 - stpipe.Tso3Pipeline.outlier_detection - INFO - Performing outlier detection on 20 inputs
# 2018-05-01 19:55:20,549 - stpipe.Tso3Pipeline.outlier_detection - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/outlier_detection/outlier_detection.py:405: RuntimeWarning: invalid value encountered in sqrt
#   ta = np.sqrt(np.abs(blot_data + subtracted_background) + err_data ** 2)
#
# 2018-05-01 19:55:20,631 - stpipe.Tso3Pipeline.outlier_detection - INFO - Step outlier_detection done
# 2018-05-01 19:55:22,057 - stpipe.Tso3Pipeline - INFO - Performing outlier detection on input images...
# 2018-05-01 19:55:22,212 - stpipe.Tso3Pipeline.outlier_detection - INFO - Step outlier_detection running with args (<jwst.datamodels.container.ModelContainer object at 0x1c2f5c0048>,).
# 2018-05-01 19:55:22,239 - stpipe.Tso3Pipeline.outlier_detection - INFO - Performing outlier detection on 20 inputs
# 2018-05-01 19:55:22,710 - stpipe.Tso3Pipeline.outlier_detection - INFO - Step outlier_detection done
# 2018-05-01 19:55:24,105 - stpipe.Tso3Pipeline - INFO - Performing outlier detection on input images...
# 2018-05-01 19:55:24,280 - stpipe.Tso3Pipeline.outlier_detection - INFO - Step outlier_detection running with args (<jwst.datamodels.container.ModelContainer object at 0x10f07e358>,).
# 2018-05-01 19:55:24,305 - stpipe.Tso3Pipeline.outlier_detection - INFO - Performing outlier detection on 20 inputs
# 2018-05-01 19:55:24,774 - stpipe.Tso3Pipeline.outlier_detection - INFO - Step outlier_detection done
# 2018-05-01 19:55:24,776 - stpipe.Tso3Pipeline - INFO - Writing Level 2c cubes with updated DQ arrays...
# 2018-05-01 19:55:24,939 - stpipe.Tso3Pipeline - INFO - Saved model in LRS-SLITLESS_demo_data_pipelined/det_image_1_MIRIMAGE_P750Lexp1_a3001_crfints.fits
# 2018-05-01 19:55:25,099 - stpipe.Tso3Pipeline - INFO - Saved model in LRS-SLITLESS_demo_data_pipelined/det_image_1_MIRIMAGE_P750Lexp3_a3001_crfints.fits
# 2018-05-01 19:55:25,260 - stpipe.Tso3Pipeline - INFO - Saved model in LRS-SLITLESS_demo_data_pipelined/det_image_1_MIRIMAGE_P750Lexp2_a3001_crfints.fits
# 2018-05-01 19:55:25,311 - stpipe.Tso3Pipeline - INFO - Extracting 1-D spectra...
# 2018-05-01 19:55:25,479 - stpipe.Tso3Pipeline.extract_1d - INFO - Step extract_1d running with args (<jwst.datamodels.cube.CubeModel object at 0x181e696f60>,).
# 2018-05-01 19:55:25,519 - stpipe.Tso3Pipeline.extract_1d - INFO - Using EXTRACT1D reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_extract1d_0004.json
# 2018-05-01 19:55:25,566 - stpipe.Tso3Pipeline.extract_1d - WARNING - spectral_order is None; using 1
# 2018-05-01 19:55:25,615 - stpipe.Tso3Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:25,752 - stpipe.Tso3Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:25,885 - stpipe.Tso3Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:26,020 - stpipe.Tso3Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:26,153 - stpipe.Tso3Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:26,289 - stpipe.Tso3Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:26,426 - stpipe.Tso3Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:26,575 - stpipe.Tso3Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:26,720 - stpipe.Tso3Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:26,857 - stpipe.Tso3Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:26,991 - stpipe.Tso3Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:27,126 - stpipe.Tso3Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:27,262 - stpipe.Tso3Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:27,404 - stpipe.Tso3Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:27,554 - stpipe.Tso3Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:27,702 - stpipe.Tso3Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:27,838 - stpipe.Tso3Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:27,973 - stpipe.Tso3Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:28,303 - stpipe.Tso3Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:28,450 - stpipe.Tso3Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:28,554 - stpipe.Tso3Pipeline.extract_1d - INFO - Step extract_1d done
# 2018-05-01 19:55:28,631 - stpipe.Tso3Pipeline - INFO - Performing white-light photometry...
# 2018-05-01 19:55:28,783 - stpipe.Tso3Pipeline.white_light - INFO - Step white_light running with args (<jwst.datamodels.multispec.MultiSpecModel object at 0x181e7865c0>,).
# 2018-05-01 19:55:28,833 - stpipe.Tso3Pipeline.white_light - INFO - Step white_light done
# 2018-05-01 19:55:28,835 - stpipe.Tso3Pipeline - INFO - Extracting 1-D spectra...
# 2018-05-01 19:55:28,972 - stpipe.Tso3Pipeline.extract_1d - INFO - Step extract_1d running with args (<jwst.datamodels.cube.CubeModel object at 0x181e9998d0>,).
# 2018-05-01 19:55:29,014 - stpipe.Tso3Pipeline.extract_1d - INFO - Using EXTRACT1D reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_extract1d_0004.json
# 2018-05-01 19:55:29,062 - stpipe.Tso3Pipeline.extract_1d - WARNING - spectral_order is None; using 1
# 2018-05-01 19:55:29,105 - stpipe.Tso3Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:29,245 - stpipe.Tso3Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:29,382 - stpipe.Tso3Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:29,519 - stpipe.Tso3Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:29,656 - stpipe.Tso3Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:29,796 - stpipe.Tso3Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:29,932 - stpipe.Tso3Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:30,068 - stpipe.Tso3Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:30,206 - stpipe.Tso3Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:30,339 - stpipe.Tso3Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:30,476 - stpipe.Tso3Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:30,615 - stpipe.Tso3Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:30,751 - stpipe.Tso3Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:30,886 - stpipe.Tso3Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:31,021 - stpipe.Tso3Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:31,156 - stpipe.Tso3Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:31,293 - stpipe.Tso3Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:31,429 - stpipe.Tso3Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:31,765 - stpipe.Tso3Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:31,917 - stpipe.Tso3Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:32,031 - stpipe.Tso3Pipeline.extract_1d - INFO - Step extract_1d done
# 2018-05-01 19:55:32,119 - stpipe.Tso3Pipeline - INFO - Performing white-light photometry...
# 2018-05-01 19:55:32,271 - stpipe.Tso3Pipeline.white_light - INFO - Step white_light running with args (<jwst.datamodels.multispec.MultiSpecModel object at 0x1c305522e8>,).
# 2018-05-01 19:55:32,317 - stpipe.Tso3Pipeline.white_light - INFO - Step white_light done
# 2018-05-01 19:55:32,318 - stpipe.Tso3Pipeline - INFO - Extracting 1-D spectra...
# 2018-05-01 19:55:32,461 - stpipe.Tso3Pipeline.extract_1d - INFO - Step extract_1d running with args (<jwst.datamodels.cube.CubeModel object at 0x1c316c9f60>,).
# 2018-05-01 19:55:32,503 - stpipe.Tso3Pipeline.extract_1d - INFO - Using EXTRACT1D reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_extract1d_0004.json
# 2018-05-01 19:55:32,552 - stpipe.Tso3Pipeline.extract_1d - WARNING - spectral_order is None; using 1
# 2018-05-01 19:55:32,598 - stpipe.Tso3Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:32,738 - stpipe.Tso3Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:32,879 - stpipe.Tso3Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:33,021 - stpipe.Tso3Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:33,156 - stpipe.Tso3Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:33,301 - stpipe.Tso3Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:33,439 - stpipe.Tso3Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:33,578 - stpipe.Tso3Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:33,724 - stpipe.Tso3Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:33,861 - stpipe.Tso3Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:33,997 - stpipe.Tso3Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:34,136 - stpipe.Tso3Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:34,275 - stpipe.Tso3Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:34,413 - stpipe.Tso3Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:34,551 - stpipe.Tso3Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:34,686 - stpipe.Tso3Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:34,824 - stpipe.Tso3Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:34,963 - stpipe.Tso3Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:35,102 - stpipe.Tso3Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:35,429 - stpipe.Tso3Pipeline.extract_1d - WARNING - Using RELSENS, 265 elements were extrapolated; these values will be set to 1.
# 2018-05-01 19:55:35,534 - stpipe.Tso3Pipeline.extract_1d - INFO - Step extract_1d done
# 2018-05-01 19:55:35,617 - stpipe.Tso3Pipeline - INFO - Performing white-light photometry...
# 2018-05-01 19:55:35,763 - stpipe.Tso3Pipeline.white_light - INFO - Step white_light running with args (<jwst.datamodels.multispec.MultiSpecModel object at 0x10f0a1550>,).
# 2018-05-01 19:55:35,810 - stpipe.Tso3Pipeline.white_light - INFO - Step white_light done
# 2018-05-01 19:55:37,933 - stpipe.Tso3Pipeline - INFO - Saved model in LRS-SLITLESS_demo_data_pipelined/tso_x1dints.fits
# 2018-05-01 19:55:37,937 - stpipe.Tso3Pipeline - INFO - Writing Level 3 photometry catalog LRS-SLITLESS_demo_data_pipelined/tso_whtlt.ecsv...
# 2018-05-01 19:55:37,945 - stpipe.Tso3Pipeline - INFO - Step Tso3Pipeline done

# %% [markdown]
# #### plot the spectra from all integrations in the combined x1dints file
# Again, using the SRF, we can flux calibrate and plot the extracted spectra

# %%
spec_file = glob.glob(os.path.join(output_dir,"tso_x1dints.fits"))[0]
dm = datamodels.open(spec_file)

fig, axs = plt.subplots(15, 4, figsize=(12, 45), sharey=True, sharex=True)
axs = axs.ravel()

for n in range(60):

    # convert the flux
    response_at_data = np.interp(dm.spec[n].spec_table['WAVELENGTH'][1:-1], relsens['wavelength'], relsens['response'])
    flux_phot = dm.spec[n].spec_table['FLUX'][1:-1] / response_at_data
    
    # plot the spectrum 
    axs[n].plot(dm.spec[n].spec_table['WAVELENGTH'][1:-1], flux_phot, c='b', marker='.', 
             markersize=0, linestyle='-', linewidth=2)
    axs[n].grid()
    
    if n in [0, 4, 8, 12, 16, 20, 24, 28, 32, 36, 40, 44, 48, 52, 56]: axs[n].set_ylabel(r'Flux (Jy)')
    if n in [56, 57 , 58, 59]: axs[n].set_xlabel(r'Wavelength ($\mu$m)')

plt.tight_layout(pad=0.0)
plt.show()

# %% [markdown]
# #### look at the white-light photometry lightcurve

# %%
from astropy.table import Table

my_lightcurve = os.path.join(output_dir,'tso_whtlt.ecsv')
lightcurve_data = Table.read(my_lightcurve, format='ascii.ecsv')

# plot--------------------------------------
fig, axs = plt.subplots(1, 1, figsize=(10, 8))

# plot input and output ramps of the first integration
axs.plot(lightcurve_data['MJD'], lightcurve_data['whitelight_flux'], c='b', marker='+', markersize=10, 
         markeredgewidth=3, linestyle=':', linewidth=0, label='white light curve')
axs.set_title('White light curve', fontsize=15)
axs.set_ylabel('white light flux', fontsize=15)
axs.set_xlabel('MJD', fontsize=15)

plt.tight_layout(h_pad=0)
plt.show()
