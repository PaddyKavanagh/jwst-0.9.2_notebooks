# %% [markdown]
# # Run level 2A, 2B and 3 pipelines on LRS-SLIT data using jwst.pipeline classes

# %% [markdown]
# ### by Patrick Kavanagh (DIAS, Ireland) April 29th 2018

# %% [markdown]
# This notebook demonstrates the execution of the level 2A and 2B pipelines for LRS-SLIT data in Python using the jwst.pipeline classes.
#
# For a description of the pipeline classes see:
#
# https://jwst-pipeline.readthedocs.io/en/latest/jwst/pipeline/index.html
#
# The files used in this notebook are a dithered (nodded) MIRISim simulation of a point source with a power-law spectrum (alpha=0) plus emission lines. The following steps are applied:
#
# - ramps to slopes pipeline (Detector1Pipeline)
#
# - CALSPEC2 steps (Spec2Pipeline), including background subtraction using the nods, spectral extraction
#
# - manual conversion of extracted spectrum to Jy using SRF

# %% [markdown]
# #### Imports

# %%
import os, glob, shutil

import numpy as np
from astropy.io import fits
from matplotlib.colors import LogNorm
import matplotlib.pyplot as plt
from subprocess import call

from jwst import datamodels

# %matplotlib inline
# %matplotlib notebook # if you want interactive plots

# %% [markdown]
# #### Set input file:

# %%
# set input filenames and directory. In this example, the files are located in a folder called 'LRS-SLIT_demo_data'
input_dir = 'LRS-SLIT_demo_data'

# load all files including the background observation
input_files = glob.glob(os.path.join(input_dir,'*.fits'))

# set the output directory name
output_dir = input_dir + '_pipeline'

# if the output directory exists, delete it
if os.path.exists(output_dir): shutil.rmtree(output_dir)

# create the output directory
os.mkdir(output_dir)

# %% [markdown]
# #### print some information about the input files. We will just look at the first file

# %%
# print some info on input file
with fits.open(input_files[0]) as hdulist:
        
    if hdulist[0].header['ORIGIN'] == 'STScI':
        # specific information on instrument/exposure
        identifier = hdulist[0].header['OBS_ID']
        detector = hdulist[0].header['EXP_TYPE']
        im_filter = hdulist[0].header['FILTER']
        nInts = hdulist[0].header['NINTS']
        nGroups = hdulist[0].header['NGROUPS']
        readPatt = hdulist[0].header['READPATT']
        expTime = hdulist[0].header['EFFEXPTM']
        subArr = hdulist[0].header['SUBARRAY']
        channel = hdulist[0].header['CHANNEL']
        band = hdulist[0].header['BAND']
        print("ID\t\t\t Detector\t Filter\t subAr\t nInts\t nGrps\t rdPatt\t ExpTime (s)")
        print("--------------------------------------------------------------------------------------------------")
        print("%s\t %s\t %s\t %s\t %d\t %d\t %s\t %0.1f" % (identifier,detector,im_filter,subArr,nInts,nGroups,readPatt,expTime))
        print("\n\n")
            
    else:
        # specific information on instrument/exposure
        detector = hdulist[0].header['EXP_TYPE']
        im_filter = hdulist[0].header['FILTER']
        nInts = hdulist[0].header['NINTS']
        nGroups = hdulist[0].header['NGROUPS']
        readPatt = hdulist[0].header['READPATT']
        expTime = hdulist[0].header['EFFEXPTM']
        subArr = hdulist[0].header['SUBARRAY']
        print("ID\t Type\t\t\t Filter\t subAr\t nInts\t nGrps\t rdPatt\t ExpTime (s)")
        print("--------------------------------------------------------------------------------------------------")
        print("MIRISim\t %s\t %s\t %s\t %d\t %d\t %s\t %0.1f" % (detector,im_filter,subArr, nInts,nGroups,readPatt,expTime))
        print("\n\n")

    # fits extension table
    hdulist.info()
# Out:
# ID	 Type			 Filter	 subAr	 nInts	 nGrps	 rdPatt	 ExpTime (s)
# --------------------------------------------------------------------------------------------------
# MIRISim	 MIR_LRS-FIXEDSLIT	 P750L	 FULL	 2	 50	 FAST	 277.5
#
#
#
# Filename: LRS-SLIT_demo_data/det_image_1_MIRIMAGE_P750Lexp1.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     101   ()
#   1  SCI           1 ImageHDU        65   (1032, 1024, 50, 2)   float32
#   2  REFOUT        1 ImageHDU        15   (258, 1024, 50, 2)   float32
#   3  PIXELDQ       1 ImageHDU        11   (1032, 1024)   int32 (rescales to uint32)
#   4  PIXELDQ_DEF    1 BinTableHDU     18   31R x 4C   [J, J, 40A, 128A]
#   5  ASDF          1 ImageHDU         7   (533679276,)   uint8

# %% [markdown]
# #### show the last frame of the first integration for each file

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 6))
axs = axs.ravel()

for n, f in enumerate(input_files):
    with datamodels.open(f) as in_dm:
        axs[n].imshow(in_dm.data[0,-1,:,:], cmap='jet', interpolation='nearest', origin='lower', norm=LogNorm(vmin=1e4,vmax=5e4))
        axs[n].set_facecolor('black')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Level 2A pipeline (ramps-to-slopes)

# %% [markdown]
# #### import the level 2A pipeline class and print description

# %%
from jwst.pipeline import Detector1Pipeline
print(Detector1Pipeline.__doc__)
# Out:
#     Detector1Pipeline: Apply all calibration steps to raw JWST
#     ramps to produce a 2-D slope product. Included steps are:
#     group_scale, dq_init, saturation, ipc, superbias, refpix, rscd,
#     lastframe, linearity, dark_current, persistence, jump detection,
#     ramp_fit, and gain_scale.

# %% [markdown]
# #### run pipeline
# We pass the level 1B files (demo data). The output level 2A files will be saved in the output_dir as '*_rate.fits'

# %%
for f in input_files:
    Detector1Pipeline.call(f, output_use_model=True, save_results=True, output_dir=output_dir,
                           steps={'ipc': {'skip': True}})
# Out:
# 2018-05-01 17:28:41,706 - stpipe.Detector1Pipeline - INFO - Detector1Pipeline instance created.
# 2018-05-01 17:28:41,708 - stpipe.Detector1Pipeline.lastframe - INFO - LastFrameStep instance created.
# 2018-05-01 17:28:41,710 - stpipe.Detector1Pipeline.rscd - INFO - RSCD_Step instance created.
# 2018-05-01 17:28:41,712 - stpipe.Detector1Pipeline.dark_current - INFO - DarkCurrentStep instance created.
# 2018-05-01 17:28:41,714 - stpipe.Detector1Pipeline.group_scale - INFO - GroupScaleStep instance created.
# 2018-05-01 17:28:41,716 - stpipe.Detector1Pipeline.ramp_fit - INFO - RampFitStep instance created.
# 2018-05-01 17:28:41,718 - stpipe.Detector1Pipeline.ipc - INFO - IPCStep instance created.
# 2018-05-01 17:28:41,720 - stpipe.Detector1Pipeline.superbias - INFO - SuperBiasStep instance created.
# 2018-05-01 17:28:41,721 - stpipe.Detector1Pipeline.refpix - INFO - RefPixStep instance created.
# 2018-05-01 17:28:41,723 - stpipe.Detector1Pipeline.firstframe - INFO - FirstFrameStep instance created.
# 2018-05-01 17:28:41,724 - stpipe.Detector1Pipeline.jump - INFO - JumpStep instance created.
# 2018-05-01 17:28:41,726 - stpipe.Detector1Pipeline.saturation - INFO - SaturationStep instance created.
# 2018-05-01 17:28:41,728 - stpipe.Detector1Pipeline.gain_scale - INFO - GainScaleStep instance created.
# 2018-05-01 17:28:41,729 - stpipe.Detector1Pipeline.linearity - INFO - LinearityStep instance created.
# 2018-05-01 17:28:41,731 - stpipe.Detector1Pipeline.persistence - INFO - PersistenceStep instance created.
# 2018-05-01 17:28:41,733 - stpipe.Detector1Pipeline.dq_init - INFO - DQInitStep instance created.
# 2018-05-01 17:28:43,197 - stpipe.Detector1Pipeline - INFO - Prefetch for DARK reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_dark_0058.fits'.
# 2018-05-01 17:28:43,199 - stpipe.Detector1Pipeline - INFO - Prefetch for GAIN reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_gain_0008.fits'.
# 2018-05-01 17:28:43,200 - stpipe.Detector1Pipeline - INFO - Prefetch for LINEARITY reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_linearity_0024.fits'.
# 2018-05-01 17:28:43,201 - stpipe.Detector1Pipeline - INFO - Prefetch for MASK reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_mask_0019.fits'.
# 2018-05-01 17:28:43,202 - stpipe.Detector1Pipeline - INFO - Prefetch for PERSAT reference file is 'N/A'.
# 2018-05-01 17:28:43,203 - stpipe.Detector1Pipeline - INFO - Prefetch for READNOISE reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_readnoise_0040.fits'.
# 2018-05-01 17:28:43,205 - stpipe.Detector1Pipeline - INFO - Prefetch for REFPIX reference file is 'N/A'.
# 2018-05-01 17:28:43,205 - stpipe.Detector1Pipeline - INFO - Prefetch for RSCD reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_rscd_0004.fits'.
# 2018-05-01 17:28:43,206 - stpipe.Detector1Pipeline - INFO - Prefetch for SATURATION reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_saturation_0019.fits'.
# 2018-05-01 17:28:43,207 - stpipe.Detector1Pipeline - INFO - Prefetch for SUPERBIAS reference file is 'N/A'.
# 2018-05-01 17:28:43,207 - stpipe.Detector1Pipeline - INFO - Prefetch for TRAPDENSITY reference file is 'N/A'.
# 2018-05-01 17:28:43,208 - stpipe.Detector1Pipeline - INFO - Prefetch for TRAPPARS reference file is 'N/A'.
# 2018-05-01 17:28:43,209 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline running with args ('LRS-SLIT_demo_data/det_image_1_MIRIMAGE_P750Lexp1.fits',).
# 2018-05-01 17:28:43,209 - stpipe.Detector1Pipeline - INFO - Starting calwebb_detector1 ...
# 2018-05-01 17:28:44,306 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale running with args (<jwst.datamodels.ramp.RampModel object at 0x181cadd668>,).
# 2018-05-01 17:28:44,342 - stpipe.Detector1Pipeline.group_scale - WARNING - NFRAMES=1 is a power of 2
# 2018-05-01 17:28:44,344 - stpipe.Detector1Pipeline.group_scale - WARNING - Step will be skipped
# 2018-05-01 17:28:44,346 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale done
# 2018-05-01 17:28:44,412 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init running with args (<jwst.datamodels.ramp.RampModel object at 0x181c7e7668>,).
# 2018-05-01 17:28:44,450 - stpipe.Detector1Pipeline.dq_init - INFO - Using MASK reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_mask_0019.fits
# 2018-05-01 17:28:46,981 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init done
# 2018-05-01 17:28:47,138 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation running with args (<jwst.datamodels.ramp.RampModel object at 0x187582c7f0>,).
# 2018-05-01 17:28:47,176 - stpipe.Detector1Pipeline.saturation - INFO - Using SATURATION reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_saturation_0019.fits
# 2018-05-01 17:28:48,498 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation done
# 2018-05-01 17:28:48,575 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc running with args (<jwst.datamodels.ramp.RampModel object at 0x187595ac50>,).
# 2018-05-01 17:28:48,576 - stpipe.Detector1Pipeline.ipc - INFO - Step skipped.
# 2018-05-01 17:28:48,578 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc done
# 2018-05-01 17:28:48,631 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity running with args (<jwst.datamodels.ramp.RampModel object at 0x187595ac50>,).
# 2018-05-01 17:28:48,670 - stpipe.Detector1Pipeline.linearity - INFO - Using Linearity reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_linearity_0024.fits
# 2018-05-01 17:28:50,726 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity done
# 2018-05-01 17:28:50,798 - stpipe.Detector1Pipeline.rscd - INFO - Step rscd running with args (<jwst.datamodels.ramp.RampModel object at 0x1875956be0>,).
# 2018-05-01 17:28:50,836 - stpipe.Detector1Pipeline.rscd - INFO - Using RSCD reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_rscd_0004.fits
# 2018-05-01 17:29:34,625 - stpipe.Detector1Pipeline.rscd - INFO - Step rscd done
# 2018-05-01 17:29:34,706 - stpipe.Detector1Pipeline.firstframe - INFO - Step firstframe running with args (<jwst.datamodels.ramp.RampModel object at 0x181c94ed68>,).
# 2018-05-01 17:29:35,562 - stpipe.Detector1Pipeline.firstframe - INFO - Step firstframe done
# 2018-05-01 17:29:35,646 - stpipe.Detector1Pipeline.lastframe - INFO - Step lastframe running with args (<jwst.datamodels.ramp.RampModel object at 0x181cad30f0>,).
# 2018-05-01 17:29:36,437 - stpipe.Detector1Pipeline.lastframe - INFO - Step lastframe done
# 2018-05-01 17:29:36,510 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current running with args (<jwst.datamodels.ramp.RampModel object at 0x18758f1898>,).
# 2018-05-01 17:29:36,555 - stpipe.Detector1Pipeline.dark_current - INFO - Using DARK reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_dark_0058.fits
# 2018-05-01 17:29:36,777 - stpipe.Detector1Pipeline.dark_current - INFO - Science data nints=2, ngroups=50, nframes=1, groupgap=0
# 2018-05-01 17:29:36,777 - stpipe.Detector1Pipeline.dark_current - INFO - Dark data nints=2, ngroups=200, nframes=1, groupgap=0
# 2018-05-01 17:29:47,364 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current done
# 2018-05-01 17:29:47,479 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix running with args (<jwst.datamodels.ramp.RampModel object at 0x181c94ea58>,).
# 2018-05-01 17:29:47,582 - stpipe.Detector1Pipeline.refpix - INFO - use_side_ref_pixels = True
# 2018-05-01 17:29:47,583 - stpipe.Detector1Pipeline.refpix - INFO - odd_even_columns = True
# 2018-05-01 17:29:47,583 - stpipe.Detector1Pipeline.refpix - INFO - side_smoothing_length = 11
# 2018-05-01 17:29:47,584 - stpipe.Detector1Pipeline.refpix - INFO - side_gain = 1.000000
# 2018-05-01 17:29:47,585 - stpipe.Detector1Pipeline.refpix - INFO - odd_even_rows = True
# 2018-05-01 17:29:48,364 - stpipe.Detector1Pipeline.refpix - INFO - Subtracting initial read from each integration
# 2018-05-01 17:29:49,932 - stpipe.Detector1Pipeline.refpix - INFO - Adding initial read back in
# 2018-05-01 17:29:50,972 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix done
# 2018-05-01 17:29:51,040 - stpipe.Detector1Pipeline.jump - INFO - Step jump running with args (<jwst.datamodels.ramp.RampModel object at 0x181c90fe80>,).
# 2018-05-01 17:29:51,074 - stpipe.Detector1Pipeline.jump - INFO - CR rejection threshold = 4 sigma
# 2018-05-01 17:29:51,082 - stpipe.Detector1Pipeline.jump - INFO - Using GAIN reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_gain_0008.fits
# 2018-05-01 17:29:51,134 - stpipe.Detector1Pipeline.jump - INFO - Using READNOISE reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_readnoise_0040.fits
# 2018-05-01 17:29:52,124 - stpipe.Detector1Pipeline.jump - INFO - Executing two-point difference method
# 2018-05-01 17:29:52,683 - stpipe.Detector1Pipeline.jump - INFO -  working on integration 1
# 2018-05-01 17:29:55,731 - stpipe.Detector1Pipeline.jump - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/jump/twopoint_difference.py:83: RuntimeWarning: invalid value encountered in sqrt
#   poisson_noise = np.sqrt(np.abs(med_diffs))
#
# 2018-05-01 17:30:26,873 - stpipe.Detector1Pipeline.jump - INFO -  working on integration 2
# 2018-05-01 17:31:05,228 - stpipe.Detector1Pipeline.jump - INFO - Step jump done
# 2018-05-01 17:31:05,303 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit running with args (<jwst.datamodels.ramp.RampModel object at 0x18758075f8>,).
# 2018-05-01 17:31:05,345 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using READNOISE reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_readnoise_0040.fits
# 2018-05-01 17:31:05,492 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using GAIN reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_gain_0008.fits
# 2018-05-01 17:31:05,528 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using algorithm = ols
# 2018-05-01 17:31:05,529 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using weighting = optimal
# 2018-05-01 17:31:05,533 - stpipe.Detector1Pipeline.ramp_fit - INFO - MIRI dataset has all final reads flagged as DO_NOT_USE.
# 2018-05-01 17:31:05,548 - stpipe.Detector1Pipeline.ramp_fit - INFO - Effective integration time per group: 2.77504
# 2018-05-01 17:32:47,083 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/utils.py:475: RuntimeWarning: divide by zero encountered in true_divide
#   var_poisson = sum_p / (sum_wgt_p * nsegs_pix)
#
# 2018-05-01 17:32:47,084 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/utils.py:475: RuntimeWarning: invalid value encountered in true_divide
#   var_poisson = sum_p / (sum_wgt_p * nsegs_pix)
#
# 2018-05-01 17:32:55,736 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/utils.py:481: RuntimeWarning: divide by zero encountered in true_divide
#   var_r = rn_1d**2 * 12./(segments**3. - segments)
#
# 2018-05-01 17:32:56,523 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/utils.py:485: RuntimeWarning: divide by zero encountered in true_divide
#   sum_r = (segments*var_r[:]/((nsegs_pix)**3.)).sum(axis=0)
#
# 2018-05-01 17:32:56,524 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/utils.py:485: RuntimeWarning: invalid value encountered in true_divide
#   sum_r = (segments*var_r[:]/((nsegs_pix)**3.)).sum(axis=0)
#
# 2018-05-01 17:32:56,720 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/utils.py:489: RuntimeWarning: divide by zero encountered in true_divide
#   var_readnoise = sum_r/nsegs_pix
#
# 2018-05-01 17:32:56,720 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/utils.py:489: RuntimeWarning: invalid value encountered in true_divide
#   var_readnoise = sum_r/nsegs_pix
#
# 2018-05-01 17:35:03,208 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/ramp_fit.py:324: RuntimeWarning: invalid value encountered in sqrt
#   err_2d_all = np.sqrt( var_p_2d_all + var_r_2d_all )
#
# 2018-05-01 17:38:07,008 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/utils.py:620: RuntimeWarning: invalid value encountered in sqrt
#   cubemod.err = np.sqrt(var_p_int + var_r_int)
#
# 2018-05-01 17:38:07,049 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of groups per integration: 50
# 2018-05-01 17:38:07,050 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of integrations: 2
# 2018-05-01 17:38:07,353 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit done
# 2018-05-01 17:38:07,537 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<jwst.datamodels.image.ImageModel object at 0x1875807fd0>,).
# 2018-05-01 17:38:07,626 - stpipe.Detector1Pipeline.gain_scale - INFO - GAINFACT not found in gain reference file
# 2018-05-01 17:38:07,627 - stpipe.Detector1Pipeline.gain_scale - INFO - Step will be skipped
# 2018-05-01 17:38:07,631 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# 2018-05-01 17:38:07,709 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<jwst.datamodels.cube.CubeModel object at 0x181caaff28>,).
# 2018-05-01 17:38:07,784 - stpipe.Detector1Pipeline.gain_scale - INFO - GAINFACT not found in gain reference file
# 2018-05-01 17:38:07,785 - stpipe.Detector1Pipeline.gain_scale - INFO - Step will be skipped
# 2018-05-01 17:38:07,788 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# 2018-05-01 17:38:07,932 - stpipe.Detector1Pipeline - INFO - Saved model in LRS-SLIT_demo_data_pipeline/det_image_1_MIRIMAGE_P750Lexp1_rateints.fits
# 2018-05-01 17:38:07,933 - stpipe.Detector1Pipeline - INFO - ... ending calwebb_detector1
# 2018-05-01 17:38:08,023 - stpipe.Detector1Pipeline - INFO - Saved model in LRS-SLIT_demo_data_pipeline/det_image_1_MIRIMAGE_P750Lexp1_rate.fits
# 2018-05-01 17:38:08,024 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline done
# 2018-05-01 17:38:08,037 - stpipe.Detector1Pipeline - INFO - Detector1Pipeline instance created.
# 2018-05-01 17:38:08,038 - stpipe.Detector1Pipeline.lastframe - INFO - LastFrameStep instance created.
# 2018-05-01 17:38:08,040 - stpipe.Detector1Pipeline.rscd - INFO - RSCD_Step instance created.
# 2018-05-01 17:38:08,042 - stpipe.Detector1Pipeline.dark_current - INFO - DarkCurrentStep instance created.
# 2018-05-01 17:38:08,044 - stpipe.Detector1Pipeline.group_scale - INFO - GroupScaleStep instance created.
# 2018-05-01 17:38:08,045 - stpipe.Detector1Pipeline.ramp_fit - INFO - RampFitStep instance created.
# 2018-05-01 17:38:08,048 - stpipe.Detector1Pipeline.ipc - INFO - IPCStep instance created.
# 2018-05-01 17:38:08,049 - stpipe.Detector1Pipeline.superbias - INFO - SuperBiasStep instance created.
# 2018-05-01 17:38:08,051 - stpipe.Detector1Pipeline.refpix - INFO - RefPixStep instance created.
# 2018-05-01 17:38:08,053 - stpipe.Detector1Pipeline.firstframe - INFO - FirstFrameStep instance created.
# 2018-05-01 17:38:08,055 - stpipe.Detector1Pipeline.jump - INFO - JumpStep instance created.
# 2018-05-01 17:38:08,056 - stpipe.Detector1Pipeline.saturation - INFO - SaturationStep instance created.
# 2018-05-01 17:38:08,058 - stpipe.Detector1Pipeline.gain_scale - INFO - GainScaleStep instance created.
# 2018-05-01 17:38:08,060 - stpipe.Detector1Pipeline.linearity - INFO - LinearityStep instance created.
# 2018-05-01 17:38:08,062 - stpipe.Detector1Pipeline.persistence - INFO - PersistenceStep instance created.
# 2018-05-01 17:38:08,064 - stpipe.Detector1Pipeline.dq_init - INFO - DQInitStep instance created.
# 2018-05-01 17:38:09,098 - stpipe.Detector1Pipeline - INFO - Prefetch for DARK reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_dark_0058.fits'.
# 2018-05-01 17:38:09,099 - stpipe.Detector1Pipeline - INFO - Prefetch for GAIN reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_gain_0008.fits'.
# 2018-05-01 17:38:09,100 - stpipe.Detector1Pipeline - INFO - Prefetch for LINEARITY reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_linearity_0024.fits'.
# 2018-05-01 17:38:09,100 - stpipe.Detector1Pipeline - INFO - Prefetch for MASK reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_mask_0019.fits'.
# 2018-05-01 17:38:09,101 - stpipe.Detector1Pipeline - INFO - Prefetch for PERSAT reference file is 'N/A'.
# 2018-05-01 17:38:09,102 - stpipe.Detector1Pipeline - INFO - Prefetch for READNOISE reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_readnoise_0040.fits'.
# 2018-05-01 17:38:09,102 - stpipe.Detector1Pipeline - INFO - Prefetch for REFPIX reference file is 'N/A'.
# 2018-05-01 17:38:09,103 - stpipe.Detector1Pipeline - INFO - Prefetch for RSCD reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_rscd_0004.fits'.
# 2018-05-01 17:38:09,104 - stpipe.Detector1Pipeline - INFO - Prefetch for SATURATION reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_saturation_0019.fits'.
# 2018-05-01 17:38:09,105 - stpipe.Detector1Pipeline - INFO - Prefetch for SUPERBIAS reference file is 'N/A'.
# 2018-05-01 17:38:09,106 - stpipe.Detector1Pipeline - INFO - Prefetch for TRAPDENSITY reference file is 'N/A'.
# 2018-05-01 17:38:09,107 - stpipe.Detector1Pipeline - INFO - Prefetch for TRAPPARS reference file is 'N/A'.
# 2018-05-01 17:38:09,107 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline running with args ('LRS-SLIT_demo_data/det_image_2_MIRIMAGE_P750Lexp1.fits',).
# 2018-05-01 17:38:09,108 - stpipe.Detector1Pipeline - INFO - Starting calwebb_detector1 ...
# 2018-05-01 17:38:10,221 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale running with args (<jwst.datamodels.ramp.RampModel object at 0x181c9571d0>,).
# 2018-05-01 17:38:10,253 - stpipe.Detector1Pipeline.group_scale - WARNING - NFRAMES=1 is a power of 2
# 2018-05-01 17:38:10,254 - stpipe.Detector1Pipeline.group_scale - WARNING - Step will be skipped
# 2018-05-01 17:38:10,256 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale done
# 2018-05-01 17:38:10,325 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init running with args (<jwst.datamodels.ramp.RampModel object at 0x181caf2128>,).
# 2018-05-01 17:38:10,364 - stpipe.Detector1Pipeline.dq_init - INFO - Using MASK reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_mask_0019.fits
# 2018-05-01 17:38:11,285 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init done
# 2018-05-01 17:38:11,457 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation running with args (<jwst.datamodels.ramp.RampModel object at 0x18757f4710>,).
# 2018-05-01 17:38:11,494 - stpipe.Detector1Pipeline.saturation - INFO - Using SATURATION reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_saturation_0019.fits
# 2018-05-01 17:38:12,830 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation done
# 2018-05-01 17:38:12,911 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc running with args (<jwst.datamodels.ramp.RampModel object at 0x185df40390>,).
# 2018-05-01 17:38:12,911 - stpipe.Detector1Pipeline.ipc - INFO - Step skipped.
# 2018-05-01 17:38:12,913 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc done
# 2018-05-01 17:38:12,990 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity running with args (<jwst.datamodels.ramp.RampModel object at 0x185df40390>,).
# 2018-05-01 17:38:13,029 - stpipe.Detector1Pipeline.linearity - INFO - Using Linearity reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_linearity_0024.fits
# 2018-05-01 17:38:14,683 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity done
# 2018-05-01 17:38:14,763 - stpipe.Detector1Pipeline.rscd - INFO - Step rscd running with args (<jwst.datamodels.ramp.RampModel object at 0x18759564e0>,).
# 2018-05-01 17:38:14,801 - stpipe.Detector1Pipeline.rscd - INFO - Using RSCD reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_rscd_0004.fits
# 2018-05-01 17:39:01,995 - stpipe.Detector1Pipeline.rscd - INFO - Step rscd done
# 2018-05-01 17:39:02,084 - stpipe.Detector1Pipeline.firstframe - INFO - Step firstframe running with args (<jwst.datamodels.ramp.RampModel object at 0x10db10780>,).
# 2018-05-01 17:39:02,964 - stpipe.Detector1Pipeline.firstframe - INFO - Step firstframe done
# 2018-05-01 17:39:03,035 - stpipe.Detector1Pipeline.lastframe - INFO - Step lastframe running with args (<jwst.datamodels.ramp.RampModel object at 0x181c938eb8>,).
# 2018-05-01 17:39:03,843 - stpipe.Detector1Pipeline.lastframe - INFO - Step lastframe done
# 2018-05-01 17:39:03,913 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current running with args (<jwst.datamodels.ramp.RampModel object at 0x181cad3fd0>,).
# 2018-05-01 17:39:03,952 - stpipe.Detector1Pipeline.dark_current - INFO - Using DARK reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_dark_0058.fits
# 2018-05-01 17:39:04,166 - stpipe.Detector1Pipeline.dark_current - INFO - Science data nints=2, ngroups=50, nframes=1, groupgap=0
# 2018-05-01 17:39:04,167 - stpipe.Detector1Pipeline.dark_current - INFO - Dark data nints=2, ngroups=200, nframes=1, groupgap=0
# 2018-05-01 17:39:11,587 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current done
# 2018-05-01 17:39:11,689 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix running with args (<jwst.datamodels.ramp.RampModel object at 0x18757f4240>,).
# 2018-05-01 17:39:11,802 - stpipe.Detector1Pipeline.refpix - INFO - use_side_ref_pixels = True
# 2018-05-01 17:39:11,803 - stpipe.Detector1Pipeline.refpix - INFO - odd_even_columns = True
# 2018-05-01 17:39:11,803 - stpipe.Detector1Pipeline.refpix - INFO - side_smoothing_length = 11
# 2018-05-01 17:39:11,804 - stpipe.Detector1Pipeline.refpix - INFO - side_gain = 1.000000
# 2018-05-01 17:39:11,805 - stpipe.Detector1Pipeline.refpix - INFO - odd_even_rows = True
# 2018-05-01 17:39:12,611 - stpipe.Detector1Pipeline.refpix - INFO - Subtracting initial read from each integration
# 2018-05-01 17:39:14,276 - stpipe.Detector1Pipeline.refpix - INFO - Adding initial read back in
# 2018-05-01 17:39:15,355 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix done
# 2018-05-01 17:39:15,427 - stpipe.Detector1Pipeline.jump - INFO - Step jump running with args (<jwst.datamodels.ramp.RampModel object at 0x181c8b4550>,).
# 2018-05-01 17:39:15,460 - stpipe.Detector1Pipeline.jump - INFO - CR rejection threshold = 4 sigma
# 2018-05-01 17:39:15,467 - stpipe.Detector1Pipeline.jump - INFO - Using GAIN reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_gain_0008.fits
# 2018-05-01 17:39:15,514 - stpipe.Detector1Pipeline.jump - INFO - Using READNOISE reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_readnoise_0040.fits
# 2018-05-01 17:39:16,536 - stpipe.Detector1Pipeline.jump - INFO - Executing two-point difference method
# 2018-05-01 17:39:17,148 - stpipe.Detector1Pipeline.jump - INFO -  working on integration 1
# 2018-05-01 17:39:21,100 - stpipe.Detector1Pipeline.jump - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/jump/twopoint_difference.py:83: RuntimeWarning: invalid value encountered in sqrt
#   poisson_noise = np.sqrt(np.abs(med_diffs))
#
# 2018-05-01 17:39:55,469 - stpipe.Detector1Pipeline.jump - INFO -  working on integration 2
# 2018-05-01 17:40:37,745 - stpipe.Detector1Pipeline.jump - INFO - Step jump done
# 2018-05-01 17:40:37,816 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit running with args (<jwst.datamodels.ramp.RampModel object at 0x181c945ef0>,).
# 2018-05-01 17:40:37,863 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using READNOISE reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_readnoise_0040.fits
# 2018-05-01 17:40:38,040 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using GAIN reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_gain_0008.fits
# 2018-05-01 17:40:38,076 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using algorithm = ols
# 2018-05-01 17:40:38,077 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using weighting = optimal
# 2018-05-01 17:40:38,081 - stpipe.Detector1Pipeline.ramp_fit - INFO - MIRI dataset has all final reads flagged as DO_NOT_USE.
# 2018-05-01 17:40:38,101 - stpipe.Detector1Pipeline.ramp_fit - INFO - Effective integration time per group: 2.77504
# 2018-05-01 17:42:27,428 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/utils.py:475: RuntimeWarning: invalid value encountered in true_divide
#   var_poisson = sum_p / (sum_wgt_p * nsegs_pix)
#
# 2018-05-01 17:42:35,429 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/utils.py:481: RuntimeWarning: divide by zero encountered in true_divide
#   var_r = rn_1d**2 * 12./(segments**3. - segments)
#
# 2018-05-01 17:42:36,017 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/utils.py:485: RuntimeWarning: divide by zero encountered in true_divide
#   sum_r = (segments*var_r[:]/((nsegs_pix)**3.)).sum(axis=0)
#
# 2018-05-01 17:42:36,018 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/utils.py:485: RuntimeWarning: invalid value encountered in true_divide
#   sum_r = (segments*var_r[:]/((nsegs_pix)**3.)).sum(axis=0)
#
# 2018-05-01 17:42:36,130 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/utils.py:489: RuntimeWarning: divide by zero encountered in true_divide
#   var_readnoise = sum_r/nsegs_pix
#
# 2018-05-01 17:42:36,131 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/utils.py:489: RuntimeWarning: invalid value encountered in true_divide
#   var_readnoise = sum_r/nsegs_pix
#
# 2018-05-01 17:44:22,312 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/utils.py:475: RuntimeWarning: divide by zero encountered in true_divide
#   var_poisson = sum_p / (sum_wgt_p * nsegs_pix)
#
# 2018-05-01 17:44:32,040 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/ramp_fit.py:324: RuntimeWarning: invalid value encountered in sqrt
#   err_2d_all = np.sqrt( var_p_2d_all + var_r_2d_all )
#
# 2018-05-01 17:47:25,103 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/utils.py:620: RuntimeWarning: invalid value encountered in sqrt
#   cubemod.err = np.sqrt(var_p_int + var_r_int)
#
# 2018-05-01 17:47:25,140 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of groups per integration: 50
# 2018-05-01 17:47:25,141 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of integrations: 2
# 2018-05-01 17:47:25,572 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit done
# 2018-05-01 17:47:25,743 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<jwst.datamodels.image.ImageModel object at 0x18759c26a0>,).
# 2018-05-01 17:47:25,816 - stpipe.Detector1Pipeline.gain_scale - INFO - GAINFACT not found in gain reference file
# 2018-05-01 17:47:25,817 - stpipe.Detector1Pipeline.gain_scale - INFO - Step will be skipped
# 2018-05-01 17:47:25,820 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# 2018-05-01 17:47:25,896 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<jwst.datamodels.cube.CubeModel object at 0x181ca93240>,).
# 2018-05-01 17:47:25,984 - stpipe.Detector1Pipeline.gain_scale - INFO - GAINFACT not found in gain reference file
# 2018-05-01 17:47:25,984 - stpipe.Detector1Pipeline.gain_scale - INFO - Step will be skipped
# 2018-05-01 17:47:25,988 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# 2018-05-01 17:47:26,125 - stpipe.Detector1Pipeline - INFO - Saved model in LRS-SLIT_demo_data_pipeline/det_image_2_MIRIMAGE_P750Lexp1_rateints.fits
# 2018-05-01 17:47:26,126 - stpipe.Detector1Pipeline - INFO - ... ending calwebb_detector1
# 2018-05-01 17:47:26,214 - stpipe.Detector1Pipeline - INFO - Saved model in LRS-SLIT_demo_data_pipeline/det_image_2_MIRIMAGE_P750Lexp1_rate.fits
# 2018-05-01 17:47:26,215 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline done

# %% [markdown]
# #### Quick check of the pipeline steps applied in the output:

# %%
level2A_files = glob.glob(os.path.join(output_dir,'*_rate.fits'))

with datamodels.open(level2A_files[0]) as dm:
    # check the calibration step information
    print('Check step information status:')
    print('dq_init: %s' % dm.meta.cal_step.dq_init)
    print('saturation: %s' % dm.meta.cal_step.saturation)
    print('linearity: %s' % dm.meta.cal_step.linearity)
    print('rscd: %s' % dm.meta.cal_step.rscd)
    print('lastframe: %s' % dm.meta.cal_step.lastframe)
    print('dark_current: %s' % dm.meta.cal_step.dark_sub)
    print('refpix: %s' % dm.meta.cal_step.refpix)
    print('jump: %s' % dm.meta.cal_step.jump)
    print('ramp_fit: %s' % dm.meta.cal_step.ramp_fit)
# Out:
# Check step information status:
# dq_init: COMPLETE
# saturation: COMPLETE
# linearity: COMPLETE
# rscd: COMPLETE
# lastframe: COMPLETE
# dark_current: COMPLETE
# refpix: COMPLETE
# jump: COMPLETE
# ramp_fit: COMPLETE

# %% [markdown]
# ### Level 2B pipeline

# %% [markdown]
# #### import the level 2B pipeline class and print description

# %%
from jwst.pipeline import Spec2Pipeline
print(Spec2Pipeline.__doc__)
# Out:
#     Spec2Pipeline: Processes JWST spectroscopic exposures from Level 2a to 2b.
#     Accepts a single exposure or an association as input.
#
#     Included steps are:
#     assign_wcs, background subtraction, NIRSpec MSA imprint subtraction,
#     NIRSpec MSA bad shutter flagging, 2-D subwindow extraction, flat field,
#     source type decision, straylight, fringe, pathloss, barshadow,  photom,
#     resample_spec, cube_build, and extract_1d.

# %% [markdown]
# The bkg_subtract subtract step requires an association file defining the source and background exposures. At the moment, there is no easy way to create one, so we define it manually in a cell and write to the association json file.
#
# Note that the first nod in the MIRISim simulations is actually the background nod so we define this in the association file.

# %%
import json

data = {
        "degraded_status": "No known degraded exposures in association.",
        "asn_rule": "DMS_Level3_Base",
        "asn_pool": "none",
        "asn_type": "None",
        "constraints": "No constraints",
        "program": "none",
        "code_version": "0.7.2.beta5",
        "asn_id": "a3001",
        "products": [
        {
            "name": "lrs_bgsub_1",
            "members": [
                {
                    "expname": "LRS-SLIT_demo_data_pipeline/det_image_2_MIRIMAGE_P750Lexp1_rate.fits",
                    "exptype": "science"
                },
                {
                    "expname": "LRS-SLIT_demo_data_pipeline/det_image_1_MIRIMAGE_P750Lexp1_rate.fits",
                    "exptype": "background"
                }
            ]
        }
    ],
    "target": "none"
}

with open('LRS_lvl2_asn.json', 'w') as outfile:  
    json.dump(data, outfile)

# %% [markdown]
# #### run pipeline
# We pass the level 2 assocation file. The output is contained in the dm_2B data model and saved to a fits file ending in '_cal.fits'.
#
# The call to the pipeline will also extract a spectrum from this _cal.fits file (ending in _x1d.fits).

# %%
Spec2Pipeline.call('LRS_lvl2_asn.json', save_results=True, output_dir=output_dir, steps={'extract_1d':{'save_results':True}})
# Out:
# 2018-05-01 17:47:26,460 - stpipe.Spec2Pipeline - INFO - Spec2Pipeline instance created.
# 2018-05-01 17:47:26,462 - stpipe.Spec2Pipeline.bkg_subtract - INFO - BackgroundStep instance created.
# 2018-05-01 17:47:26,464 - stpipe.Spec2Pipeline.fringe - INFO - FringeStep instance created.
# 2018-05-01 17:47:26,466 - stpipe.Spec2Pipeline.extract_2d - INFO - Extract2dStep instance created.
# 2018-05-01 17:47:26,468 - stpipe.Spec2Pipeline.straylight - INFO - StraylightStep instance created.
# 2018-05-01 17:47:26,470 - stpipe.Spec2Pipeline.msa_flagging - INFO - MSAFlagOpenStep instance created.
# 2018-05-01 17:47:26,472 - stpipe.Spec2Pipeline.resample_spec - INFO - ResampleSpecStep instance created.
# 2018-05-01 17:47:26,474 - stpipe.Spec2Pipeline.extract_1d - INFO - Extract1dStep instance created.
# 2018-05-01 17:47:26,477 - stpipe.Spec2Pipeline.cube_build - INFO - CubeBuildStep instance created.
# 2018-05-01 17:47:26,479 - stpipe.Spec2Pipeline.assign_wcs - INFO - AssignWcsStep instance created.
# 2018-05-01 17:47:26,481 - stpipe.Spec2Pipeline.flat_field - INFO - FlatFieldStep instance created.
# 2018-05-01 17:47:26,483 - stpipe.Spec2Pipeline.barshadow - INFO - BarShadowStep instance created.
# 2018-05-01 17:47:26,485 - stpipe.Spec2Pipeline.imprint_subtract - INFO - ImprintStep instance created.
# 2018-05-01 17:47:26,486 - stpipe.Spec2Pipeline.srctype - INFO - SourceTypeStep instance created.
# 2018-05-01 17:47:26,488 - stpipe.Spec2Pipeline.photom - INFO - PhotomStep instance created.
# 2018-05-01 17:47:26,490 - stpipe.Spec2Pipeline.pathloss - INFO - PathLossStep instance created.
# 2018-05-01 17:47:26,825 - stpipe.Spec2Pipeline - INFO - Prefetch for AREA reference file is 'N/A'.
# 2018-05-01 17:47:26,826 - stpipe.Spec2Pipeline - INFO - Prefetch for BARSHADOW reference file is 'N/A'.
# 2018-05-01 17:47:26,827 - stpipe.Spec2Pipeline - INFO - Prefetch for CAMERA reference file is 'N/A'.
# 2018-05-01 17:47:26,827 - stpipe.Spec2Pipeline - INFO - Prefetch for COLLIMATOR reference file is 'N/A'.
# 2018-05-01 17:47:26,828 - stpipe.Spec2Pipeline - INFO - Prefetch for CUBEPAR reference file is 'N/A'.
# 2018-05-01 17:47:26,829 - stpipe.Spec2Pipeline - INFO - Prefetch for DFLAT reference file is 'N/A'.
# 2018-05-01 17:47:26,830 - stpipe.Spec2Pipeline - INFO - Prefetch for DISPERSER reference file is 'N/A'.
# 2018-05-01 17:47:26,830 - stpipe.Spec2Pipeline - INFO - Prefetch for DISTORTION reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_distortion_0023.asdf'.
# 2018-05-01 17:47:26,832 - stpipe.Spec2Pipeline - INFO - Prefetch for DRIZPARS reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_drizpars_0001.fits'.
# 2018-05-01 17:47:26,834 - stpipe.Spec2Pipeline - INFO - Prefetch for EXTRACT1D reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_extract1d_0004.json'.
# 2018-05-01 17:47:26,835 - stpipe.Spec2Pipeline - INFO - Prefetch for FFLAT reference file is 'N/A'.
# 2018-05-01 17:47:26,836 - stpipe.Spec2Pipeline - INFO - Prefetch for FILTEROFFSET reference file is 'N/A'.
# 2018-05-01 17:47:26,837 - stpipe.Spec2Pipeline - INFO - Prefetch for FLAT reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_flat_0244.fits'.
# 2018-05-01 17:47:26,838 - stpipe.Spec2Pipeline - INFO - Prefetch for FORE reference file is 'N/A'.
# 2018-05-01 17:47:26,839 - stpipe.Spec2Pipeline - INFO - Prefetch for FPA reference file is 'N/A'.
# 2018-05-01 17:47:26,840 - stpipe.Spec2Pipeline - INFO - Prefetch for FRINGE reference file is 'N/A'.
# 2018-05-01 17:47:26,840 - stpipe.Spec2Pipeline - INFO - Prefetch for IFUFORE reference file is 'N/A'.
# 2018-05-01 17:47:26,841 - stpipe.Spec2Pipeline - INFO - Prefetch for IFUPOST reference file is 'N/A'.
# 2018-05-01 17:47:26,842 - stpipe.Spec2Pipeline - INFO - Prefetch for IFUSLICER reference file is 'N/A'.
# 2018-05-01 17:47:26,842 - stpipe.Spec2Pipeline - INFO - Prefetch for MSA reference file is 'N/A'.
# 2018-05-01 17:47:26,843 - stpipe.Spec2Pipeline - INFO - Prefetch for MSAOPER reference file is 'N/A'.
# 2018-05-01 17:47:26,843 - stpipe.Spec2Pipeline - INFO - Prefetch for OTE reference file is 'N/A'.
# 2018-05-01 17:47:26,845 - stpipe.Spec2Pipeline - INFO - Prefetch for PATHLOSS reference file is 'N/A'.
# 2018-05-01 17:47:26,845 - stpipe.Spec2Pipeline - INFO - Prefetch for PHOTOM reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_photom_0014.fits'.
# 2018-05-01 17:47:26,846 - stpipe.Spec2Pipeline - INFO - Prefetch for REGIONS reference file is 'N/A'.
# 2018-05-01 17:47:26,847 - stpipe.Spec2Pipeline - INFO - Prefetch for RESOL reference file is 'N/A'.
# 2018-05-01 17:47:26,847 - stpipe.Spec2Pipeline - INFO - Prefetch for SFLAT reference file is 'N/A'.
# 2018-05-01 17:47:26,848 - stpipe.Spec2Pipeline - INFO - Prefetch for SPECWCS reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_specwcs_0001.fits'.
# 2018-05-01 17:47:26,849 - stpipe.Spec2Pipeline - INFO - Prefetch for STRAYMASK reference file is 'N/A'.
# 2018-05-01 17:47:26,849 - stpipe.Spec2Pipeline - INFO - Prefetch for WAVECORR reference file is 'N/A'.
# 2018-05-01 17:47:26,850 - stpipe.Spec2Pipeline - INFO - Prefetch for WAVELENGTHRANGE reference file is 'N/A'.
# 2018-05-01 17:47:27,035 - stpipe.Spec2Pipeline - INFO - Prefetch for AREA reference file is 'N/A'.
# 2018-05-01 17:47:27,036 - stpipe.Spec2Pipeline - INFO - Prefetch for BARSHADOW reference file is 'N/A'.
# 2018-05-01 17:47:27,036 - stpipe.Spec2Pipeline - INFO - Prefetch for CAMERA reference file is 'N/A'.
# 2018-05-01 17:47:27,037 - stpipe.Spec2Pipeline - INFO - Prefetch for COLLIMATOR reference file is 'N/A'.
# 2018-05-01 17:47:27,038 - stpipe.Spec2Pipeline - INFO - Prefetch for CUBEPAR reference file is 'N/A'.
# 2018-05-01 17:47:27,038 - stpipe.Spec2Pipeline - INFO - Prefetch for DFLAT reference file is 'N/A'.
# 2018-05-01 17:47:27,039 - stpipe.Spec2Pipeline - INFO - Prefetch for DISPERSER reference file is 'N/A'.
# 2018-05-01 17:47:27,039 - stpipe.Spec2Pipeline - INFO - Prefetch for DISTORTION reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_distortion_0023.asdf'.
# 2018-05-01 17:47:27,040 - stpipe.Spec2Pipeline - INFO - Prefetch for DRIZPARS reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_drizpars_0001.fits'.
# 2018-05-01 17:47:27,042 - stpipe.Spec2Pipeline - INFO - Prefetch for EXTRACT1D reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_extract1d_0004.json'.
# 2018-05-01 17:47:27,043 - stpipe.Spec2Pipeline - INFO - Prefetch for FFLAT reference file is 'N/A'.
# 2018-05-01 17:47:27,043 - stpipe.Spec2Pipeline - INFO - Prefetch for FILTEROFFSET reference file is 'N/A'.
# 2018-05-01 17:47:27,045 - stpipe.Spec2Pipeline - INFO - Prefetch for FLAT reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_flat_0244.fits'.
# 2018-05-01 17:47:27,046 - stpipe.Spec2Pipeline - INFO - Prefetch for FORE reference file is 'N/A'.
# 2018-05-01 17:47:27,047 - stpipe.Spec2Pipeline - INFO - Prefetch for FPA reference file is 'N/A'.
# 2018-05-01 17:47:27,048 - stpipe.Spec2Pipeline - INFO - Prefetch for FRINGE reference file is 'N/A'.
# 2018-05-01 17:47:27,049 - stpipe.Spec2Pipeline - INFO - Prefetch for IFUFORE reference file is 'N/A'.
# 2018-05-01 17:47:27,049 - stpipe.Spec2Pipeline - INFO - Prefetch for IFUPOST reference file is 'N/A'.
# 2018-05-01 17:47:27,050 - stpipe.Spec2Pipeline - INFO - Prefetch for IFUSLICER reference file is 'N/A'.
# 2018-05-01 17:47:27,051 - stpipe.Spec2Pipeline - INFO - Prefetch for MSA reference file is 'N/A'.
# 2018-05-01 17:47:27,052 - stpipe.Spec2Pipeline - INFO - Prefetch for MSAOPER reference file is 'N/A'.
# 2018-05-01 17:47:27,052 - stpipe.Spec2Pipeline - INFO - Prefetch for OTE reference file is 'N/A'.
# 2018-05-01 17:47:27,053 - stpipe.Spec2Pipeline - INFO - Prefetch for PATHLOSS reference file is 'N/A'.
# 2018-05-01 17:47:27,054 - stpipe.Spec2Pipeline - INFO - Prefetch for PHOTOM reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_photom_0014.fits'.
# 2018-05-01 17:47:27,055 - stpipe.Spec2Pipeline - INFO - Prefetch for REGIONS reference file is 'N/A'.
# 2018-05-01 17:47:27,056 - stpipe.Spec2Pipeline - INFO - Prefetch for RESOL reference file is 'N/A'.
# 2018-05-01 17:47:27,056 - stpipe.Spec2Pipeline - INFO - Prefetch for SFLAT reference file is 'N/A'.
# 2018-05-01 17:47:27,057 - stpipe.Spec2Pipeline - INFO - Prefetch for SPECWCS reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_specwcs_0001.fits'.
# 2018-05-01 17:47:27,058 - stpipe.Spec2Pipeline - INFO - Prefetch for STRAYMASK reference file is 'N/A'.
# 2018-05-01 17:47:27,059 - stpipe.Spec2Pipeline - INFO - Prefetch for WAVECORR reference file is 'N/A'.
# 2018-05-01 17:47:27,060 - stpipe.Spec2Pipeline - INFO - Prefetch for WAVELENGTHRANGE reference file is 'N/A'.
# 2018-05-01 17:47:27,061 - stpipe.Spec2Pipeline - INFO - Step Spec2Pipeline running with args ('LRS_lvl2_asn.json',).
# 2018-05-01 17:47:27,062 - stpipe.Spec2Pipeline - INFO - Starting calwebb_spec2 ...
# 2018-05-01 17:47:27,072 - stpipe.Spec2Pipeline - INFO - Processing product lrs_bgsub_1
# 2018-05-01 17:47:27,073 - stpipe.Spec2Pipeline - INFO - Working on input LRS-SLIT_demo_data_pipeline/det_image_2_MIRIMAGE_P750Lexp1_rate.fits ...
# 2018-05-01 17:47:27,333 - stpipe.Spec2Pipeline.assign_wcs - INFO - Step assign_wcs running with args (<jwst.datamodels.image.ImageModel object at 0x10db42f60>,).
# 2018-05-01 17:47:28,786 - stpipe.Spec2Pipeline.assign_wcs - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/assign_wcs/util.py:559: RuntimeWarning: invalid value encountered in less
#   negative_ind = footprint[0] < 0
#
# 2018-05-01 17:47:28,788 - stpipe.Spec2Pipeline.assign_wcs - INFO - There are NaNs in s_region
# 2018-05-01 17:47:28,788 - stpipe.Spec2Pipeline.assign_wcs - INFO - COMPLETED assign_wcs
# 2018-05-01 17:47:28,796 - stpipe.Spec2Pipeline.assign_wcs - INFO - Step assign_wcs done
# 2018-05-01 17:47:28,876 - stpipe.Spec2Pipeline.bkg_subtract - INFO - Step bkg_subtract running with args (<jwst.datamodels.image.ImageModel object at 0x10e67cfd0>, ['LRS-SLIT_demo_data_pipeline/det_image_1_MIRIMAGE_P750Lexp1_rate.fits']).
# 2018-05-01 17:47:29,141 - stpipe.Spec2Pipeline.bkg_subtract - WARNING - /Users/patrickkavanagh/anaconda/envs/jwst0.9.2/lib/python3.5/site-packages/jwst-0.9.2-py3.5-macosx-10.6-x86_64.egg/jwst/background/background_sub.py:94: RuntimeWarning: invalid value encountered in sqrt
#   avg_bkg.err = np.sqrt(avg_bkg.err) / num_bkg  # err is uncertainty in the mean
#
# 2018-05-01 17:47:29,263 - stpipe.Spec2Pipeline.bkg_subtract - INFO - Step bkg_subtract done
# 2018-05-01 17:47:29,357 - stpipe.Spec2Pipeline.flat_field - INFO - Step flat_field running with args (<jwst.datamodels.image.ImageModel object at 0x18759c2668>,).
# 2018-05-01 17:47:29,528 - stpipe.Spec2Pipeline.flat_field - WARNING - Keyword CDP_PARTIAL_DATA does not correspond to an existing DQ mnemonic, so will be ignored
# 2018-05-01 17:47:29,529 - stpipe.Spec2Pipeline.flat_field - WARNING - Keyword CDP_LOW_QUAL does not correspond to an existing DQ mnemonic, so will be ignored
# 2018-05-01 17:47:29,530 - stpipe.Spec2Pipeline.flat_field - WARNING - Keyword CDP_UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2018-05-01 17:47:29,536 - stpipe.Spec2Pipeline.flat_field - WARNING - Keyword DIFF_PATTERN does not correspond to an existing DQ mnemonic, so will be ignored
# 2018-05-01 17:47:29,668 - stpipe.Spec2Pipeline.flat_field - INFO - Step flat_field done
# 2018-05-01 17:47:29,745 - stpipe.Spec2Pipeline.srctype - INFO - Step srctype running with args (<jwst.datamodels.image.ImageModel object at 0x10db59128>,).
# 2018-05-01 17:47:29,787 - stpipe.Spec2Pipeline.srctype - INFO - Input EXP_TYPE is MIR_LRS-FIXEDSLIT
# 2018-05-01 17:47:29,788 - stpipe.Spec2Pipeline.srctype - INFO - Input SRCTYPE is unknown. Setting to default value of POINT
# 2018-05-01 17:47:29,791 - stpipe.Spec2Pipeline.srctype - INFO - Step srctype done
# 2018-05-01 17:47:29,869 - stpipe.Spec2Pipeline.photom - INFO - Step photom running with args (<jwst.datamodels.image.ImageModel object at 0x18758f86d8>,).
# 2018-05-01 17:47:29,911 - stpipe.Spec2Pipeline.photom - INFO - Using photom reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_photom_0014.fits
# 2018-05-01 17:47:29,915 - stpipe.Spec2Pipeline.photom - INFO - Using area reference file: N/A
# 2018-05-01 17:47:29,916 - stpipe.Spec2Pipeline.photom - INFO - Using instrument: MIRI
# 2018-05-01 17:47:29,917 - stpipe.Spec2Pipeline.photom - INFO -  detector: MIRIMAGE
# 2018-05-01 17:47:29,918 - stpipe.Spec2Pipeline.photom - INFO -  exp_type: MIR_LRS-FIXEDSLIT
# 2018-05-01 17:47:29,918 - stpipe.Spec2Pipeline.photom - INFO -  filter: P750L
# 2018-05-01 17:47:29,989 - stpipe.Spec2Pipeline.photom - INFO -  subarray: FULL
# 2018-05-01 17:47:29,992 - stpipe.Spec2Pipeline.photom - INFO - PHOTMJSR value: 1
# 2018-05-01 17:47:29,996 - stpipe.Spec2Pipeline.photom - INFO - Storing relative response table
# 2018-05-01 17:47:30,001 - stpipe.Spec2Pipeline.photom - INFO - Step photom done
# 2018-05-01 17:47:30,081 - stpipe.Spec2Pipeline.extract_1d - INFO - Step extract_1d running with args (<jwst.datamodels.image.ImageModel object at 0x181c8f8e10>,).
# 2018-05-01 17:47:30,122 - stpipe.Spec2Pipeline.extract_1d - INFO - Using EXTRACT1D reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_extract1d_0004.json
# 2018-05-01 17:47:30,184 - stpipe.Spec2Pipeline.extract_1d - WARNING - spectral_order is None; using 1
# 2018-05-01 17:47:30,222 - stpipe.Spec2Pipeline.extract_1d - WARNING - 1 NaNs in wavelength array
# 2018-05-01 17:47:30,285 - stpipe.Spec2Pipeline.extract_1d - INFO - Output arrays have been trimmed by 1 elements
# 2018-05-01 17:47:30,288 - stpipe.Spec2Pipeline.extract_1d - WARNING - Using RELSENS, 387 elements were extrapolated; these values will be set to 1.
# 2018-05-01 17:47:30,463 - stpipe.Spec2Pipeline.extract_1d - INFO - Saved model in LRS-SLIT_demo_data_pipeline/lrs_bgsub_1_x1d.fits
# 2018-05-01 17:47:30,464 - stpipe.Spec2Pipeline.extract_1d - INFO - Step extract_1d done
# 2018-05-01 17:47:30,465 - stpipe.Spec2Pipeline - INFO - Finished processing product lrs_bgsub_1
# 2018-05-01 17:47:30,693 - stpipe.Spec2Pipeline - INFO - Saved model in LRS-SLIT_demo_data_pipeline/lrs_bgsub_1_cal.fits
# 2018-05-01 17:47:30,761 - stpipe.Spec2Pipeline - INFO - Ending calwebb_spec2
# 2018-05-01 17:47:30,763 - stpipe.Spec2Pipeline - INFO - Step Spec2Pipeline done

# %% [markdown]
# ### check of output
#
# We can have a look at the steps applied to the level 2B file in the pipeline

# %%
# set the output file names
level2B_files = glob.glob(os.path.join(output_dir,'*_cal.fits'))

with datamodels.open(level2B_files[0]) as dm:
    # check the calibration step information
    print('Check step information status:')
    print('assign_wcs: %s' % dm.meta.cal_step.assign_wcs)
    print('bkg_subtract: %s' % dm.meta.cal_step.back_sub)
    print('flat_field: %s' % dm.meta.cal_step.flat_field)
    print('srctype: %s' % dm.meta.cal_step.srctype)
    print('photom: %s' % dm.meta.cal_step.photom)
# Out:
# Check step information status:
# assign_wcs: COMPLETE
# bkg_subtract: COMPLETE
# flat_field: COMPLETE
# srctype: COMPLETE
# photom: COMPLETE

# %% [markdown]
# While the photom step attaches the SRF to the _cal.fits file, it does not actually apply it so we must manually convert the extracted spectrum from DN/s to Jy using the SRF. We can look at the SRF while is located in the 'relsens' object in the metadata.

# %%
with datamodels.open(level2B_files[0]) as dm:  
    #print(dm.relsens)
    relsens = np.array(dm.relsens, dtype=[('wavelength', 'f4'), ('response', 'i8')])
    # plot--------------------------------------
    fig, axs = plt.subplots(1, 1, figsize=(8, 6))

    # plot input and output ramps of the first integration
    axs.plot(relsens['wavelength'], relsens['response'], c='b', marker='o', markersize=2, 
             markeredgewidth=3, linestyle='-', linewidth=1, label='relsens')
    axs.set_title('RELSENS', fontsize=15)
    axs.set_xlabel('wavelength (micron)', fontsize=15)
    axs.set_ylabel('SRF (DN/s/Jy)', fontsize=15)

    plt.tight_layout(h_pad=0)
    plt.show()

# %% [markdown]
# #### plot the spectrum
# Using the SRF, we can flux calibrate and plot the extracted spectrum

# %%
spec_file = glob.glob(os.path.join(output_dir,"*x1d.fits"))[0]
dm = datamodels.open(spec_file)

fig, axs = plt.subplots(1, 1, figsize=(10, 7))

# convert the flux to Jy
response_at_data = np.interp(dm.spec[0].spec_table['WAVELENGTH'][1:-1], relsens['wavelength'], relsens['response'])
flux_Jy = dm.spec[0].spec_table['FLUX'][1:-1] / response_at_data

# plot the spectrum 
axs.plot(dm.spec[0].spec_table['WAVELENGTH'][1:-1], flux_Jy, c='b', marker='.', 
         markersize=0, linestyle='-', linewidth=2)
axs.set_ylabel(r'Flux (Jy)')
axs.set_xlabel(r'Wavelength ($\mu$m)')
axs.set_xlim(5.0,14.0)
axs.set_ylim(0,0.02)
plt.grid()
plt.show()
